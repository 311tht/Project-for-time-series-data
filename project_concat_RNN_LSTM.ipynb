# %% [markdown]
# ## **0. Tải bộ dữ liệu**

# %%
# https://drive.google.com/file/d/1FC2P-NC8q_6cAqYIAkV4mBH5MCF1c-oc/view?usp=share_link
# !gdown --id 1FC2P-NC8q_6cAqYIAkV4mBH5MCF1c-oc
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1FC2P-NC8q_6cAqYIAkV4mBH5MCF1c-oc
# To: /content/tesla_stock_price.zip
# 100% 34.1k/34.1k [00:00<00:00, 36.4MB/s]

# %%
# !unzip './tesla_stock_price.zip'
# Out:
# Archive:  ./tesla_stock_price.zip
#   inflating: tesla_stock.csv

# %% [markdown]
# ## **1. Import các thư viện cần thiết**

# %%
import os   
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

from sklearn.model_selection import train_test_split

RANDOM_SEED = 1
tf.random.set_seed(RANDOM_SEED)

# %% [markdown]
# ## **2. Trực quan hóa dữ liệu**

# %%
dataset_filepath = './tesla_stock.csv' # Khai báo đường dẫn đến file .csv của bộ dữ liệu
df = pd.read_csv(dataset_filepath, index_col=0) # Đọc file .csv thành DataFrame
df
# Out:
#                  Open        High         Low       Close    Volume  \
# Date
# 6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 7/1/2010    25.000000   25.920000   20.270000   21.959999   8218800
# 7/2/2010    23.000000   23.100000   18.709999   19.200001   5139800
# 7/6/2010    20.000000   20.000000   15.830000   16.110001   6866900
# ...               ...         ...         ...         ...       ...
# 3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#             Adj Close
# Date
# 6/29/2010   23.889999
# 6/30/2010   23.830000
# 7/1/2010    21.959999
# 7/2/2010    19.200001
# 7/6/2010    16.110001
# ...               ...
# 3/13/2017  246.169998
# 3/14/2017  258.000000
# 3/15/2017  255.729996
# 3/16/2017  262.049988
# 3/17/2017  261.500000
#
# [1692 rows x 6 columns]

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.215000    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1692 entries, 6/29/2010 to 3/17/2017
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1692 non-null   float64
#  1   High       1692 non-null   float64
#  2   Low        1692 non-null   float64
#  3   Close      1692 non-null   float64
#  4   Volume     1692 non-null   int64
#  5   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 92.5+ KB

# %%
plt.figure(figsize=(10, 5))
df['Adj Close'].plot()
plt.title('Adjusted Closing Price of Tesla Stock')
plt.xlabel('Date')
plt.ylabel('Adj Closing Price')
plt.show()

# %%
plt.figure(figsize=(10, 5))
df['Volume'].plot()
plt.title('Volume over day of Tesla Stock')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.show()

# %% [markdown]
# ## **3. Chuẩn bị dữ liệu**

# %%
# Khai báo hàm Windowing (dùng để tạo các cặp X, y cho time series data)
def slicing_window(df, df_start_idx, df_end_idx, input_size, label_size, offset, label_name):
    features = [] # Khai báo list dùng để lưu trữ các X
    labels = [] # Khai báo list dùng để lưu trữ các y

    # Nếu df_end_idx = chỉ mục cuối cùng bảng dữ liệu, cần phải dời xuống 1 khoảng = window size 
    if df_end_idx == None:
        df_end_idx = len(df) - label_size - offset

    df_start_idx = df_start_idx + input_size + offset

    # Duyệt qua từng mẫu dữ liệu
    for idx in range(df_start_idx, df_end_idx):
        feature_start_idx = idx - input_size - offset
        feature_end_idx = feature_start_idx + input_size

        label_start_idx = idx - 1
        label_end_idx = label_start_idx + label_size

        feature = df[feature_start_idx:feature_end_idx] # Lấy X
        label = df[label_name][label_start_idx:label_end_idx] # Lấy y

        features.append(feature) 
        labels.append(label)

    # Chuyển list thành np.ndarrray
    features = np.array(features)
    labels = np.array(labels)

    return features, labels

# %%
INPUT_SIZE = 30 
LABEL_SIZE = 1 
OFFSET = 1 
BATCH_SIZE = 64
TARGET_NAME = 'Adj Close'

# %%
dataset_length = len(df) # Số lượng mẫu dữ liệu trong DataFrame
TRAIN_SIZE = 0.7 # Tỉ lệ kích thước tập train
VAL_SIZE = 0.2 # Tỉ lệ kích thước tập val
# Đổi tỉ lệ thành chỉ mục
TRAIN_END_IDX = int(TRAIN_SIZE * dataset_length) 
VAL_END_IDX = int(VAL_SIZE * dataset_length) + TRAIN_END_IDX

# Khởi tạo X, y cho tập train
X_train, y_train = slicing_window(df, 
                                  df_start_idx=0,
                                  df_end_idx=TRAIN_END_IDX,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET,
                                  label_name=TARGET_NAME)

# Khởi tạo X, y cho tập val
X_val, y_val = slicing_window(df, 
                                  df_start_idx=TRAIN_END_IDX,
                                  df_end_idx=VAL_END_IDX,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET,
                                  label_name=TARGET_NAME)

# Khởi tạo X, y cho tập test
X_test, y_test = slicing_window(df, 
                                  df_start_idx=VAL_END_IDX,
                                  df_end_idx=None,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET,
                                  label_name=TARGET_NAME)

# %%
# Khởi tạo tf.data.Dataset
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(BATCH_SIZE)
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(BATCH_SIZE)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE)

# %%
# Cấu hình các tham số tối ưu cho việc đọc dữ liệu
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## **4. Xây dựng mô hình**

# %%
# Khai báo normalization layer
normalize_layer = tf.keras.layers.Normalization()
normalize_layer.adapt(np.vstack((X_train, X_val, X_test)))

# %%
# Xây dựng hàm khởi tạo model
def build_model(input_shape, output_size):
    input_layer = tf.keras.Input(shape=input_shape, name='input_layer')

    x = normalize_layer(input_layer)

    for n_unit in [128, 64]:
        rnn_x = tf.keras.layers.SimpleRNN(n_unit, 
                                    return_sequences=True, 
                                    kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)
                                    )(x)
        
        lstm_x = tf.keras.layers.LSTM(n_unit, 
                                    return_sequences=True, 
                                    kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)
                                    )(x)

        x = tf.concat([rnn_x, lstm_x], axis=-1)  

    rnn_x = tf.keras.layers.SimpleRNN(n_unit, 
                                return_sequences=False, 
                                kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)
                                )(x)
    
    lstm_x = tf.keras.layers.LSTM(n_unit, 
                                return_sequences=False, 
                                kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)
                                )(x)

    x = tf.concat([rnn_x, lstm_x], axis=-1)  
                        
    x = tf.keras.layers.Dense(32,
                            activation='relu',
                            kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED),
                            name='fc_layer_1'
                            )(x)
    
    output_layer = tf.keras.layers.Dense(output_size, 
                            kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED),
                            name='output_layer')(x)

    model = tf.keras.Model(input_layer, output_layer, name='combined_model')

    return model

# %%
INPUT_SHAPE = X_train.shape[-2:] 
model = build_model(INPUT_SHAPE,
                    LABEL_SIZE)
model.summary()
# Out:
# Model: "combined_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_layer (InputLayer)       [(None, 30, 6)]      0           []
#
#  normalization (Normalization)  multiple             13          ['input_layer[0][0]']
#
#  simple_rnn_8 (SimpleRNN)       (None, 30, 128)      17280       ['normalization[4][0]']
#
#  lstm_8 (LSTM)                  (None, 30, 128)      69120       ['normalization[4][0]']
#
#  tf.concat_7 (TFOpLambda)       (None, 30, 256)      0           ['simple_rnn_8[0][0]',
#                                                                   'lstm_8[0][0]']
#
#  simple_rnn_9 (SimpleRNN)       (None, 30, 64)       20544       ['tf.concat_7[0][0]']
#
#  lstm_9 (LSTM)                  (None, 30, 64)       82176       ['tf.concat_7[0][0]']
#
#  tf.concat_8 (TFOpLambda)       (None, 30, 128)      0           ['simple_rnn_9[0][0]',
#                                                                   'lstm_9[0][0]']
#
#  simple_rnn_10 (SimpleRNN)      (None, 64)           12352       ['tf.concat_8[0][0]']
#
#  lstm_10 (LSTM)                 (None, 64)           49408       ['tf.concat_8[0][0]']
#
#  tf.concat_9 (TFOpLambda)       (None, 128)          0           ['simple_rnn_10[0][0]',
#                                                                   'lstm_10[0][0]']
#
#  fc_layer_1 (Dense)             (None, 32)           4128        ['tf.concat_9[0][0]']
#
#  output_layer (Dense)           (None, 1)            33          ['fc_layer_1[0][0]']
#
# ==================================================================================================
# Total params: 255,054
# Trainable params: 255,041
# Non-trainable params: 13
# __________________________________________________________________________________________________

# %% [markdown]
# ## **5. Cấu hình mô hình**

# %%
# Khai báo một số giá trị siêu tham số
EPOCHS = 500
LR = 1e-3

# %%
# Cấu hình một số thông tin cho mô hình
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR), # Sử dụng optimizer Adam
    loss=tf.keras.losses.MeanSquaredError(), # Sử dụng hàm loss Mean Squared Error
)

# %% [markdown]
# ## **6. Huấn luyện mô hình**

# %%
history = model.fit(train_ds, 
                    validation_data=val_ds,
                    epochs=EPOCHS)
# Out:
# Epoch 1/500
# 19/19 [==============================] - 10s 155ms/step - loss: 16021.3965 - val_loss: 52657.9844
# Epoch 2/500
# 19/19 [==============================] - 2s 90ms/step - loss: 15040.5791 - val_loss: 50851.6758
# Epoch 3/500
# 19/19 [==============================] - 2s 86ms/step - loss: 13555.9648 - val_loss: 43382.0625
# Epoch 4/500
# 19/19 [==============================] - 2s 86ms/step - loss: 11565.0410 - val_loss: 39540.8516
# Epoch 5/500
# 19/19 [==============================] - 2s 88ms/step - loss: 10369.1826 - val_loss: 35957.5234
# Epoch 6/500
# 19/19 [==============================] - 2s 85ms/step - loss: 9436.9463 - val_loss: 32814.6250
# Epoch 7/500
# 19/19 [==============================] - 2s 87ms/step - loss: 8730.0156 - val_loss: 30076.5547
# Epoch 8/500
# 19/19 [==============================] - 2s 86ms/step - loss: 8211.0879 - val_loss: 27720.7109
# Epoch 9/500
# 19/19 [==============================] - 2s 85ms/step - loss: 7841.0601 - val_loss: 25721.6230
# Epoch 10/500
# 19/19 [==============================] - 2s 87ms/step - loss: 7661.7451 - val_loss: 24078.0469
# Epoch 11/500
# 19/19 [==============================] - 2s 92ms/step - loss: 7410.4639 - val_loss: 22720.7363
# Epoch 12/500
# 19/19 [==============================] - 2s 84ms/step - loss: 7152.7803 - val_loss: 21471.0801
# Epoch 13/500
# 19/19 [==============================] - 2s 85ms/step - loss: 5142.4790 - val_loss: 19160.5801
# Epoch 14/500
# 19/19 [==============================] - 2s 87ms/step - loss: 4378.3701 - val_loss: 16738.0098
# Epoch 15/500
# 19/19 [==============================] - 2s 84ms/step - loss: 3698.9927 - val_loss: 14460.3193
# Epoch 16/500
# 19/19 [==============================] - 2s 84ms/step - loss: 3100.2703 - val_loss: 12352.4521
# Epoch 17/500
# 19/19 [==============================] - 2s 84ms/step - loss: 2585.9531 - val_loss: 10497.0547
# Epoch 18/500
# 19/19 [==============================] - 2s 83ms/step - loss: 2159.0283 - val_loss: 8890.2529
# Epoch 19/500
# 19/19 [==============================] - 2s 84ms/step - loss: 1809.6818 - val_loss: 7520.8403
# Epoch 20/500
# 19/19 [==============================] - 2s 86ms/step - loss: 1531.9845 - val_loss: 6362.3320
# Epoch 21/500
# 19/19 [==============================] - 2s 87ms/step - loss: 1307.9426 - val_loss: 5364.9102
# Epoch 22/500
# 19/19 [==============================] - 2s 87ms/step - loss: 1229.4094 - val_loss: 4935.3613
# Epoch 23/500
# 19/19 [==============================] - 2s 85ms/step - loss: 1222.9589 - val_loss: 4964.1890
# Epoch 24/500
# 19/19 [==============================] - 2s 89ms/step - loss: 1071.0199 - val_loss: 4251.7993
# Epoch 25/500
# 19/19 [==============================] - 2s 85ms/step - loss: 1018.6202 - val_loss: 3951.5146
# Epoch 26/500
# 19/19 [==============================] - 2s 89ms/step - loss: 892.8365 - val_loss: 3426.7080
# Epoch 27/500
# 19/19 [==============================] - 2s 87ms/step - loss: 826.8583 - val_loss: 3215.4490
# Epoch 28/500
# 19/19 [==============================] - 2s 84ms/step - loss: 1193.3777 - val_loss: 2979.1611
# Epoch 29/500
# 19/19 [==============================] - 2s 86ms/step - loss: 1091.8562 - val_loss: 4030.6157
# Epoch 30/500
# 19/19 [==============================] - 2s 84ms/step - loss: 887.0897 - val_loss: 3409.8745
# Epoch 31/500
# 19/19 [==============================] - 2s 89ms/step - loss: 813.2997 - val_loss: 2646.6929
# Epoch 32/500
# 19/19 [==============================] - 2s 88ms/step - loss: 825.1863 - val_loss: 2417.1721
# Epoch 33/500
# 19/19 [==============================] - 2s 87ms/step - loss: 897.1811 - val_loss: 2769.7397
# Epoch 34/500
# 19/19 [==============================] - 2s 87ms/step - loss: 832.7100 - val_loss: 2743.2322
# Epoch 35/500
# 19/19 [==============================] - 2s 85ms/step - loss: 743.3394 - val_loss: 2836.1125
# Epoch 36/500
# 19/19 [==============================] - 2s 83ms/step - loss: 598.1919 - val_loss: 2167.6211
# Epoch 37/500
# 19/19 [==============================] - 2s 88ms/step - loss: 570.3696 - val_loss: 1884.8937
# Epoch 38/500
# 19/19 [==============================] - 2s 87ms/step - loss: 487.1937 - val_loss: 1514.6201
# Epoch 39/500
# 19/19 [==============================] - 2s 87ms/step - loss: 624.5555 - val_loss: 1396.8018
# Epoch 40/500
# 19/19 [==============================] - 2s 84ms/step - loss: 487.3036 - val_loss: 1366.5680
# Epoch 41/500
# 19/19 [==============================] - 2s 85ms/step - loss: 431.7368 - val_loss: 1276.0573
# Epoch 42/500
# 19/19 [==============================] - 2s 88ms/step - loss: 394.4869 - val_loss: 1165.3774
# Epoch 43/500
# 19/19 [==============================] - 2s 84ms/step - loss: 404.3351 - val_loss: 1299.1272
# Epoch 44/500
# 19/19 [==============================] - 2s 85ms/step - loss: 511.0807 - val_loss: 1236.3542
# Epoch 45/500
# 19/19 [==============================] - 2s 87ms/step - loss: 433.0017 - val_loss: 1216.4941
# Epoch 46/500
# 19/19 [==============================] - 2s 87ms/step - loss: 390.8877 - val_loss: 1155.7872
# Epoch 47/500
# 19/19 [==============================] - 2s 87ms/step - loss: 368.0478 - val_loss: 1107.4795
# Epoch 48/500
# 19/19 [==============================] - 2s 84ms/step - loss: 316.6767 - val_loss: 1012.7766
# Epoch 49/500
# 19/19 [==============================] - 2s 83ms/step - loss: 319.2509 - val_loss: 911.0576
# Epoch 50/500
# 19/19 [==============================] - 2s 84ms/step - loss: 459.9236 - val_loss: 863.4310
# Epoch 51/500
# 19/19 [==============================] - 2s 86ms/step - loss: 1359.2026 - val_loss: 909.1752
# Epoch 52/500
# 19/19 [==============================] - 2s 85ms/step - loss: 477.3417 - val_loss: 994.5901
# Epoch 53/500
# 19/19 [==============================] - 2s 86ms/step - loss: 364.4239 - val_loss: 978.3257
# Epoch 54/500
# 19/19 [==============================] - 2s 85ms/step - loss: 326.6543 - val_loss: 922.8553
# Epoch 55/500
# 19/19 [==============================] - 2s 86ms/step - loss: 317.7328 - val_loss: 881.5980
# Epoch 56/500
# 19/19 [==============================] - 2s 86ms/step - loss: 499.6092 - val_loss: 962.6986
# Epoch 57/500
# 19/19 [==============================] - 2s 85ms/step - loss: 885.0261 - val_loss: 1160.9845
# Epoch 58/500
# 19/19 [==============================] - 2s 88ms/step - loss: 727.6790 - val_loss: 972.0761
# Epoch 59/500
# 19/19 [==============================] - 2s 89ms/step - loss: 666.4091 - val_loss: 794.3926
# Epoch 60/500
# 19/19 [==============================] - 2s 87ms/step - loss: 744.8107 - val_loss: 849.8313
# Epoch 61/500
# 19/19 [==============================] - 2s 86ms/step - loss: 483.8061 - val_loss: 982.1273
# Epoch 62/500
# 19/19 [==============================] - 2s 87ms/step - loss: 448.8561 - val_loss: 869.6889
# Epoch 63/500
# 19/19 [==============================] - 2s 89ms/step - loss: 321.5174 - val_loss: 830.6487
# Epoch 64/500
# 19/19 [==============================] - 2s 88ms/step - loss: 271.2917 - val_loss: 753.0099
# Epoch 65/500
# 19/19 [==============================] - 2s 89ms/step - loss: 221.8453 - val_loss: 658.7578
# Epoch 66/500
# 19/19 [==============================] - 2s 86ms/step - loss: 231.9966 - val_loss: 577.7386
# Epoch 67/500
# 19/19 [==============================] - 2s 86ms/step - loss: 244.5361 - val_loss: 583.8705
# Epoch 68/500
# 19/19 [==============================] - 2s 87ms/step - loss: 434.6525 - val_loss: 524.0225
# Epoch 69/500
# 19/19 [==============================] - 2s 87ms/step - loss: 430.4179 - val_loss: 550.7473
# Epoch 70/500
# 19/19 [==============================] - 2s 86ms/step - loss: 301.0600 - val_loss: 674.4005
# Epoch 71/500
# 19/19 [==============================] - 2s 87ms/step - loss: 227.0820 - val_loss: 582.2474
# Epoch 72/500
# 19/19 [==============================] - 2s 82ms/step - loss: 207.6112 - val_loss: 552.6653
# Epoch 73/500
# 19/19 [==============================] - 2s 84ms/step - loss: 203.7177 - val_loss: 475.6687
# Epoch 74/500
# 19/19 [==============================] - 2s 83ms/step - loss: 176.0253 - val_loss: 392.9376
# Epoch 75/500
# 19/19 [==============================] - 2s 88ms/step - loss: 183.2692 - val_loss: 366.5391
# Epoch 76/500
# 19/19 [==============================] - 2s 88ms/step - loss: 195.4768 - val_loss: 339.9148
# Epoch 77/500
# 19/19 [==============================] - 2s 88ms/step - loss: 230.3765 - val_loss: 332.2533
# Epoch 78/500
# 19/19 [==============================] - 2s 85ms/step - loss: 296.2504 - val_loss: 336.8630
# Epoch 79/500
# 19/19 [==============================] - 2s 86ms/step - loss: 359.6331 - val_loss: 328.6353
# Epoch 80/500
# 19/19 [==============================] - 2s 82ms/step - loss: 391.9017 - val_loss: 486.8616
# Epoch 81/500
# 19/19 [==============================] - 2s 87ms/step - loss: 193.8060 - val_loss: 402.8676
# Epoch 82/500
# 19/19 [==============================] - 2s 88ms/step - loss: 158.3421 - val_loss: 350.9849
# Epoch 83/500
# 19/19 [==============================] - 2s 83ms/step - loss: 139.7820 - val_loss: 326.0153
# Epoch 84/500
# 19/19 [==============================] - 2s 84ms/step - loss: 129.5864 - val_loss: 298.0541
# Epoch 85/500
# 19/19 [==============================] - 2s 85ms/step - loss: 117.8678 - val_loss: 274.8329
# Epoch 86/500
# 19/19 [==============================] - 2s 85ms/step - loss: 111.2363 - val_loss: 256.0941
# Epoch 87/500
# 19/19 [==============================] - 2s 87ms/step - loss: 108.8384 - val_loss: 241.6878
# Epoch 88/500
# 19/19 [==============================] - 2s 87ms/step - loss: 126.1398 - val_loss: 216.5013
# Epoch 89/500
# 19/19 [==============================] - 2s 85ms/step - loss: 158.6088 - val_loss: 227.6330
# Epoch 90/500
# 19/19 [==============================] - 2s 87ms/step - loss: 217.1785 - val_loss: 259.2265
# Epoch 91/500
# 19/19 [==============================] - 2s 86ms/step - loss: 232.3858 - val_loss: 231.3576
# Epoch 92/500
# 19/19 [==============================] - 2s 86ms/step - loss: 267.0267 - val_loss: 245.6678
# Epoch 93/500
# 19/19 [==============================] - 2s 82ms/step - loss: 357.4403 - val_loss: 367.5216
# Epoch 94/500
# 19/19 [==============================] - 2s 86ms/step - loss: 286.5202 - val_loss: 349.5240
# Epoch 95/500
# 19/19 [==============================] - 2s 84ms/step - loss: 211.8000 - val_loss: 309.7445
# Epoch 96/500
# 19/19 [==============================] - 2s 84ms/step - loss: 173.8519 - val_loss: 283.6028
# Epoch 97/500
# 19/19 [==============================] - 2s 85ms/step - loss: 134.6900 - val_loss: 254.7090
# Epoch 98/500
# 19/19 [==============================] - 2s 85ms/step - loss: 128.2154 - val_loss: 253.5004
# Epoch 99/500
# 19/19 [==============================] - 2s 87ms/step - loss: 112.6541 - val_loss: 221.9976
# Epoch 100/500
# 19/19 [==============================] - 2s 89ms/step - loss: 122.0471 - val_loss: 208.4800
# Epoch 101/500
# 19/19 [==============================] - 2s 85ms/step - loss: 103.4799 - val_loss: 193.9267
# Epoch 102/500
# 19/19 [==============================] - 2s 85ms/step - loss: 107.8330 - val_loss: 187.1554
# Epoch 103/500
# 19/19 [==============================] - 2s 86ms/step - loss: 99.2877 - val_loss: 178.8138
# Epoch 104/500
# 19/19 [==============================] - 2s 87ms/step - loss: 120.4909 - val_loss: 173.9780
# Epoch 105/500
# 19/19 [==============================] - 2s 87ms/step - loss: 129.8419 - val_loss: 161.8184
# Epoch 106/500
# 19/19 [==============================] - 2s 86ms/step - loss: 184.1165 - val_loss: 168.7272
# Epoch 107/500
# 19/19 [==============================] - 2s 87ms/step - loss: 183.3491 - val_loss: 213.3728
# Epoch 108/500
# 19/19 [==============================] - 3s 146ms/step - loss: 172.2944 - val_loss: 212.4572
# Epoch 109/500
# 19/19 [==============================] - 2s 88ms/step - loss: 121.5287 - val_loss: 201.3973
# Epoch 110/500
# 19/19 [==============================] - 2s 88ms/step - loss: 123.2769 - val_loss: 199.3262
# Epoch 111/500
# 19/19 [==============================] - 2s 84ms/step - loss: 102.6154 - val_loss: 181.7750
# Epoch 112/500
# 19/19 [==============================] - 2s 90ms/step - loss: 94.9143 - val_loss: 174.1085
# Epoch 113/500
# 19/19 [==============================] - 2s 90ms/step - loss: 88.5788 - val_loss: 164.7304
# Epoch 114/500
# 19/19 [==============================] - 2s 88ms/step - loss: 92.5807 - val_loss: 164.8985
# Epoch 115/500
# 19/19 [==============================] - 2s 88ms/step - loss: 91.2047 - val_loss: 153.5827
# Epoch 116/500
# 19/19 [==============================] - 2s 87ms/step - loss: 111.1912 - val_loss: 156.2205
# Epoch 117/500
# 19/19 [==============================] - 2s 87ms/step - loss: 113.1373 - val_loss: 142.6658
# Epoch 118/500
# 19/19 [==============================] - 2s 85ms/step - loss: 149.2227 - val_loss: 162.7739
# Epoch 119/500
# 19/19 [==============================] - 2s 86ms/step - loss: 139.5064 - val_loss: 160.4260
# Epoch 120/500
# 19/19 [==============================] - 2s 86ms/step - loss: 148.0826 - val_loss: 176.5964
# Epoch 121/500
# 19/19 [==============================] - 2s 87ms/step - loss: 122.2425 - val_loss: 163.4014
# Epoch 122/500
# 19/19 [==============================] - 2s 86ms/step - loss: 122.6380 - val_loss: 176.7263
# Epoch 123/500
# 19/19 [==============================] - 2s 87ms/step - loss: 107.8354 - val_loss: 158.8541
# Epoch 124/500
# 19/19 [==============================] - 2s 86ms/step - loss: 92.7350 - val_loss: 170.3147
# Epoch 125/500
# 19/19 [==============================] - 2s 85ms/step - loss: 80.0051 - val_loss: 144.5587
# Epoch 126/500
# 19/19 [==============================] - 2s 88ms/step - loss: 76.9053 - val_loss: 142.2681
# Epoch 127/500
# 19/19 [==============================] - 2s 85ms/step - loss: 79.1421 - val_loss: 124.5236
# Epoch 128/500
# 19/19 [==============================] - 2s 87ms/step - loss: 90.4430 - val_loss: 126.0912
# Epoch 129/500
# 19/19 [==============================] - 2s 87ms/step - loss: 87.8135 - val_loss: 117.0802
# Epoch 130/500
# 19/19 [==============================] - 2s 89ms/step - loss: 88.5478 - val_loss: 118.7846
# Epoch 131/500
# 19/19 [==============================] - 2s 86ms/step - loss: 91.6289 - val_loss: 122.4242
# Epoch 132/500
# 19/19 [==============================] - 2s 86ms/step - loss: 94.9747 - val_loss: 127.2436
# Epoch 133/500
# 19/19 [==============================] - 2s 86ms/step - loss: 115.5825 - val_loss: 122.7205
# Epoch 134/500
# 19/19 [==============================] - 2s 87ms/step - loss: 131.4212 - val_loss: 144.2238
# Epoch 135/500
# 19/19 [==============================] - 2s 87ms/step - loss: 139.6944 - val_loss: 142.8052
# Epoch 136/500
# 19/19 [==============================] - 2s 83ms/step - loss: 148.9106 - val_loss: 171.6595
# Epoch 137/500
# 19/19 [==============================] - 2s 83ms/step - loss: 102.6640 - val_loss: 150.2738
# Epoch 138/500
# 19/19 [==============================] - 2s 87ms/step - loss: 86.4047 - val_loss: 136.8757
# Epoch 139/500
# 19/19 [==============================] - 2s 84ms/step - loss: 83.5079 - val_loss: 135.5854
# Epoch 140/500
# 19/19 [==============================] - 2s 84ms/step - loss: 72.3728 - val_loss: 125.1412
# Epoch 141/500
# 19/19 [==============================] - 2s 87ms/step - loss: 70.2685 - val_loss: 122.8691
# Epoch 142/500
# 19/19 [==============================] - 2s 88ms/step - loss: 64.2420 - val_loss: 119.8901
# Epoch 143/500
# 19/19 [==============================] - 2s 88ms/step - loss: 66.7978 - val_loss: 110.3610
# Epoch 144/500
# 19/19 [==============================] - 2s 88ms/step - loss: 63.5798 - val_loss: 111.3237
# Epoch 145/500
# 19/19 [==============================] - 2s 86ms/step - loss: 65.4636 - val_loss: 107.5137
# Epoch 146/500
# 19/19 [==============================] - 2s 88ms/step - loss: 68.1593 - val_loss: 107.9190
# Epoch 147/500
# 19/19 [==============================] - 2s 86ms/step - loss: 74.6307 - val_loss: 99.9259
# Epoch 148/500
# 19/19 [==============================] - 2s 88ms/step - loss: 71.4118 - val_loss: 103.5567
# Epoch 149/500
# 19/19 [==============================] - 2s 92ms/step - loss: 83.6449 - val_loss: 103.4068
# Epoch 150/500
# 19/19 [==============================] - 2s 87ms/step - loss: 93.6695 - val_loss: 113.5963
# Epoch 151/500
# 19/19 [==============================] - 2s 87ms/step - loss: 132.7792 - val_loss: 128.5771
# Epoch 152/500
# 19/19 [==============================] - 2s 87ms/step - loss: 242.5869 - val_loss: 181.6613
# Epoch 153/500
# 19/19 [==============================] - 2s 85ms/step - loss: 439.0622 - val_loss: 181.2849
# Epoch 154/500
# 19/19 [==============================] - 2s 89ms/step - loss: 609.7091 - val_loss: 867.8613
# Epoch 155/500
# 19/19 [==============================] - 2s 85ms/step - loss: 727.3523 - val_loss: 656.0991
# Epoch 156/500
# 19/19 [==============================] - 2s 86ms/step - loss: 348.2145 - val_loss: 811.2292
# Epoch 157/500
# 19/19 [==============================] - 2s 86ms/step - loss: 229.4209 - val_loss: 564.1555
# Epoch 158/500
# 19/19 [==============================] - 2s 87ms/step - loss: 214.6682 - val_loss: 525.3463
# Epoch 159/500
# 19/19 [==============================] - 2s 85ms/step - loss: 302.2268 - val_loss: 435.5040
# Epoch 160/500
# 19/19 [==============================] - 2s 88ms/step - loss: 230.8634 - val_loss: 428.3044
# Epoch 161/500
# 19/19 [==============================] - 2s 86ms/step - loss: 208.3428 - val_loss: 392.4366
# Epoch 162/500
# 19/19 [==============================] - 2s 86ms/step - loss: 188.3656 - val_loss: 332.8607
# Epoch 163/500
# 19/19 [==============================] - 2s 86ms/step - loss: 172.0428 - val_loss: 287.1672
# Epoch 164/500
# 19/19 [==============================] - 2s 88ms/step - loss: 145.3907 - val_loss: 270.5175
# Epoch 165/500
# 19/19 [==============================] - 2s 86ms/step - loss: 130.7950 - val_loss: 242.4983
# Epoch 166/500
# 19/19 [==============================] - 2s 86ms/step - loss: 119.2986 - val_loss: 223.6653
# Epoch 167/500
# 19/19 [==============================] - 2s 87ms/step - loss: 132.4736 - val_loss: 234.2811
# Epoch 168/500
# 19/19 [==============================] - 2s 88ms/step - loss: 123.8580 - val_loss: 229.1751
# Epoch 169/500
# 19/19 [==============================] - 2s 87ms/step - loss: 101.5284 - val_loss: 219.4653
# Epoch 170/500
# 19/19 [==============================] - 2s 87ms/step - loss: 96.4221 - val_loss: 190.7300
# Epoch 171/500
# 19/19 [==============================] - 2s 87ms/step - loss: 90.5874 - val_loss: 195.1496
# Epoch 172/500
# 19/19 [==============================] - 2s 88ms/step - loss: 79.6981 - val_loss: 177.0375
# Epoch 173/500
# 19/19 [==============================] - 2s 83ms/step - loss: 72.1839 - val_loss: 166.8820
# Epoch 174/500
# 19/19 [==============================] - 2s 86ms/step - loss: 58.0822 - val_loss: 157.1680
# Epoch 175/500
# 19/19 [==============================] - 2s 87ms/step - loss: 68.4025 - val_loss: 148.1004
# Epoch 176/500
# 19/19 [==============================] - 2s 87ms/step - loss: 51.5494 - val_loss: 139.5563
# Epoch 177/500
# 19/19 [==============================] - 2s 85ms/step - loss: 47.1703 - val_loss: 132.2258
# Epoch 178/500
# 19/19 [==============================] - 2s 88ms/step - loss: 59.0946 - val_loss: 126.2382
# Epoch 179/500
# 19/19 [==============================] - 2s 88ms/step - loss: 42.9327 - val_loss: 118.0183
# Epoch 180/500
# 19/19 [==============================] - 2s 87ms/step - loss: 42.8618 - val_loss: 111.4432
# Epoch 181/500
# 19/19 [==============================] - 2s 85ms/step - loss: 43.6926 - val_loss: 108.5040
# Epoch 182/500
# 19/19 [==============================] - 2s 87ms/step - loss: 52.2062 - val_loss: 105.6614
# Epoch 183/500
# 19/19 [==============================] - 2s 87ms/step - loss: 66.0525 - val_loss: 118.3267
# Epoch 184/500
# 19/19 [==============================] - 2s 90ms/step - loss: 63.5638 - val_loss: 101.6325
# Epoch 185/500
# 19/19 [==============================] - 2s 86ms/step - loss: 42.2952 - val_loss: 97.2000
# Epoch 186/500
# 19/19 [==============================] - 2s 87ms/step - loss: 43.9411 - val_loss: 90.6904
# Epoch 187/500
# 19/19 [==============================] - 2s 88ms/step - loss: 36.1203 - val_loss: 90.1731
# Epoch 188/500
# 19/19 [==============================] - 2s 86ms/step - loss: 30.3961 - val_loss: 86.6422
# Epoch 189/500
# 19/19 [==============================] - 2s 86ms/step - loss: 32.1926 - val_loss: 85.5746
# Epoch 190/500
# 19/19 [==============================] - 2s 84ms/step - loss: 30.7071 - val_loss: 87.9858
# Epoch 191/500
# 19/19 [==============================] - 2s 85ms/step - loss: 49.5395 - val_loss: 84.9034
# Epoch 192/500
# 19/19 [==============================] - 2s 87ms/step - loss: 35.3411 - val_loss: 91.1445
# Epoch 193/500
# 19/19 [==============================] - 2s 85ms/step - loss: 55.8584 - val_loss: 92.2668
# Epoch 194/500
# 19/19 [==============================] - 2s 84ms/step - loss: 67.5794 - val_loss: 113.9211
# Epoch 195/500
# 19/19 [==============================] - 2s 87ms/step - loss: 104.5936 - val_loss: 90.1011
# Epoch 196/500
# 19/19 [==============================] - 2s 87ms/step - loss: 70.7794 - val_loss: 100.8940
# Epoch 197/500
# 19/19 [==============================] - 2s 84ms/step - loss: 65.0024 - val_loss: 107.1354
# Epoch 198/500
# 19/19 [==============================] - 2s 86ms/step - loss: 71.3855 - val_loss: 94.9623
# Epoch 199/500
# 19/19 [==============================] - 2s 83ms/step - loss: 124.1501 - val_loss: 138.4575
# Epoch 200/500
# 19/19 [==============================] - 2s 85ms/step - loss: 189.9348 - val_loss: 184.7460
# Epoch 201/500
# 19/19 [==============================] - 2s 87ms/step - loss: 318.0005 - val_loss: 177.2623
# Epoch 202/500
# 19/19 [==============================] - 2s 84ms/step - loss: 455.3201 - val_loss: 322.1730
# Epoch 203/500
# 19/19 [==============================] - 2s 86ms/step - loss: 351.0211 - val_loss: 227.0665
# Epoch 204/500
# 19/19 [==============================] - 2s 86ms/step - loss: 275.2586 - val_loss: 484.1450
# Epoch 205/500
# 19/19 [==============================] - 2s 86ms/step - loss: 160.1587 - val_loss: 322.8174
# Epoch 206/500
# 19/19 [==============================] - 2s 88ms/step - loss: 126.3498 - val_loss: 243.4111
# Epoch 207/500
# 19/19 [==============================] - 2s 88ms/step - loss: 100.2223 - val_loss: 175.4743
# Epoch 208/500
# 19/19 [==============================] - 2s 86ms/step - loss: 84.1508 - val_loss: 121.6203
# Epoch 209/500
# 19/19 [==============================] - 2s 84ms/step - loss: 77.7786 - val_loss: 119.9852
# Epoch 210/500
# 19/19 [==============================] - 2s 83ms/step - loss: 137.2879 - val_loss: 217.2598
# Epoch 211/500
# 19/19 [==============================] - 2s 85ms/step - loss: 112.6908 - val_loss: 148.9716
# Epoch 212/500
# 19/19 [==============================] - 2s 87ms/step - loss: 158.0879 - val_loss: 110.0483
# Epoch 213/500
# 19/19 [==============================] - 2s 85ms/step - loss: 238.3875 - val_loss: 276.4316
# Epoch 214/500
# 19/19 [==============================] - 2s 91ms/step - loss: 163.7354 - val_loss: 210.2249
# Epoch 215/500
# 19/19 [==============================] - 2s 87ms/step - loss: 144.5993 - val_loss: 224.7988
# Epoch 216/500
# 19/19 [==============================] - 2s 85ms/step - loss: 111.0231 - val_loss: 136.6460
# Epoch 217/500
# 19/19 [==============================] - 2s 83ms/step - loss: 109.9519 - val_loss: 123.2336
# Epoch 218/500
# 19/19 [==============================] - 2s 84ms/step - loss: 103.6722 - val_loss: 135.4400
# Epoch 219/500
# 19/19 [==============================] - 2s 83ms/step - loss: 90.8899 - val_loss: 114.1061
# Epoch 220/500
# 19/19 [==============================] - 2s 88ms/step - loss: 163.2134 - val_loss: 121.2257
# Epoch 221/500
# 19/19 [==============================] - 2s 85ms/step - loss: 171.0532 - val_loss: 113.3951
# Epoch 222/500
# 19/19 [==============================] - 2s 86ms/step - loss: 131.0135 - val_loss: 540.7583
# Epoch 223/500
# 19/19 [==============================] - 2s 88ms/step - loss: 158.0895 - val_loss: 265.7085
# Epoch 224/500
# 19/19 [==============================] - 2s 88ms/step - loss: 213.2708 - val_loss: 167.4624
# Epoch 225/500
# 19/19 [==============================] - 2s 84ms/step - loss: 118.1314 - val_loss: 129.0564
# Epoch 226/500
# 19/19 [==============================] - 2s 94ms/step - loss: 99.6662 - val_loss: 151.7301
# Epoch 227/500
# 19/19 [==============================] - 3s 139ms/step - loss: 68.5500 - val_loss: 117.3962
# Epoch 228/500
# 19/19 [==============================] - 2s 85ms/step - loss: 77.1653 - val_loss: 106.5374
# Epoch 229/500
# 19/19 [==============================] - 2s 87ms/step - loss: 59.8529 - val_loss: 117.1772
# Epoch 230/500
# 19/19 [==============================] - 2s 87ms/step - loss: 71.0305 - val_loss: 96.8088
# Epoch 231/500
# 19/19 [==============================] - 2s 85ms/step - loss: 51.4383 - val_loss: 94.0637
# Epoch 232/500
# 19/19 [==============================] - 2s 88ms/step - loss: 51.4701 - val_loss: 92.0616
# Epoch 233/500
# 19/19 [==============================] - 2s 88ms/step - loss: 64.3640 - val_loss: 90.1428
# Epoch 234/500
# 19/19 [==============================] - 2s 88ms/step - loss: 52.6993 - val_loss: 89.2054
# Epoch 235/500
# 19/19 [==============================] - 2s 83ms/step - loss: 48.9627 - val_loss: 81.4961
# Epoch 236/500
# 19/19 [==============================] - 2s 87ms/step - loss: 40.1966 - val_loss: 81.2354
# Epoch 237/500
# 19/19 [==============================] - 2s 86ms/step - loss: 34.1828 - val_loss: 81.3124
# Epoch 238/500
# 19/19 [==============================] - 2s 84ms/step - loss: 33.0860 - val_loss: 79.4301
# Epoch 239/500
# 19/19 [==============================] - 2s 86ms/step - loss: 29.8333 - val_loss: 80.2736
# Epoch 240/500
# 19/19 [==============================] - 2s 85ms/step - loss: 33.9991 - val_loss: 77.6799
# Epoch 241/500
# 19/19 [==============================] - 2s 86ms/step - loss: 31.1133 - val_loss: 80.7004
# Epoch 242/500
# 19/19 [==============================] - 2s 85ms/step - loss: 45.9047 - val_loss: 76.1103
# Epoch 243/500
# 19/19 [==============================] - 2s 87ms/step - loss: 42.0779 - val_loss: 84.9639
# Epoch 244/500
# 19/19 [==============================] - 2s 84ms/step - loss: 69.2099 - val_loss: 79.0322
# Epoch 245/500
# 19/19 [==============================] - 2s 86ms/step - loss: 43.6383 - val_loss: 83.9288
# Epoch 246/500
# 19/19 [==============================] - 2s 87ms/step - loss: 43.1600 - val_loss: 79.5078
# Epoch 247/500
# 19/19 [==============================] - 2s 84ms/step - loss: 28.1757 - val_loss: 79.4706
# Epoch 248/500
# 19/19 [==============================] - 2s 86ms/step - loss: 31.6082 - val_loss: 76.9901
# Epoch 249/500
# 19/19 [==============================] - 2s 87ms/step - loss: 27.5661 - val_loss: 79.6719
# Epoch 250/500
# 19/19 [==============================] - 2s 85ms/step - loss: 32.9313 - val_loss: 77.1113
# Epoch 251/500
# 19/19 [==============================] - 2s 87ms/step - loss: 30.2817 - val_loss: 81.7529
# Epoch 252/500
# 19/19 [==============================] - 2s 84ms/step - loss: 43.2978 - val_loss: 76.7550
# Epoch 253/500
# 19/19 [==============================] - 2s 85ms/step - loss: 34.9425 - val_loss: 92.9145
# Epoch 254/500
# 19/19 [==============================] - 2s 86ms/step - loss: 57.2120 - val_loss: 91.5067
# Epoch 255/500
# 19/19 [==============================] - 2s 85ms/step - loss: 37.9256 - val_loss: 84.8729
# Epoch 256/500
# 19/19 [==============================] - 2s 85ms/step - loss: 36.0867 - val_loss: 96.4864
# Epoch 257/500
# 19/19 [==============================] - 2s 86ms/step - loss: 63.1050 - val_loss: 104.4538
# Epoch 258/500
# 19/19 [==============================] - 2s 87ms/step - loss: 44.1780 - val_loss: 82.9913
# Epoch 259/500
# 19/19 [==============================] - 2s 87ms/step - loss: 60.4930 - val_loss: 81.0868
# Epoch 260/500
# 19/19 [==============================] - 2s 90ms/step - loss: 51.9888 - val_loss: 83.3950
# Epoch 261/500
# 19/19 [==============================] - 2s 88ms/step - loss: 51.5956 - val_loss: 85.5505
# Epoch 262/500
# 19/19 [==============================] - 2s 86ms/step - loss: 106.0034 - val_loss: 329.5236
# Epoch 263/500
# 19/19 [==============================] - 2s 83ms/step - loss: 122.9792 - val_loss: 114.9773
# Epoch 264/500
# 19/19 [==============================] - 2s 87ms/step - loss: 281.4910 - val_loss: 177.4072
# Epoch 265/500
# 19/19 [==============================] - 2s 86ms/step - loss: 502.3001 - val_loss: 379.0428
# Epoch 266/500
# 19/19 [==============================] - 2s 86ms/step - loss: 368.3776 - val_loss: 254.5688
# Epoch 267/500
# 19/19 [==============================] - 2s 89ms/step - loss: 192.3059 - val_loss: 255.8672
# Epoch 268/500
# 19/19 [==============================] - 2s 86ms/step - loss: 147.3105 - val_loss: 209.0571
# Epoch 269/500
# 19/19 [==============================] - 2s 87ms/step - loss: 228.2553 - val_loss: 186.8869
# Epoch 270/500
# 19/19 [==============================] - 2s 87ms/step - loss: 288.8633 - val_loss: 199.4247
# Epoch 271/500
# 19/19 [==============================] - 2s 88ms/step - loss: 195.2343 - val_loss: 231.6293
# Epoch 272/500
# 19/19 [==============================] - 2s 86ms/step - loss: 142.4441 - val_loss: 149.5470
# Epoch 273/500
# 19/19 [==============================] - 2s 88ms/step - loss: 83.8506 - val_loss: 122.9389
# Epoch 274/500
# 19/19 [==============================] - 2s 85ms/step - loss: 61.5980 - val_loss: 96.0376
# Epoch 275/500
# 19/19 [==============================] - 2s 87ms/step - loss: 70.4551 - val_loss: 96.1114
# Epoch 276/500
# 19/19 [==============================] - 2s 88ms/step - loss: 40.4851 - val_loss: 87.8935
# Epoch 277/500
# 19/19 [==============================] - 2s 87ms/step - loss: 34.2800 - val_loss: 86.3218
# Epoch 278/500
# 19/19 [==============================] - 2s 88ms/step - loss: 30.3286 - val_loss: 84.7570
# Epoch 279/500
# 19/19 [==============================] - 2s 86ms/step - loss: 31.5308 - val_loss: 82.9356
# Epoch 280/500
# 19/19 [==============================] - 2s 84ms/step - loss: 29.0909 - val_loss: 83.3939
# Epoch 281/500
# 19/19 [==============================] - 2s 86ms/step - loss: 34.3323 - val_loss: 81.4787
# Epoch 282/500
# 19/19 [==============================] - 2s 84ms/step - loss: 33.5203 - val_loss: 84.9028
# Epoch 283/500
# 19/19 [==============================] - 2s 85ms/step - loss: 45.9874 - val_loss: 79.9944
# Epoch 284/500
# 19/19 [==============================] - 2s 86ms/step - loss: 36.7509 - val_loss: 87.0194
# Epoch 285/500
# 19/19 [==============================] - 2s 89ms/step - loss: 47.5088 - val_loss: 80.8464
# Epoch 286/500
# 19/19 [==============================] - 2s 89ms/step - loss: 33.9662 - val_loss: 89.1998
# Epoch 287/500
# 19/19 [==============================] - 2s 88ms/step - loss: 54.6704 - val_loss: 79.8698
# Epoch 288/500
# 19/19 [==============================] - 2s 85ms/step - loss: 29.2524 - val_loss: 80.2218
# Epoch 289/500
# 19/19 [==============================] - 2s 87ms/step - loss: 28.6932 - val_loss: 76.9975
# Epoch 290/500
# 19/19 [==============================] - 2s 85ms/step - loss: 24.6865 - val_loss: 76.0186
# Epoch 291/500
# 19/19 [==============================] - 2s 85ms/step - loss: 27.5792 - val_loss: 74.5600
# Epoch 292/500
# 19/19 [==============================] - 2s 88ms/step - loss: 27.0899 - val_loss: 80.0408
# Epoch 293/500
# 19/19 [==============================] - 2s 86ms/step - loss: 42.9875 - val_loss: 78.7253
# Epoch 294/500
# 19/19 [==============================] - 2s 85ms/step - loss: 90.2157 - val_loss: 78.5180
# Epoch 295/500
# 19/19 [==============================] - 2s 87ms/step - loss: 167.0076 - val_loss: 99.6965
# Epoch 296/500
# 19/19 [==============================] - 2s 87ms/step - loss: 212.7339 - val_loss: 243.1015
# Epoch 297/500
# 19/19 [==============================] - 2s 86ms/step - loss: 164.4800 - val_loss: 125.5687
# Epoch 298/500
# 19/19 [==============================] - 2s 87ms/step - loss: 176.4396 - val_loss: 121.3531
# Epoch 299/500
# 19/19 [==============================] - 2s 86ms/step - loss: 104.7231 - val_loss: 118.6571
# Epoch 300/500
# 19/19 [==============================] - 2s 83ms/step - loss: 115.6729 - val_loss: 150.7980
# Epoch 301/500
# 19/19 [==============================] - 2s 85ms/step - loss: 109.9264 - val_loss: 123.8747
# Epoch 302/500
# 19/19 [==============================] - 2s 86ms/step - loss: 90.1259 - val_loss: 126.8002
# Epoch 303/500
# 19/19 [==============================] - 2s 84ms/step - loss: 91.1821 - val_loss: 108.9429
# Epoch 304/500
# 19/19 [==============================] - 2s 87ms/step - loss: 80.3242 - val_loss: 119.8465
# Epoch 305/500
# 19/19 [==============================] - 2s 87ms/step - loss: 88.5091 - val_loss: 108.8222
# Epoch 306/500
# 19/19 [==============================] - 2s 84ms/step - loss: 90.0124 - val_loss: 126.8534
# Epoch 307/500
# 19/19 [==============================] - 2s 83ms/step - loss: 75.7423 - val_loss: 128.8023
# Epoch 308/500
# 19/19 [==============================] - 2s 85ms/step - loss: 68.3971 - val_loss: 130.9757
# Epoch 309/500
# 19/19 [==============================] - 2s 86ms/step - loss: 45.3620 - val_loss: 101.5022
# Epoch 310/500
# 19/19 [==============================] - 2s 83ms/step - loss: 69.8380 - val_loss: 114.5683
# Epoch 311/500
# 19/19 [==============================] - 2s 88ms/step - loss: 35.5672 - val_loss: 98.6034
# Epoch 312/500
# 19/19 [==============================] - 2s 87ms/step - loss: 36.0445 - val_loss: 99.0891
# Epoch 313/500
# 19/19 [==============================] - 2s 86ms/step - loss: 28.0732 - val_loss: 93.6919
# Epoch 314/500
# 19/19 [==============================] - 2s 84ms/step - loss: 33.3503 - val_loss: 91.8100
# Epoch 315/500
# 19/19 [==============================] - 2s 86ms/step - loss: 29.8389 - val_loss: 87.9060
# Epoch 316/500
# 19/19 [==============================] - 2s 86ms/step - loss: 32.1505 - val_loss: 90.3008
# Epoch 317/500
# 19/19 [==============================] - 2s 86ms/step - loss: 27.1359 - val_loss: 86.2096
# Epoch 318/500
# 19/19 [==============================] - 2s 88ms/step - loss: 30.1699 - val_loss: 87.0233
# Epoch 319/500
# 19/19 [==============================] - 2s 90ms/step - loss: 28.1833 - val_loss: 95.5504
# Epoch 320/500
# 19/19 [==============================] - 2s 90ms/step - loss: 37.5666 - val_loss: 96.0437
# Epoch 321/500
# 19/19 [==============================] - 2s 84ms/step - loss: 44.8814 - val_loss: 85.9672
# Epoch 322/500
# 19/19 [==============================] - 2s 88ms/step - loss: 62.2323 - val_loss: 87.8066
# Epoch 323/500
# 19/19 [==============================] - 2s 87ms/step - loss: 66.1602 - val_loss: 90.3068
# Epoch 324/500
# 19/19 [==============================] - 2s 83ms/step - loss: 89.4874 - val_loss: 93.4777
# Epoch 325/500
# 19/19 [==============================] - 2s 87ms/step - loss: 85.3734 - val_loss: 92.1642
# Epoch 326/500
# 19/19 [==============================] - 2s 85ms/step - loss: 112.2173 - val_loss: 104.6151
# Epoch 327/500
# 19/19 [==============================] - 2s 84ms/step - loss: 61.5510 - val_loss: 96.3193
# Epoch 328/500
# 19/19 [==============================] - 2s 85ms/step - loss: 93.8300 - val_loss: 113.6010
# Epoch 329/500
# 19/19 [==============================] - 2s 87ms/step - loss: 98.8416 - val_loss: 99.5510
# Epoch 330/500
# 19/19 [==============================] - 2s 87ms/step - loss: 87.8251 - val_loss: 127.6119
# Epoch 331/500
# 19/19 [==============================] - 2s 89ms/step - loss: 101.6983 - val_loss: 116.7535
# Epoch 332/500
# 19/19 [==============================] - 2s 88ms/step - loss: 100.8210 - val_loss: 146.7583
# Epoch 333/500
# 19/19 [==============================] - 2s 87ms/step - loss: 77.9791 - val_loss: 120.9208
# Epoch 334/500
# 19/19 [==============================] - 2s 89ms/step - loss: 83.8488 - val_loss: 134.1950
# Epoch 335/500
# 19/19 [==============================] - 2s 88ms/step - loss: 84.7192 - val_loss: 108.4794
# Epoch 336/500
# 19/19 [==============================] - 2s 87ms/step - loss: 91.0493 - val_loss: 123.1782
# Epoch 337/500
# 19/19 [==============================] - 2s 90ms/step - loss: 72.4739 - val_loss: 102.3219
# Epoch 338/500
# 19/19 [==============================] - 2s 86ms/step - loss: 68.3189 - val_loss: 116.0894
# Epoch 339/500
# 19/19 [==============================] - 2s 84ms/step - loss: 45.5765 - val_loss: 111.6815
# Epoch 340/500
# 19/19 [==============================] - 2s 86ms/step - loss: 70.5709 - val_loss: 93.7861
# Epoch 341/500
# 19/19 [==============================] - 2s 87ms/step - loss: 38.1056 - val_loss: 91.8659
# Epoch 342/500
# 19/19 [==============================] - 2s 87ms/step - loss: 47.8950 - val_loss: 110.3436
# Epoch 343/500
# 19/19 [==============================] - 2s 86ms/step - loss: 32.9538 - val_loss: 103.7262
# Epoch 344/500
# 19/19 [==============================] - 2s 110ms/step - loss: 50.9312 - val_loss: 90.5709
# Epoch 345/500
# 19/19 [==============================] - 2s 117ms/step - loss: 26.7116 - val_loss: 93.2630
# Epoch 346/500
# 19/19 [==============================] - 2s 86ms/step - loss: 28.0512 - val_loss: 91.5599
# Epoch 347/500
# 19/19 [==============================] - 2s 86ms/step - loss: 23.5969 - val_loss: 90.0792
# Epoch 348/500
# 19/19 [==============================] - 2s 88ms/step - loss: 24.3620 - val_loss: 89.3414
# Epoch 349/500
# 19/19 [==============================] - 2s 85ms/step - loss: 23.7860 - val_loss: 89.0443
# Epoch 350/500
# 19/19 [==============================] - 2s 85ms/step - loss: 29.2501 - val_loss: 88.1972
# Epoch 351/500
# 19/19 [==============================] - 2s 89ms/step - loss: 33.8776 - val_loss: 93.1482
# Epoch 352/500
# 19/19 [==============================] - 2s 85ms/step - loss: 55.2260 - val_loss: 97.4929
# Epoch 353/500
# 19/19 [==============================] - 2s 88ms/step - loss: 54.8655 - val_loss: 98.7280
# Epoch 354/500
# 19/19 [==============================] - 2s 87ms/step - loss: 99.4372 - val_loss: 113.8306
# Epoch 355/500
# 19/19 [==============================] - 2s 90ms/step - loss: 88.8975 - val_loss: 96.0607
# Epoch 356/500
# 19/19 [==============================] - 2s 89ms/step - loss: 98.9160 - val_loss: 94.4713
# Epoch 357/500
# 19/19 [==============================] - 2s 86ms/step - loss: 71.3939 - val_loss: 91.0757
# Epoch 358/500
# 19/19 [==============================] - 2s 91ms/step - loss: 88.1200 - val_loss: 88.7291
# Epoch 359/500
# 19/19 [==============================] - 2s 86ms/step - loss: 107.6738 - val_loss: 94.3148
# Epoch 360/500
# 19/19 [==============================] - 2s 87ms/step - loss: 107.1165 - val_loss: 124.9650
# Epoch 361/500
# 19/19 [==============================] - 2s 88ms/step - loss: 95.7665 - val_loss: 103.0958
# Epoch 362/500
# 19/19 [==============================] - 2s 88ms/step - loss: 100.1500 - val_loss: 137.5818
# Epoch 363/500
# 19/19 [==============================] - 2s 89ms/step - loss: 91.5730 - val_loss: 119.9042
# Epoch 364/500
# 19/19 [==============================] - 2s 93ms/step - loss: 99.7881 - val_loss: 130.7738
# Epoch 365/500
# 19/19 [==============================] - 2s 90ms/step - loss: 71.9900 - val_loss: 113.9671
# Epoch 366/500
# 19/19 [==============================] - 2s 92ms/step - loss: 54.7937 - val_loss: 108.1663
# Epoch 367/500
# 19/19 [==============================] - 2s 89ms/step - loss: 54.6400 - val_loss: 88.8996
# Epoch 368/500
# 19/19 [==============================] - 2s 87ms/step - loss: 50.5632 - val_loss: 97.6143
# Epoch 369/500
# 19/19 [==============================] - 2s 88ms/step - loss: 34.9400 - val_loss: 83.7543
# Epoch 370/500
# 19/19 [==============================] - 2s 89ms/step - loss: 32.1484 - val_loss: 83.4114
# Epoch 371/500
# 19/19 [==============================] - 2s 86ms/step - loss: 25.0582 - val_loss: 77.7925
# Epoch 372/500
# 19/19 [==============================] - 2s 88ms/step - loss: 26.7830 - val_loss: 79.3174
# Epoch 373/500
# 19/19 [==============================] - 2s 87ms/step - loss: 22.7432 - val_loss: 79.1278
# Epoch 374/500
# 19/19 [==============================] - 2s 92ms/step - loss: 19.2726 - val_loss: 78.4511
# Epoch 375/500
# 19/19 [==============================] - 2s 86ms/step - loss: 17.2155 - val_loss: 79.9639
# Epoch 376/500
# 19/19 [==============================] - 2s 87ms/step - loss: 18.5275 - val_loss: 79.8951
# Epoch 377/500
# 19/19 [==============================] - 2s 89ms/step - loss: 17.3397 - val_loss: 79.9475
# Epoch 378/500
# 19/19 [==============================] - 2s 92ms/step - loss: 22.2610 - val_loss: 81.0013
# Epoch 379/500
# 19/19 [==============================] - 2s 90ms/step - loss: 27.0434 - val_loss: 82.1716
# Epoch 380/500
# 19/19 [==============================] - 2s 90ms/step - loss: 37.1995 - val_loss: 83.5415
# Epoch 381/500
# 19/19 [==============================] - 2s 91ms/step - loss: 39.6777 - val_loss: 79.2178
# Epoch 382/500
# 19/19 [==============================] - 2s 87ms/step - loss: 46.3446 - val_loss: 96.2102
# Epoch 383/500
# 19/19 [==============================] - 2s 87ms/step - loss: 46.4631 - val_loss: 81.9640
# Epoch 384/500
# 19/19 [==============================] - 2s 87ms/step - loss: 87.6731 - val_loss: 96.0768
# Epoch 385/500
# 19/19 [==============================] - 2s 89ms/step - loss: 44.4221 - val_loss: 80.7938
# Epoch 386/500
# 19/19 [==============================] - 2s 90ms/step - loss: 58.3006 - val_loss: 83.5617
# Epoch 387/500
# 19/19 [==============================] - 2s 89ms/step - loss: 44.6743 - val_loss: 82.7450
# Epoch 388/500
# 19/19 [==============================] - 2s 88ms/step - loss: 66.8205 - val_loss: 94.6676
# Epoch 389/500
# 19/19 [==============================] - 2s 90ms/step - loss: 74.8087 - val_loss: 97.9968
# Epoch 390/500
# 19/19 [==============================] - 2s 88ms/step - loss: 34.8946 - val_loss: 91.5217
# Epoch 391/500
# 19/19 [==============================] - 2s 91ms/step - loss: 37.0012 - val_loss: 91.9281
# Epoch 392/500
# 19/19 [==============================] - 2s 91ms/step - loss: 39.6474 - val_loss: 81.2157
# Epoch 393/500
# 19/19 [==============================] - 2s 83ms/step - loss: 35.7312 - val_loss: 83.8598
# Epoch 394/500
# 19/19 [==============================] - 2s 87ms/step - loss: 38.2808 - val_loss: 76.7263
# Epoch 395/500
# 19/19 [==============================] - 2s 89ms/step - loss: 32.4778 - val_loss: 81.2078
# Epoch 396/500
# 19/19 [==============================] - 2s 87ms/step - loss: 42.4494 - val_loss: 80.4065
# Epoch 397/500
# 19/19 [==============================] - 2s 90ms/step - loss: 43.3168 - val_loss: 95.1051
# Epoch 398/500
# 19/19 [==============================] - 2s 90ms/step - loss: 48.0921 - val_loss: 84.9108
# Epoch 399/500
# 19/19 [==============================] - 2s 88ms/step - loss: 45.7391 - val_loss: 84.9443
# Epoch 400/500
# 19/19 [==============================] - 2s 89ms/step - loss: 64.0968 - val_loss: 87.2731
# Epoch 401/500
# 19/19 [==============================] - 2s 89ms/step - loss: 32.8435 - val_loss: 75.7065
# Epoch 402/500
# 19/19 [==============================] - 2s 87ms/step - loss: 34.4572 - val_loss: 85.3076
# Epoch 403/500
# 19/19 [==============================] - 2s 91ms/step - loss: 23.5517 - val_loss: 79.6189
# Epoch 404/500
# 19/19 [==============================] - 2s 92ms/step - loss: 24.7211 - val_loss: 97.9330
# Epoch 405/500
# 19/19 [==============================] - 2s 89ms/step - loss: 38.4560 - val_loss: 82.3910
# Epoch 406/500
# 19/19 [==============================] - 2s 88ms/step - loss: 37.0017 - val_loss: 78.5476
# Epoch 407/500
# 19/19 [==============================] - 2s 90ms/step - loss: 47.3410 - val_loss: 73.6798
# Epoch 408/500
# 19/19 [==============================] - 2s 87ms/step - loss: 77.1944 - val_loss: 83.9311
# Epoch 409/500
# 19/19 [==============================] - 2s 91ms/step - loss: 117.6163 - val_loss: 105.8307
# Epoch 410/500
# 19/19 [==============================] - 2s 92ms/step - loss: 111.8202 - val_loss: 108.6602
# Epoch 411/500
# 19/19 [==============================] - 2s 90ms/step - loss: 102.8842 - val_loss: 91.0909
# Epoch 412/500
# 19/19 [==============================] - 2s 88ms/step - loss: 164.8865 - val_loss: 209.9023
# Epoch 413/500
# 19/19 [==============================] - 2s 91ms/step - loss: 308.2202 - val_loss: 436.8091
# Epoch 414/500
# 19/19 [==============================] - 2s 87ms/step - loss: 125.6584 - val_loss: 205.8888
# Epoch 415/500
# 19/19 [==============================] - 2s 86ms/step - loss: 86.9375 - val_loss: 135.6202
# Epoch 416/500
# 19/19 [==============================] - 2s 86ms/step - loss: 70.5593 - val_loss: 94.9657
# Epoch 417/500
# 19/19 [==============================] - 2s 88ms/step - loss: 82.1965 - val_loss: 104.8843
# Epoch 418/500
# 19/19 [==============================] - 2s 86ms/step - loss: 99.0698 - val_loss: 107.2056
# Epoch 419/500
# 19/19 [==============================] - 2s 86ms/step - loss: 91.7705 - val_loss: 113.1329
# Epoch 420/500
# 19/19 [==============================] - 2s 87ms/step - loss: 88.1570 - val_loss: 102.0629
# Epoch 421/500
# 19/19 [==============================] - 2s 88ms/step - loss: 173.7227 - val_loss: 129.4688
# Epoch 422/500
# 19/19 [==============================] - 2s 92ms/step - loss: 213.3335 - val_loss: 264.3405
# Epoch 423/500
# 19/19 [==============================] - 2s 88ms/step - loss: 100.9549 - val_loss: 127.5383
# Epoch 424/500
# 19/19 [==============================] - 2s 86ms/step - loss: 69.0953 - val_loss: 99.9004
# Epoch 425/500
# 19/19 [==============================] - 2s 89ms/step - loss: 56.3742 - val_loss: 104.7178
# Epoch 426/500
# 19/19 [==============================] - 2s 88ms/step - loss: 61.1000 - val_loss: 100.6874
# Epoch 427/500
# 19/19 [==============================] - 2s 90ms/step - loss: 45.8274 - val_loss: 87.0514
# Epoch 428/500
# 19/19 [==============================] - 2s 89ms/step - loss: 44.7982 - val_loss: 78.6634
# Epoch 429/500
# 19/19 [==============================] - 2s 88ms/step - loss: 40.8718 - val_loss: 84.1468
# Epoch 430/500
# 19/19 [==============================] - 2s 87ms/step - loss: 50.4529 - val_loss: 82.0511
# Epoch 431/500
# 19/19 [==============================] - 2s 89ms/step - loss: 35.0079 - val_loss: 84.1573
# Epoch 432/500
# 19/19 [==============================] - 2s 88ms/step - loss: 33.5445 - val_loss: 75.4488
# Epoch 433/500
# 19/19 [==============================] - 2s 88ms/step - loss: 26.6558 - val_loss: 75.7246
# Epoch 434/500
# 19/19 [==============================] - 2s 91ms/step - loss: 31.2978 - val_loss: 78.2140
# Epoch 435/500
# 19/19 [==============================] - 2s 87ms/step - loss: 28.2539 - val_loss: 71.9111
# Epoch 436/500
# 19/19 [==============================] - 2s 88ms/step - loss: 22.4635 - val_loss: 68.5564
# Epoch 437/500
# 19/19 [==============================] - 2s 90ms/step - loss: 23.5274 - val_loss: 68.7090
# Epoch 438/500
# 19/19 [==============================] - 2s 89ms/step - loss: 27.5884 - val_loss: 80.2005
# Epoch 439/500
# 19/19 [==============================] - 2s 90ms/step - loss: 49.0164 - val_loss: 80.3512
# Epoch 440/500
# 19/19 [==============================] - 2s 90ms/step - loss: 58.0937 - val_loss: 85.1192
# Epoch 441/500
# 19/19 [==============================] - 2s 89ms/step - loss: 100.6782 - val_loss: 85.8709
# Epoch 442/500
# 19/19 [==============================] - 2s 86ms/step - loss: 62.4993 - val_loss: 93.4825
# Epoch 443/500
# 19/19 [==============================] - 2s 90ms/step - loss: 110.1247 - val_loss: 105.7612
# Epoch 444/500
# 19/19 [==============================] - 2s 93ms/step - loss: 92.2815 - val_loss: 83.0522
# Epoch 445/500
# 19/19 [==============================] - 2s 90ms/step - loss: 105.5034 - val_loss: 167.5118
# Epoch 446/500
# 19/19 [==============================] - 2s 84ms/step - loss: 108.5508 - val_loss: 136.9213
# Epoch 447/500
# 19/19 [==============================] - 2s 90ms/step - loss: 137.0926 - val_loss: 157.3428
# Epoch 448/500
# 19/19 [==============================] - 2s 88ms/step - loss: 141.8311 - val_loss: 143.7321
# Epoch 449/500
# 19/19 [==============================] - 2s 88ms/step - loss: 93.2260 - val_loss: 185.1043
# Epoch 450/500
# 19/19 [==============================] - 2s 86ms/step - loss: 51.3120 - val_loss: 102.4594
# Epoch 451/500
# 19/19 [==============================] - 2s 87ms/step - loss: 39.0299 - val_loss: 88.6107
# Epoch 452/500
# 19/19 [==============================] - 2s 88ms/step - loss: 27.9034 - val_loss: 80.9348
# Epoch 453/500
# 19/19 [==============================] - 2s 89ms/step - loss: 28.7637 - val_loss: 78.5656
# Epoch 454/500
# 19/19 [==============================] - 2s 91ms/step - loss: 21.1380 - val_loss: 73.2810
# Epoch 455/500
# 19/19 [==============================] - 2s 90ms/step - loss: 20.4963 - val_loss: 73.6736
# Epoch 456/500
# 19/19 [==============================] - 2s 88ms/step - loss: 20.8102 - val_loss: 75.2104
# Epoch 457/500
# 19/19 [==============================] - 2s 88ms/step - loss: 19.7569 - val_loss: 72.0152
# Epoch 458/500
# 19/19 [==============================] - 2s 91ms/step - loss: 18.1911 - val_loss: 77.2086
# Epoch 459/500
# 19/19 [==============================] - 2s 94ms/step - loss: 18.5383 - val_loss: 78.8663
# Epoch 460/500
# 19/19 [==============================] - 3s 138ms/step - loss: 18.2708 - val_loss: 78.9112
# Epoch 461/500
# 19/19 [==============================] - 2s 90ms/step - loss: 19.5994 - val_loss: 72.4781
# Epoch 462/500
# 19/19 [==============================] - 2s 91ms/step - loss: 18.8053 - val_loss: 73.3194
# Epoch 463/500
# 19/19 [==============================] - 2s 88ms/step - loss: 21.8532 - val_loss: 71.4729
# Epoch 464/500
# 19/19 [==============================] - 2s 90ms/step - loss: 22.6087 - val_loss: 71.8321
# Epoch 465/500
# 19/19 [==============================] - 2s 90ms/step - loss: 34.4010 - val_loss: 72.7615
# Epoch 466/500
# 19/19 [==============================] - 2s 88ms/step - loss: 32.6103 - val_loss: 73.9684
# Epoch 467/500
# 19/19 [==============================] - 2s 88ms/step - loss: 49.4605 - val_loss: 82.9865
# Epoch 468/500
# 19/19 [==============================] - 2s 86ms/step - loss: 53.5403 - val_loss: 85.4456
# Epoch 469/500
# 19/19 [==============================] - 2s 87ms/step - loss: 76.4956 - val_loss: 79.3766
# Epoch 470/500
# 19/19 [==============================] - 2s 90ms/step - loss: 30.4089 - val_loss: 69.7641
# Epoch 471/500
# 19/19 [==============================] - 2s 91ms/step - loss: 40.8190 - val_loss: 67.8688
# Epoch 472/500
# 19/19 [==============================] - 2s 98ms/step - loss: 25.8620 - val_loss: 73.2038
# Epoch 473/500
# 19/19 [==============================] - 2s 90ms/step - loss: 28.0778 - val_loss: 67.7550
# Epoch 474/500
# 19/19 [==============================] - 2s 94ms/step - loss: 20.5216 - val_loss: 66.8067
# Epoch 475/500
# 19/19 [==============================] - 2s 93ms/step - loss: 17.3417 - val_loss: 68.0175
# Epoch 476/500
# 19/19 [==============================] - 2s 90ms/step - loss: 21.7297 - val_loss: 71.5444
# Epoch 477/500
# 19/19 [==============================] - 2s 89ms/step - loss: 19.4948 - val_loss: 67.3516
# Epoch 478/500
# 19/19 [==============================] - 2s 89ms/step - loss: 35.3979 - val_loss: 72.8252
# Epoch 479/500
# 19/19 [==============================] - 2s 89ms/step - loss: 36.2478 - val_loss: 74.8590
# Epoch 480/500
# 19/19 [==============================] - 2s 88ms/step - loss: 22.9509 - val_loss: 73.5419
# Epoch 481/500
# 19/19 [==============================] - 2s 88ms/step - loss: 20.6559 - val_loss: 89.6141
# Epoch 482/500
# 19/19 [==============================] - 2s 93ms/step - loss: 29.7790 - val_loss: 72.6342
# Epoch 483/500
# 19/19 [==============================] - 2s 89ms/step - loss: 33.5011 - val_loss: 66.4639
# Epoch 484/500
# 19/19 [==============================] - 2s 90ms/step - loss: 41.6211 - val_loss: 64.9261
# Epoch 485/500
# 19/19 [==============================] - 2s 91ms/step - loss: 42.5822 - val_loss: 83.9199
# Epoch 486/500
# 19/19 [==============================] - 2s 92ms/step - loss: 73.4481 - val_loss: 75.9228
# Epoch 487/500
# 19/19 [==============================] - 2s 90ms/step - loss: 70.5501 - val_loss: 97.8768
# Epoch 488/500
# 19/19 [==============================] - 2s 90ms/step - loss: 93.8681 - val_loss: 75.4510
# Epoch 489/500
# 19/19 [==============================] - 2s 89ms/step - loss: 86.9245 - val_loss: 107.3395
# Epoch 490/500
# 19/19 [==============================] - 2s 92ms/step - loss: 127.3812 - val_loss: 104.5160
# Epoch 491/500
# 19/19 [==============================] - 2s 92ms/step - loss: 132.3144 - val_loss: 96.0006
# Epoch 492/500
# 19/19 [==============================] - 2s 92ms/step - loss: 110.9384 - val_loss: 635.6104
# Epoch 493/500
# 19/19 [==============================] - 2s 87ms/step - loss: 80.1982 - val_loss: 101.1502
# Epoch 494/500
# 19/19 [==============================] - 2s 90ms/step - loss: 48.9399 - val_loss: 94.9918
# Epoch 495/500
# 19/19 [==============================] - 2s 88ms/step - loss: 50.4216 - val_loss: 96.0030
# Epoch 496/500
# 19/19 [==============================] - 2s 89ms/step - loss: 60.2196 - val_loss: 84.9074
# Epoch 497/500
# 19/19 [==============================] - 2s 91ms/step - loss: 62.5232 - val_loss: 146.8230
# Epoch 498/500
# 19/19 [==============================] - 2s 92ms/step - loss: 84.7761 - val_loss: 99.7309
# Epoch 499/500
# 19/19 [==============================] - 2s 94ms/step - loss: 53.6723 - val_loss: 106.2777
# Epoch 500/500
# 19/19 [==============================] - 2s 92ms/step - loss: 42.0573 - val_loss: 87.2245

# %% [markdown]
# ## **7. Đánh giá và trực quan hóa**

# %%
def mae(y_true, y_pred):
    mae = np.mean(np.abs((y_true - y_pred)))

    return mae

def mse(y_true, y_pred):
    mse = np.mean((y_true - y_pred) ** 2)

    return mse

def rmse(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true-y_pred)**2))

    return rmse

def mape(y_true, y_pred):
    mape = np.mean(np.abs((y_true-y_pred) / y_true)) * 100

    return mape

# %%
y_test_pred = model.predict(X_test, verbose=0)
print(f'RMSE: {rmse(y_test, y_test_pred)}')
print(f'MAPE: {mape(y_test, y_test_pred)}')
print(f'MSE: {mse(y_test, y_test_pred)}')
print(f'MAE: {mae(y_test, y_test_pred)}')
# Out:
# RMSE: 7.789138611092089
# MAPE: 2.8000696337746875
# MSE: 60.67068030280561
# MAE: 6.073736595239793

# %%
train_loss = history.history['loss']# Đọc thông tin loss trên tập train
val_loss = history.history['val_loss'] # Đọc thông tin loss trên tập val

plt.figure(figsize=(10, 5)) # Cài đặt kích thước khung ảnh

plt.subplot(1, 2, 1) # Khởi tạo khung ảnh cho training loss
plt.xlabel('Epochs') # Hiển thị tên trục hoành là 'Epochs'
plt.ylabel('Loss') # Hiển thị tên trục tung là 'Loss'
plt.title('Training loss') # Hiển thị title của khung ảnh hiện tại là 'Training Loss'
plt.plot(train_loss, color='green') # Vẽ đường giá trị loss trên tập train qua từng epoch (đường vẽ màu đỏ)

plt.subplot(1, 2, 2) # Khởi tạo khung ảnh cho val loss
plt.xlabel('Epochs') # Hiển thị tên trục hoành là 'Epochs'
plt.ylabel('Loss') # Hiển thị tên trục tung là 'Loss'
plt.title('Validation loss') # Hiển thị title của khung ảnh hiện tại là 'Validation loss'
plt.plot(val_loss, color='orange') # Vẽ đường giá trị loss trên tập val qua từng epoch (đường vẽ màu đỏ)

plt.show() # Hiển thị 2 khung ảnh nhỏ

# %%
def plot_difference(y, pred):
    plt.figure(figsize=(20, 6))
    times = range(len(y))
    y_to_plot = y.flatten()
    pred_to_plot = pred.flatten()

    plt.plot(times, y_to_plot, color='steelblue', marker='o', label='True value')
    plt.plot(times, pred_to_plot, color='orangered', marker='X', label='Prediction')

    plt.title('Adj Closing Price per day')
    plt.xlabel('Date')
    plt.ylabel('Adj Close Price')
    plt.legend()
    plt.show()

plot_difference(y_test[:300], model.predict(X_test[:300], verbose=0))
