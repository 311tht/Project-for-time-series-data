# %% [markdown]
# ## **0. Tải bộ dữ liệu**

# %%
# https://drive.google.com/file/d/1FC2P-NC8q_6cAqYIAkV4mBH5MCF1c-oc/view?usp=share_link
# !gdown --id 1FC2P-NC8q_6cAqYIAkV4mBH5MCF1c-oc
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1FC2P-NC8q_6cAqYIAkV4mBH5MCF1c-oc
# To: /content/tesla_stock_price.zip
# 100% 34.1k/34.1k [00:00<00:00, 46.1MB/s]

# %%
# !unzip './tesla_stock_price.zip'
# Out:
# Archive:  ./tesla_stock_price.zip
#   inflating: tesla_stock.csv

# %% [markdown]
# ## **1. Import các thư viện cần thiết**

# %%
import os   
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

from sklearn.model_selection import train_test_split

RANDOM_SEED = 1
tf.random.set_seed(RANDOM_SEED)

# %% [markdown]
# ## **2. Trực quan hóa dữ liệu**

# %%
dataset_filepath = './tesla_stock.csv' # Khai báo đường dẫn đến file .csv của bộ dữ liệu
df = pd.read_csv(dataset_filepath, index_col=0) # Đọc file .csv thành DataFrame
df
# Out:
#                  Open        High         Low       Close    Volume  \
# Date
# 6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 7/1/2010    25.000000   25.920000   20.270000   21.959999   8218800
# 7/2/2010    23.000000   23.100000   18.709999   19.200001   5139800
# 7/6/2010    20.000000   20.000000   15.830000   16.110001   6866900
# ...               ...         ...         ...         ...       ...
# 3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#             Adj Close
# Date
# 6/29/2010   23.889999
# 6/30/2010   23.830000
# 7/1/2010    21.959999
# 7/2/2010    19.200001
# 7/6/2010    16.110001
# ...               ...
# 3/13/2017  246.169998
# 3/14/2017  258.000000
# 3/15/2017  255.729996
# 3/16/2017  262.049988
# 3/17/2017  261.500000
#
# [1692 rows x 6 columns]

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.215000    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1692 entries, 6/29/2010 to 3/17/2017
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1692 non-null   float64
#  1   High       1692 non-null   float64
#  2   Low        1692 non-null   float64
#  3   Close      1692 non-null   float64
#  4   Volume     1692 non-null   int64
#  5   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 92.5+ KB

# %%
plt.figure(figsize=(10, 5))
df['Adj Close'].plot()
plt.title('Adjusted Closing Price of Tesla Stock')
plt.xlabel('Date')
plt.ylabel('Adj Closing Price')
plt.show()

# %%
plt.figure(figsize=(10, 5))
df['Volume'].plot()
plt.title('Volume over day of Tesla Stock')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.show()

# %% [markdown]
# ## **3. Chuẩn bị dữ liệu**

# %%
# Khai báo hàm Windowing (dùng để tạo các cặp X, y cho time series data)
def slicing_window(df, df_start_idx, df_end_idx, input_size, label_size, offset, label_name):
    features = [] # Khai báo list dùng để lưu trữ các X
    labels = [] # Khai báo list dùng để lưu trữ các y

    # Nếu df_end_idx = chỉ mục cuối cùng bảng dữ liệu, cần phải dời xuống 1 khoảng = window size 
    if df_end_idx == None:
        df_end_idx = len(df) - label_size - offset

    df_start_idx = df_start_idx + input_size + offset

    # Duyệt qua từng mẫu dữ liệu
    for idx in range(df_start_idx, df_end_idx):
        feature_start_idx = idx - input_size - offset
        feature_end_idx = feature_start_idx + input_size

        label_start_idx = idx - 1
        label_end_idx = label_start_idx + label_size

        feature = df[feature_start_idx:feature_end_idx] # Lấy X
        label = df[label_name][label_start_idx:label_end_idx] # Lấy y

        features.append(feature) 
        labels.append(label)

    # Chuyển list thành np.ndarrray
    features = np.array(features)
    labels = np.array(labels)

    return features, labels

# %%
INPUT_SIZE = 30 
LABEL_SIZE = 1
OFFSET = 1
BATCH_SIZE = 64
TARGET_NAME = 'Adj Close'

# %%
dataset_length = len(df) # Số lượng mẫu dữ liệu trong DataFrame
TRAIN_SIZE = 0.7 # Tỉ lệ kích thước tập train
VAL_SIZE = 0.2 # Tỉ lệ kích thước tập val
# Đổi tỉ lệ thành chỉ mục
TRAIN_END_IDX = int(TRAIN_SIZE * dataset_length) 
VAL_END_IDX = int(VAL_SIZE * dataset_length) + TRAIN_END_IDX

# Khởi tạo X, y cho tập train
X_train, y_train = slicing_window(df, 
                                  df_start_idx=0,
                                  df_end_idx=TRAIN_END_IDX,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET,
                                  label_name=TARGET_NAME)

# Khởi tạo X, y cho tập val
X_val, y_val = slicing_window(df, 
                                  df_start_idx=TRAIN_END_IDX,
                                  df_end_idx=VAL_END_IDX,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET,
                                  label_name=TARGET_NAME)

# Khởi tạo X, y cho tập test
X_test, y_test = slicing_window(df, 
                                  df_start_idx=VAL_END_IDX,
                                  df_end_idx=None,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET,
                                  label_name=TARGET_NAME)

# %%
# Khởi tạo tf.data.Dataset
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(BATCH_SIZE)
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(BATCH_SIZE)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE)

# %%
# Cấu hình các tham số tối ưu cho việc đọc dữ liệu
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## **4. Xây dựng mô hình**

# %%
# Khai báo normalization layer
normalize_layer = tf.keras.layers.Normalization()
normalize_layer.adapt(np.vstack((X_train, X_val, X_test)))

# %%
# Xây dựng hàm khởi tạo model
def build_model(input_shape, output_size):
    model = tf.keras.Sequential([
        # Input layer 
        tf.keras.Input(shape=input_shape, name='input_layer'), 

        normalize_layer,

        # BiLSTM Layer 1 
        tf.keras.layers.Bidirectional(tf.keras.layers.SimpleRNN(128, 
                                                           return_sequences=True, 
                                                           kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)),
                                      name='bilstm_layer_1'), 

        # BiLSTM Layer 2
        tf.keras.layers.Bidirectional(tf.keras.layers.SimpleRNN(64, 
                                                           return_sequences=True, 
                                                           kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)),
                                      name='bilstm_layer_2'),          

        # BiLSTM Layer 3
        tf.keras.layers.Bidirectional(tf.keras.layers.SimpleRNN(32, 
                                                           return_sequences=False, 
                                                           kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)),
                                      name='bilstm_layer_3'),   
                            
        # FC Layer 1
        tf.keras.layers.Dense(32,
                              activation='relu',
                              kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED),
                              name='fc_layer_1'
                              ),
        
        # Output Layer
        tf.keras.layers.Dense(output_size, 
                              kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED),
                              name='output_layer') 
    ],
    name='bilstm_model')

    return model

# %%
INPUT_SHAPE = X_train.shape[-2:] 
model = build_model(INPUT_SHAPE,
                    LABEL_SIZE)
model.summary()
# Out:
# Model: "bilstm_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 30, 6)            13
#  n)
#
#  bilstm_layer_1 (Bidirection  (None, 30, 256)          34560
#  al)
#
#  bilstm_layer_2 (Bidirection  (None, 30, 128)          41088
#  al)
#
#  bilstm_layer_3 (Bidirection  (None, 64)               10304
#  al)
#
#  fc_layer_1 (Dense)          (None, 32)                2080
#
#  output_layer (Dense)        (None, 1)                 33
#
# =================================================================
# Total params: 88,078
# Trainable params: 88,065
# Non-trainable params: 13
# _________________________________________________________________

# %% [markdown]
# ## **5. Cấu hình mô hình**

# %%
# Khai báo một số giá trị siêu tham số
EPOCHS = 500
LR = 1e-3

# %%
# Cấu hình một số thông tin cho mô hình
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR), # Sử dụng optimizer Adam
    loss=tf.keras.losses.MeanSquaredError(), # Sử dụng hàm loss Mean Squared Error
)

# %% [markdown]
# ## **6. Huấn luyện mô hình**

# %%
history = model.fit(train_ds, 
                    validation_data=val_ds,
                    epochs=EPOCHS)
# Out:
# Epoch 1/500
# 19/19 [==============================] - 18s 468ms/step - loss: 16330.6729 - val_loss: 53309.9141
# Epoch 2/500
# 19/19 [==============================] - 5s 284ms/step - loss: 15904.9102 - val_loss: 51937.1406
# Epoch 3/500
# 19/19 [==============================] - 3s 142ms/step - loss: 15242.3730 - val_loss: 48643.6875
# Epoch 4/500
# 19/19 [==============================] - 3s 141ms/step - loss: 14288.8203 - val_loss: 46775.3320
# Epoch 5/500
# 19/19 [==============================] - 3s 139ms/step - loss: 13618.2676 - val_loss: 44800.0703
# Epoch 6/500
# 19/19 [==============================] - 3s 145ms/step - loss: 12927.9111 - val_loss: 42734.5391
# Epoch 7/500
# 19/19 [==============================] - 3s 144ms/step - loss: 12213.3389 - val_loss: 40596.2734
# Epoch 8/500
# 19/19 [==============================] - 3s 142ms/step - loss: 11477.4414 - val_loss: 38395.5508
# Epoch 9/500
# 19/19 [==============================] - 3s 145ms/step - loss: 10725.1768 - val_loss: 36146.1289
# Epoch 10/500
# 19/19 [==============================] - 3s 140ms/step - loss: 9961.1191 - val_loss: 33864.2070
# Epoch 11/500
# 19/19 [==============================] - 3s 148ms/step - loss: 9192.8477 - val_loss: 31568.4961
# Epoch 12/500
# 19/19 [==============================] - 3s 145ms/step - loss: 8428.8789 - val_loss: 29279.2441
# Epoch 13/500
# 19/19 [==============================] - 3s 144ms/step - loss: 7678.1162 - val_loss: 27017.1484
# Epoch 14/500
# 19/19 [==============================] - 3s 142ms/step - loss: 6949.1133 - val_loss: 24802.5488
# Epoch 15/500
# 19/19 [==============================] - 3s 146ms/step - loss: 6249.8701 - val_loss: 22654.7480
# Epoch 16/500
# 19/19 [==============================] - 3s 144ms/step - loss: 5587.5059 - val_loss: 20591.4375
# Epoch 17/500
# 19/19 [==============================] - 3s 142ms/step - loss: 4968.0020 - val_loss: 18628.1875
# Epoch 18/500
# 19/19 [==============================] - 3s 142ms/step - loss: 4396.0068 - val_loss: 16778.0527
# Epoch 19/500
# 19/19 [==============================] - 3s 139ms/step - loss: 3874.7024 - val_loss: 15051.2822
# Epoch 20/500
# 19/19 [==============================] - 3s 139ms/step - loss: 3405.7334 - val_loss: 13455.0879
# Epoch 21/500
# 19/19 [==============================] - 3s 147ms/step - loss: 2989.1702 - val_loss: 11993.5645
# Epoch 22/500
# 19/19 [==============================] - 3s 148ms/step - loss: 2623.7075 - val_loss: 10667.5723
# Epoch 23/500
# 19/19 [==============================] - 3s 175ms/step - loss: 2307.8372 - val_loss: 9475.9375
# Epoch 24/500
# 19/19 [==============================] - 4s 206ms/step - loss: 2038.5977 - val_loss: 8414.3926
# Epoch 25/500
# 19/19 [==============================] - 3s 152ms/step - loss: 1811.7928 - val_loss: 7477.8667
# Epoch 26/500
# 19/19 [==============================] - 3s 147ms/step - loss: 1622.0563 - val_loss: 6656.5874
# Epoch 27/500
# 19/19 [==============================] - 3s 143ms/step - loss: 1432.2051 - val_loss: 5926.3345
# Epoch 28/500
# 19/19 [==============================] - 3s 146ms/step - loss: 1268.4106 - val_loss: 5280.3389
# Epoch 29/500
# 19/19 [==============================] - 3s 144ms/step - loss: 1135.7717 - val_loss: 4707.5684
# Epoch 30/500
# 19/19 [==============================] - 3s 140ms/step - loss: 1034.1992 - val_loss: 4218.6279
# Epoch 31/500
# 19/19 [==============================] - 3s 144ms/step - loss: 956.5181 - val_loss: 3801.9729
# Epoch 32/500
# 19/19 [==============================] - 3s 147ms/step - loss: 895.2368 - val_loss: 3449.6545
# Epoch 33/500
# 19/19 [==============================] - 3s 144ms/step - loss: 845.7892 - val_loss: 3150.6804
# Epoch 34/500
# 19/19 [==============================] - 3s 143ms/step - loss: 796.3815 - val_loss: 2886.8687
# Epoch 35/500
# 19/19 [==============================] - 3s 143ms/step - loss: 771.6779 - val_loss: 2668.4829
# Epoch 36/500
# 19/19 [==============================] - 3s 141ms/step - loss: 668.3140 - val_loss: 2445.5747
# Epoch 37/500
# 19/19 [==============================] - 3s 148ms/step - loss: 3730.5186 - val_loss: 42688.9336
# Epoch 38/500
# 19/19 [==============================] - 3s 144ms/step - loss: 15216.8857 - val_loss: 42839.0586
# Epoch 39/500
# 19/19 [==============================] - 3s 141ms/step - loss: 12062.0996 - val_loss: 40072.7188
# Epoch 40/500
# 19/19 [==============================] - 3s 144ms/step - loss: 10337.1719 - val_loss: 37452.7773
# Epoch 41/500
# 19/19 [==============================] - 3s 143ms/step - loss: 8781.3789 - val_loss: 35060.6055
# Epoch 42/500
# 19/19 [==============================] - 3s 142ms/step - loss: 8082.4521 - val_loss: 33097.1523
# Epoch 43/500
# 19/19 [==============================] - 3s 143ms/step - loss: 7590.2148 - val_loss: 31247.7539
# Epoch 44/500
# 19/19 [==============================] - 3s 144ms/step - loss: 7138.8345 - val_loss: 29442.7500
# Epoch 45/500
# 19/19 [==============================] - 3s 141ms/step - loss: 6737.3091 - val_loss: 27819.3145
# Epoch 46/500
# 19/19 [==============================] - 3s 146ms/step - loss: 6208.8799 - val_loss: 26171.5547
# Epoch 47/500
# 19/19 [==============================] - 3s 143ms/step - loss: 5922.1455 - val_loss: 24742.8730
# Epoch 48/500
# 19/19 [==============================] - 3s 149ms/step - loss: 5472.9365 - val_loss: 23248.9727
# Epoch 49/500
# 19/19 [==============================] - 3s 150ms/step - loss: 5094.6377 - val_loss: 21880.1582
# Epoch 50/500
# 19/19 [==============================] - 3s 148ms/step - loss: 4794.3442 - val_loss: 20414.0469
# Epoch 51/500
# 19/19 [==============================] - 3s 147ms/step - loss: 4513.3325 - val_loss: 19218.3438
# Epoch 52/500
# 19/19 [==============================] - 4s 209ms/step - loss: 4244.4961 - val_loss: 17898.7051
# Epoch 53/500
# 19/19 [==============================] - 3s 144ms/step - loss: 3827.1235 - val_loss: 16498.9824
# Epoch 54/500
# 19/19 [==============================] - 3s 137ms/step - loss: 3510.1702 - val_loss: 15255.1084
# Epoch 55/500
# 19/19 [==============================] - 3s 138ms/step - loss: 3210.1221 - val_loss: 13914.2354
# Epoch 56/500
# 19/19 [==============================] - 3s 140ms/step - loss: 2935.5530 - val_loss: 12792.0000
# Epoch 57/500
# 19/19 [==============================] - 3s 145ms/step - loss: 2669.7266 - val_loss: 11645.0889
# Epoch 58/500
# 19/19 [==============================] - 3s 140ms/step - loss: 2431.5767 - val_loss: 10591.7383
# Epoch 59/500
# 19/19 [==============================] - 3s 145ms/step - loss: 2194.9084 - val_loss: 9594.4111
# Epoch 60/500
# 19/19 [==============================] - 3s 141ms/step - loss: 1965.2246 - val_loss: 8675.6201
# Epoch 61/500
# 19/19 [==============================] - 3s 142ms/step - loss: 1763.3436 - val_loss: 7831.1021
# Epoch 62/500
# 19/19 [==============================] - 3s 143ms/step - loss: 1577.0123 - val_loss: 7060.4658
# Epoch 63/500
# 19/19 [==============================] - 3s 143ms/step - loss: 1414.1467 - val_loss: 6346.6826
# Epoch 64/500
# 19/19 [==============================] - 3s 145ms/step - loss: 1268.1371 - val_loss: 5715.7881
# Epoch 65/500
# 19/19 [==============================] - 3s 145ms/step - loss: 1139.2120 - val_loss: 5145.2783
# Epoch 66/500
# 19/19 [==============================] - 3s 140ms/step - loss: 1023.1286 - val_loss: 4630.8682
# Epoch 67/500
# 19/19 [==============================] - 3s 139ms/step - loss: 923.2735 - val_loss: 4169.8813
# Epoch 68/500
# 19/19 [==============================] - 3s 145ms/step - loss: 832.4094 - val_loss: 3756.2241
# Epoch 69/500
# 19/19 [==============================] - 3s 145ms/step - loss: 758.9963 - val_loss: 3389.1255
# Epoch 70/500
# 19/19 [==============================] - 3s 144ms/step - loss: 686.1358 - val_loss: 3056.0247
# Epoch 71/500
# 19/19 [==============================] - 3s 143ms/step - loss: 626.5307 - val_loss: 2759.1846
# Epoch 72/500
# 19/19 [==============================] - 3s 140ms/step - loss: 567.5601 - val_loss: 2501.8848
# Epoch 73/500
# 19/19 [==============================] - 3s 145ms/step - loss: 526.3950 - val_loss: 2274.7551
# Epoch 74/500
# 19/19 [==============================] - 3s 148ms/step - loss: 471.6479 - val_loss: 2078.6272
# Epoch 75/500
# 19/19 [==============================] - 3s 140ms/step - loss: 435.4363 - val_loss: 1904.2190
# Epoch 76/500
# 19/19 [==============================] - 3s 138ms/step - loss: 402.5789 - val_loss: 1752.9083
# Epoch 77/500
# 19/19 [==============================] - 3s 141ms/step - loss: 376.4576 - val_loss: 1629.0216
# Epoch 78/500
# 19/19 [==============================] - 3s 143ms/step - loss: 352.7488 - val_loss: 1513.4498
# Epoch 79/500
# 19/19 [==============================] - 3s 137ms/step - loss: 333.5367 - val_loss: 1420.2693
# Epoch 80/500
# 19/19 [==============================] - 3s 142ms/step - loss: 316.0624 - val_loss: 1332.2827
# Epoch 81/500
# 19/19 [==============================] - 3s 152ms/step - loss: 302.0318 - val_loss: 1253.0645
# Epoch 82/500
# 19/19 [==============================] - 3s 143ms/step - loss: 287.7882 - val_loss: 1185.1890
# Epoch 83/500
# 19/19 [==============================] - 3s 142ms/step - loss: 277.4785 - val_loss: 1132.8438
# Epoch 84/500
# 19/19 [==============================] - 3s 141ms/step - loss: 266.4074 - val_loss: 1060.4714
# Epoch 85/500
# 19/19 [==============================] - 3s 141ms/step - loss: 258.9742 - val_loss: 1016.5698
# Epoch 86/500
# 19/19 [==============================] - 3s 140ms/step - loss: 249.9359 - val_loss: 939.6716
# Epoch 87/500
# 19/19 [==============================] - 3s 139ms/step - loss: 239.8230 - val_loss: 913.7977
# Epoch 88/500
# 19/19 [==============================] - 3s 146ms/step - loss: 226.1122 - val_loss: 853.3104
# Epoch 89/500
# 19/19 [==============================] - 3s 143ms/step - loss: 224.5978 - val_loss: 827.9583
# Epoch 90/500
# 19/19 [==============================] - 3s 146ms/step - loss: 237.6033 - val_loss: 786.5255
# Epoch 91/500
# 19/19 [==============================] - 3s 145ms/step - loss: 227.0733 - val_loss: 753.2455
# Epoch 92/500
# 19/19 [==============================] - 3s 142ms/step - loss: 225.7224 - val_loss: 720.0237
# Epoch 93/500
# 19/19 [==============================] - 3s 145ms/step - loss: 219.9047 - val_loss: 694.2874
# Epoch 94/500
# 19/19 [==============================] - 3s 141ms/step - loss: 217.6675 - val_loss: 626.3405
# Epoch 95/500
# 19/19 [==============================] - 3s 141ms/step - loss: 212.0200 - val_loss: 602.1835
# Epoch 96/500
# 19/19 [==============================] - 3s 144ms/step - loss: 185.5979 - val_loss: 570.1256
# Epoch 97/500
# 19/19 [==============================] - 3s 143ms/step - loss: 174.4272 - val_loss: 520.2195
# Epoch 98/500
# 19/19 [==============================] - 3s 143ms/step - loss: 158.3891 - val_loss: 512.8818
# Epoch 99/500
# 19/19 [==============================] - 3s 141ms/step - loss: 146.8531 - val_loss: 478.6041
# Epoch 100/500
# 19/19 [==============================] - 3s 139ms/step - loss: 136.7988 - val_loss: 442.2799
# Epoch 101/500
# 19/19 [==============================] - 3s 142ms/step - loss: 138.8989 - val_loss: 429.3758
# Epoch 102/500
# 19/19 [==============================] - 3s 144ms/step - loss: 152.3731 - val_loss: 530.5280
# Epoch 103/500
# 19/19 [==============================] - 3s 146ms/step - loss: 285.5749 - val_loss: 965.6996
# Epoch 104/500
# 19/19 [==============================] - 3s 139ms/step - loss: 380.7577 - val_loss: 777.5131
# Epoch 105/500
# 19/19 [==============================] - 3s 139ms/step - loss: 288.5948 - val_loss: 616.0243
# Epoch 106/500
# 19/19 [==============================] - 3s 145ms/step - loss: 247.0328 - val_loss: 547.0684
# Epoch 107/500
# 19/19 [==============================] - 3s 148ms/step - loss: 166.8112 - val_loss: 478.6108
# Epoch 108/500
# 19/19 [==============================] - 3s 146ms/step - loss: 144.3247 - val_loss: 372.8818
# Epoch 109/500
# 19/19 [==============================] - 3s 145ms/step - loss: 123.4170 - val_loss: 312.4127
# Epoch 110/500
# 19/19 [==============================] - 3s 145ms/step - loss: 92.6763 - val_loss: 277.4853
# Epoch 111/500
# 19/19 [==============================] - 3s 167ms/step - loss: 104.2103 - val_loss: 250.1334
# Epoch 112/500
# 19/19 [==============================] - 3s 176ms/step - loss: 138.8887 - val_loss: 269.0062
# Epoch 113/500
# 19/19 [==============================] - 3s 145ms/step - loss: 103.6226 - val_loss: 243.7442
# Epoch 114/500
# 19/19 [==============================] - 3s 152ms/step - loss: 92.0715 - val_loss: 271.7711
# Epoch 115/500
# 19/19 [==============================] - 3s 141ms/step - loss: 151.0489 - val_loss: 260.2160
# Epoch 116/500
# 19/19 [==============================] - 3s 139ms/step - loss: 118.8431 - val_loss: 269.6834
# Epoch 117/500
# 19/19 [==============================] - 3s 140ms/step - loss: 188.5029 - val_loss: 230.1205
# Epoch 118/500
# 19/19 [==============================] - 3s 140ms/step - loss: 154.0679 - val_loss: 282.7246
# Epoch 119/500
# 19/19 [==============================] - 3s 139ms/step - loss: 189.6930 - val_loss: 312.0601
# Epoch 120/500
# 19/19 [==============================] - 3s 144ms/step - loss: 123.9518 - val_loss: 411.0636
# Epoch 121/500
# 19/19 [==============================] - 3s 143ms/step - loss: 120.4912 - val_loss: 218.7452
# Epoch 122/500
# 19/19 [==============================] - 3s 148ms/step - loss: 95.5527 - val_loss: 206.5076
# Epoch 123/500
# 19/19 [==============================] - 3s 141ms/step - loss: 125.0604 - val_loss: 190.8882
# Epoch 124/500
# 19/19 [==============================] - 3s 142ms/step - loss: 98.1994 - val_loss: 193.5681
# Epoch 125/500
# 19/19 [==============================] - 3s 144ms/step - loss: 142.9337 - val_loss: 210.0993
# Epoch 126/500
# 19/19 [==============================] - 3s 140ms/step - loss: 128.5378 - val_loss: 184.2966
# Epoch 127/500
# 19/19 [==============================] - 3s 141ms/step - loss: 164.6922 - val_loss: 227.7226
# Epoch 128/500
# 19/19 [==============================] - 3s 145ms/step - loss: 144.2463 - val_loss: 205.3324
# Epoch 129/500
# 19/19 [==============================] - 3s 146ms/step - loss: 166.4010 - val_loss: 228.3349
# Epoch 130/500
# 19/19 [==============================] - 3s 142ms/step - loss: 103.1925 - val_loss: 214.3876
# Epoch 131/500
# 19/19 [==============================] - 3s 143ms/step - loss: 1160.8730 - val_loss: 8608.1758
# Epoch 132/500
# 19/19 [==============================] - 3s 142ms/step - loss: 556.5178 - val_loss: 3006.3052
# Epoch 133/500
# 19/19 [==============================] - 3s 143ms/step - loss: 902.8108 - val_loss: 644.2596
# Epoch 134/500
# 19/19 [==============================] - 3s 142ms/step - loss: 304.9457 - val_loss: 429.0018
# Epoch 135/500
# 19/19 [==============================] - 3s 143ms/step - loss: 235.6860 - val_loss: 437.4998
# Epoch 136/500
# 19/19 [==============================] - 3s 147ms/step - loss: 270.6201 - val_loss: 388.6930
# Epoch 137/500
# 19/19 [==============================] - 3s 146ms/step - loss: 175.8393 - val_loss: 363.8235
# Epoch 138/500
# 19/19 [==============================] - 3s 142ms/step - loss: 140.7146 - val_loss: 330.1913
# Epoch 139/500
# 19/19 [==============================] - 3s 151ms/step - loss: 158.3325 - val_loss: 260.8707
# Epoch 140/500
# 19/19 [==============================] - 3s 147ms/step - loss: 138.6049 - val_loss: 225.8104
# Epoch 141/500
# 19/19 [==============================] - 3s 137ms/step - loss: 199.0294 - val_loss: 258.5176
# Epoch 142/500
# 19/19 [==============================] - 3s 143ms/step - loss: 171.6808 - val_loss: 311.4840
# Epoch 143/500
# 19/19 [==============================] - 3s 142ms/step - loss: 237.4849 - val_loss: 385.3309
# Epoch 144/500
# 19/19 [==============================] - 3s 140ms/step - loss: 132.5756 - val_loss: 300.9689
# Epoch 145/500
# 19/19 [==============================] - 3s 140ms/step - loss: 129.7683 - val_loss: 294.0351
# Epoch 146/500
# 19/19 [==============================] - 3s 141ms/step - loss: 90.2880 - val_loss: 284.7950
# Epoch 147/500
# 19/19 [==============================] - 3s 142ms/step - loss: 79.0293 - val_loss: 251.9402
# Epoch 148/500
# 19/19 [==============================] - 3s 142ms/step - loss: 70.8732 - val_loss: 237.0479
# Epoch 149/500
# 19/19 [==============================] - 3s 142ms/step - loss: 67.1189 - val_loss: 222.7325
# Epoch 150/500
# 19/19 [==============================] - 3s 145ms/step - loss: 66.0236 - val_loss: 196.8707
# Epoch 151/500
# 19/19 [==============================] - 3s 142ms/step - loss: 55.2815 - val_loss: 155.9955
# Epoch 152/500
# 19/19 [==============================] - 3s 142ms/step - loss: 42.6613 - val_loss: 97.7071
# Epoch 153/500
# 19/19 [==============================] - 3s 142ms/step - loss: 48.0636 - val_loss: 94.3569
# Epoch 154/500
# 19/19 [==============================] - 3s 141ms/step - loss: 56.9081 - val_loss: 97.2231
# Epoch 155/500
# 19/19 [==============================] - 3s 142ms/step - loss: 38.9005 - val_loss: 87.3299
# Epoch 156/500
# 19/19 [==============================] - 3s 138ms/step - loss: 39.7093 - val_loss: 87.7583
# Epoch 157/500
# 19/19 [==============================] - 5s 248ms/step - loss: 87.4347 - val_loss: 101.7699
# Epoch 158/500
# 19/19 [==============================] - 6s 313ms/step - loss: 59.1049 - val_loss: 89.0705
# Epoch 159/500
# 19/19 [==============================] - 3s 144ms/step - loss: 92.0099 - val_loss: 85.8754
# Epoch 160/500
# 19/19 [==============================] - 3s 143ms/step - loss: 68.2366 - val_loss: 89.5357
# Epoch 161/500
# 19/19 [==============================] - 3s 140ms/step - loss: 107.9091 - val_loss: 97.0508
# Epoch 162/500
# 19/19 [==============================] - 3s 149ms/step - loss: 90.5167 - val_loss: 99.4722
# Epoch 163/500
# 19/19 [==============================] - 3s 141ms/step - loss: 128.1727 - val_loss: 116.7526
# Epoch 164/500
# 19/19 [==============================] - 3s 140ms/step - loss: 111.0475 - val_loss: 125.4544
# Epoch 165/500
# 19/19 [==============================] - 3s 137ms/step - loss: 127.5755 - val_loss: 125.0167
# Epoch 166/500
# 19/19 [==============================] - 3s 142ms/step - loss: 95.6217 - val_loss: 173.8525
# Epoch 167/500
# 19/19 [==============================] - 3s 140ms/step - loss: 90.0134 - val_loss: 143.4541
# Epoch 168/500
# 19/19 [==============================] - 3s 142ms/step - loss: 56.6517 - val_loss: 90.6278
# Epoch 169/500
# 19/19 [==============================] - 3s 137ms/step - loss: 54.0238 - val_loss: 75.8217
# Epoch 170/500
# 19/19 [==============================] - 3s 142ms/step - loss: 45.9296 - val_loss: 78.1851
# Epoch 171/500
# 19/19 [==============================] - 3s 139ms/step - loss: 35.8549 - val_loss: 75.1226
# Epoch 172/500
# 19/19 [==============================] - 3s 138ms/step - loss: 59.7033 - val_loss: 77.2034
# Epoch 173/500
# 19/19 [==============================] - 3s 138ms/step - loss: 35.9234 - val_loss: 71.0337
# Epoch 174/500
# 19/19 [==============================] - 3s 162ms/step - loss: 42.2387 - val_loss: 71.9592
# Epoch 175/500
# 19/19 [==============================] - 3s 162ms/step - loss: 61.5941 - val_loss: 79.3067
# Epoch 176/500
# 19/19 [==============================] - 3s 142ms/step - loss: 36.2377 - val_loss: 69.0026
# Epoch 177/500
# 19/19 [==============================] - 3s 140ms/step - loss: 52.2721 - val_loss: 66.9303
# Epoch 178/500
# 19/19 [==============================] - 3s 142ms/step - loss: 41.5457 - val_loss: 67.4395
# Epoch 179/500
# 19/19 [==============================] - 3s 137ms/step - loss: 36.5260 - val_loss: 68.8941
# Epoch 180/500
# 19/19 [==============================] - 3s 135ms/step - loss: 43.3169 - val_loss: 63.9052
# Epoch 181/500
# 19/19 [==============================] - 3s 137ms/step - loss: 33.5436 - val_loss: 63.4786
# Epoch 182/500
# 19/19 [==============================] - 3s 141ms/step - loss: 26.8802 - val_loss: 59.7862
# Epoch 183/500
# 19/19 [==============================] - 3s 136ms/step - loss: 25.1893 - val_loss: 58.7963
# Epoch 184/500
# 19/19 [==============================] - 3s 134ms/step - loss: 25.0954 - val_loss: 58.0139
# Epoch 185/500
# 19/19 [==============================] - 3s 145ms/step - loss: 26.8851 - val_loss: 58.6603
# Epoch 186/500
# 19/19 [==============================] - 3s 146ms/step - loss: 32.6534 - val_loss: 59.8104
# Epoch 187/500
# 19/19 [==============================] - 3s 143ms/step - loss: 48.9324 - val_loss: 62.1705
# Epoch 188/500
# 19/19 [==============================] - 3s 146ms/step - loss: 57.3068 - val_loss: 60.1152
# Epoch 189/500
# 19/19 [==============================] - 3s 144ms/step - loss: 29.1778 - val_loss: 58.2723
# Epoch 190/500
# 19/19 [==============================] - 3s 144ms/step - loss: 34.1456 - val_loss: 57.2844
# Epoch 191/500
# 19/19 [==============================] - 3s 147ms/step - loss: 80.6502 - val_loss: 67.1069
# Epoch 192/500
# 19/19 [==============================] - 3s 146ms/step - loss: 50.2748 - val_loss: 61.6550
# Epoch 193/500
# 19/19 [==============================] - 3s 141ms/step - loss: 70.1130 - val_loss: 58.1491
# Epoch 194/500
# 19/19 [==============================] - 3s 141ms/step - loss: 62.3342 - val_loss: 57.6022
# Epoch 195/500
# 19/19 [==============================] - 3s 143ms/step - loss: 83.0187 - val_loss: 56.3660
# Epoch 196/500
# 19/19 [==============================] - 3s 141ms/step - loss: 63.6804 - val_loss: 70.5885
# Epoch 197/500
# 19/19 [==============================] - 3s 142ms/step - loss: 103.3133 - val_loss: 70.2956
# Epoch 198/500
# 19/19 [==============================] - 3s 141ms/step - loss: 83.6896 - val_loss: 75.5036
# Epoch 199/500
# 19/19 [==============================] - 3s 137ms/step - loss: 113.7045 - val_loss: 94.2187
# Epoch 200/500
# 19/19 [==============================] - 3s 138ms/step - loss: 97.2279 - val_loss: 101.0575
# Epoch 201/500
# 19/19 [==============================] - 3s 141ms/step - loss: 97.0823 - val_loss: 80.2373
# Epoch 202/500
# 19/19 [==============================] - 3s 140ms/step - loss: 80.5791 - val_loss: 80.8652
# Epoch 203/500
# 19/19 [==============================] - 3s 138ms/step - loss: 83.5672 - val_loss: 65.5669
# Epoch 204/500
# 19/19 [==============================] - 3s 149ms/step - loss: 56.5364 - val_loss: 90.1493
# Epoch 205/500
# 19/19 [==============================] - 3s 140ms/step - loss: 58.4229 - val_loss: 60.3549
# Epoch 206/500
# 19/19 [==============================] - 3s 147ms/step - loss: 47.3036 - val_loss: 60.9441
# Epoch 207/500
# 19/19 [==============================] - 3s 141ms/step - loss: 45.1262 - val_loss: 54.2005
# Epoch 208/500
# 19/19 [==============================] - 3s 145ms/step - loss: 38.9517 - val_loss: 56.6068
# Epoch 209/500
# 19/19 [==============================] - 3s 143ms/step - loss: 34.1350 - val_loss: 59.1293
# Epoch 210/500
# 19/19 [==============================] - 3s 153ms/step - loss: 61.0921 - val_loss: 66.6018
# Epoch 211/500
# 19/19 [==============================] - 3s 148ms/step - loss: 33.8183 - val_loss: 52.5738
# Epoch 212/500
# 19/19 [==============================] - 3s 144ms/step - loss: 42.0999 - val_loss: 55.2326
# Epoch 213/500
# 19/19 [==============================] - 3s 143ms/step - loss: 49.3948 - val_loss: 61.6113
# Epoch 214/500
# 19/19 [==============================] - 3s 143ms/step - loss: 31.6374 - val_loss: 52.1057
# Epoch 215/500
# 19/19 [==============================] - 3s 143ms/step - loss: 29.2937 - val_loss: 53.6684
# Epoch 216/500
# 19/19 [==============================] - 3s 141ms/step - loss: 47.9280 - val_loss: 51.5463
# Epoch 217/500
# 19/19 [==============================] - 3s 147ms/step - loss: 28.7660 - val_loss: 49.3649
# Epoch 218/500
# 19/19 [==============================] - 4s 203ms/step - loss: 32.5328 - val_loss: 55.3932
# Epoch 219/500
# 19/19 [==============================] - 3s 141ms/step - loss: 49.7766 - val_loss: 50.5632
# Epoch 220/500
# 19/19 [==============================] - 3s 141ms/step - loss: 29.4540 - val_loss: 48.6382
# Epoch 221/500
# 19/19 [==============================] - 3s 140ms/step - loss: 36.9158 - val_loss: 52.7752
# Epoch 222/500
# 19/19 [==============================] - 3s 143ms/step - loss: 41.0196 - val_loss: 48.2661
# Epoch 223/500
# 19/19 [==============================] - 3s 140ms/step - loss: 25.5905 - val_loss: 46.3731
# Epoch 224/500
# 19/19 [==============================] - 3s 140ms/step - loss: 30.5045 - val_loss: 53.7627
# Epoch 225/500
# 19/19 [==============================] - 3s 141ms/step - loss: 48.0881 - val_loss: 46.8216
# Epoch 226/500
# 19/19 [==============================] - 3s 145ms/step - loss: 35.8581 - val_loss: 47.3717
# Epoch 227/500
# 19/19 [==============================] - 3s 139ms/step - loss: 37.1392 - val_loss: 54.8715
# Epoch 228/500
# 19/19 [==============================] - 3s 143ms/step - loss: 47.8833 - val_loss: 48.7373
# Epoch 229/500
# 19/19 [==============================] - 3s 142ms/step - loss: 31.3450 - val_loss: 45.8044
# Epoch 230/500
# 19/19 [==============================] - 3s 141ms/step - loss: 31.0126 - val_loss: 49.6469
# Epoch 231/500
# 19/19 [==============================] - 3s 145ms/step - loss: 35.7158 - val_loss: 52.8426
# Epoch 232/500
# 19/19 [==============================] - 3s 151ms/step - loss: 54.8363 - val_loss: 50.5084
# Epoch 233/500
# 19/19 [==============================] - 3s 141ms/step - loss: 27.3530 - val_loss: 44.3853
# Epoch 234/500
# 19/19 [==============================] - 3s 148ms/step - loss: 32.0171 - val_loss: 47.0550
# Epoch 235/500
# 19/19 [==============================] - 3s 144ms/step - loss: 37.4484 - val_loss: 57.9072
# Epoch 236/500
# 19/19 [==============================] - 3s 141ms/step - loss: 64.1735 - val_loss: 63.9160
# Epoch 237/500
# 19/19 [==============================] - 3s 137ms/step - loss: 28.5281 - val_loss: 46.5462
# Epoch 238/500
# 19/19 [==============================] - 3s 139ms/step - loss: 30.2166 - val_loss: 44.4268
# Epoch 239/500
# 19/19 [==============================] - 3s 139ms/step - loss: 31.7508 - val_loss: 54.3492
# Epoch 240/500
# 19/19 [==============================] - 3s 140ms/step - loss: 50.1281 - val_loss: 51.7707
# Epoch 241/500
# 19/19 [==============================] - 3s 138ms/step - loss: 40.7897 - val_loss: 60.3758
# Epoch 242/500
# 19/19 [==============================] - 3s 140ms/step - loss: 89.1651 - val_loss: 57.9955
# Epoch 243/500
# 19/19 [==============================] - 3s 143ms/step - loss: 63.8470 - val_loss: 78.2685
# Epoch 244/500
# 19/19 [==============================] - 3s 138ms/step - loss: 87.4589 - val_loss: 54.9405
# Epoch 245/500
# 19/19 [==============================] - 3s 142ms/step - loss: 30.0080 - val_loss: 49.5902
# Epoch 246/500
# 19/19 [==============================] - 3s 144ms/step - loss: 26.0131 - val_loss: 51.3409
# Epoch 247/500
# 19/19 [==============================] - 3s 136ms/step - loss: 35.8702 - val_loss: 43.5637
# Epoch 248/500
# 19/19 [==============================] - 3s 137ms/step - loss: 39.3100 - val_loss: 65.9953
# Epoch 249/500
# 19/19 [==============================] - 3s 138ms/step - loss: 78.3016 - val_loss: 55.4568
# Epoch 250/500
# 19/19 [==============================] - 3s 139ms/step - loss: 58.9681 - val_loss: 63.0093
# Epoch 251/500
# 19/19 [==============================] - 3s 137ms/step - loss: 73.0276 - val_loss: 54.8095
# Epoch 252/500
# 19/19 [==============================] - 3s 138ms/step - loss: 43.4412 - val_loss: 60.7051
# Epoch 253/500
# 19/19 [==============================] - 3s 142ms/step - loss: 66.6135 - val_loss: 49.4046
# Epoch 254/500
# 19/19 [==============================] - 3s 138ms/step - loss: 53.5717 - val_loss: 51.5607
# Epoch 255/500
# 19/19 [==============================] - 3s 144ms/step - loss: 30.0650 - val_loss: 46.7994
# Epoch 256/500
# 19/19 [==============================] - 3s 138ms/step - loss: 33.0386 - val_loss: 47.0872
# Epoch 257/500
# 19/19 [==============================] - 3s 144ms/step - loss: 42.6165 - val_loss: 51.1957
# Epoch 258/500
# 19/19 [==============================] - 3s 144ms/step - loss: 24.9731 - val_loss: 48.8853
# Epoch 259/500
# 19/19 [==============================] - 3s 146ms/step - loss: 34.9455 - val_loss: 45.5882
# Epoch 260/500
# 19/19 [==============================] - 3s 150ms/step - loss: 31.3949 - val_loss: 47.7999
# Epoch 261/500
# 19/19 [==============================] - 3s 147ms/step - loss: 33.2500 - val_loss: 44.8623
# Epoch 262/500
# 19/19 [==============================] - 3s 143ms/step - loss: 26.5545 - val_loss: 45.6178
# Epoch 263/500
# 19/19 [==============================] - 3s 143ms/step - loss: 25.0588 - val_loss: 42.5423
# Epoch 264/500
# 19/19 [==============================] - 3s 137ms/step - loss: 21.7456 - val_loss: 44.0420
# Epoch 265/500
# 19/19 [==============================] - 3s 143ms/step - loss: 24.3717 - val_loss: 42.0513
# Epoch 266/500
# 19/19 [==============================] - 3s 142ms/step - loss: 22.1129 - val_loss: 45.4368
# Epoch 267/500
# 19/19 [==============================] - 3s 142ms/step - loss: 29.5810 - val_loss: 42.5834
# Epoch 268/500
# 19/19 [==============================] - 3s 146ms/step - loss: 29.5038 - val_loss: 49.3931
# Epoch 269/500
# 19/19 [==============================] - 3s 144ms/step - loss: 42.3139 - val_loss: 44.9902
# Epoch 270/500
# 19/19 [==============================] - 3s 142ms/step - loss: 30.9076 - val_loss: 45.7792
# Epoch 271/500
# 19/19 [==============================] - 4s 208ms/step - loss: 23.2196 - val_loss: 40.3789
# Epoch 272/500
# 19/19 [==============================] - 3s 141ms/step - loss: 19.4495 - val_loss: 41.6115
# Epoch 273/500
# 19/19 [==============================] - 3s 145ms/step - loss: 20.3461 - val_loss: 40.8548
# Epoch 274/500
# 19/19 [==============================] - 3s 142ms/step - loss: 20.4635 - val_loss: 43.5649
# Epoch 275/500
# 19/19 [==============================] - 3s 136ms/step - loss: 25.5569 - val_loss: 41.2970
# Epoch 276/500
# 19/19 [==============================] - 3s 138ms/step - loss: 22.9423 - val_loss: 48.9631
# Epoch 277/500
# 19/19 [==============================] - 3s 140ms/step - loss: 40.4376 - val_loss: 41.5866
# Epoch 278/500
# 19/19 [==============================] - 3s 141ms/step - loss: 37.4155 - val_loss: 56.4721
# Epoch 279/500
# 19/19 [==============================] - 3s 139ms/step - loss: 54.5918 - val_loss: 44.1603
# Epoch 280/500
# 19/19 [==============================] - 3s 138ms/step - loss: 29.4489 - val_loss: 49.6508
# Epoch 281/500
# 19/19 [==============================] - 3s 138ms/step - loss: 37.3744 - val_loss: 40.5702
# Epoch 282/500
# 19/19 [==============================] - 3s 138ms/step - loss: 39.8846 - val_loss: 55.3142
# Epoch 283/500
# 19/19 [==============================] - 3s 138ms/step - loss: 48.8400 - val_loss: 46.7169
# Epoch 284/500
# 19/19 [==============================] - 3s 142ms/step - loss: 24.8437 - val_loss: 45.7115
# Epoch 285/500
# 19/19 [==============================] - 3s 146ms/step - loss: 29.5516 - val_loss: 42.0704
# Epoch 286/500
# 19/19 [==============================] - 3s 145ms/step - loss: 22.0247 - val_loss: 43.1693
# Epoch 287/500
# 19/19 [==============================] - 3s 145ms/step - loss: 29.0463 - val_loss: 41.6920
# Epoch 288/500
# 19/19 [==============================] - 3s 138ms/step - loss: 23.6212 - val_loss: 46.8246
# Epoch 289/500
# 19/19 [==============================] - 3s 138ms/step - loss: 39.7093 - val_loss: 42.1256
# Epoch 290/500
# 19/19 [==============================] - 3s 141ms/step - loss: 28.3597 - val_loss: 50.5504
# Epoch 291/500
# 19/19 [==============================] - 3s 145ms/step - loss: 50.9714 - val_loss: 45.4142
# Epoch 292/500
# 19/19 [==============================] - 3s 142ms/step - loss: 27.1488 - val_loss: 49.1508
# Epoch 293/500
# 19/19 [==============================] - 3s 143ms/step - loss: 38.8744 - val_loss: 40.0299
# Epoch 294/500
# 19/19 [==============================] - 3s 147ms/step - loss: 27.2189 - val_loss: 48.3079
# Epoch 295/500
# 19/19 [==============================] - 3s 141ms/step - loss: 37.9838 - val_loss: 44.6874
# Epoch 296/500
# 19/19 [==============================] - 3s 144ms/step - loss: 24.6307 - val_loss: 48.6911
# Epoch 297/500
# 19/19 [==============================] - 3s 139ms/step - loss: 38.4099 - val_loss: 41.2344
# Epoch 298/500
# 19/19 [==============================] - 3s 140ms/step - loss: 25.2771 - val_loss: 49.2325
# Epoch 299/500
# 19/19 [==============================] - 3s 144ms/step - loss: 45.1741 - val_loss: 47.7145
# Epoch 300/500
# 19/19 [==============================] - 3s 145ms/step - loss: 25.2267 - val_loss: 48.0997
# Epoch 301/500
# 19/19 [==============================] - 3s 136ms/step - loss: 39.1761 - val_loss: 41.2454
# Epoch 302/500
# 19/19 [==============================] - 3s 142ms/step - loss: 24.8556 - val_loss: 45.1435
# Epoch 303/500
# 19/19 [==============================] - 3s 145ms/step - loss: 33.8600 - val_loss: 40.8523
# Epoch 304/500
# 19/19 [==============================] - 3s 143ms/step - loss: 22.9369 - val_loss: 43.4398
# Epoch 305/500
# 19/19 [==============================] - 3s 138ms/step - loss: 31.6312 - val_loss: 41.8895
# Epoch 306/500
# 19/19 [==============================] - 3s 144ms/step - loss: 22.7547 - val_loss: 45.5795
# Epoch 307/500
# 19/19 [==============================] - 3s 145ms/step - loss: 37.9342 - val_loss: 40.6428
# Epoch 308/500
# 19/19 [==============================] - 3s 138ms/step - loss: 24.6320 - val_loss: 46.9030
# Epoch 309/500
# 19/19 [==============================] - 3s 149ms/step - loss: 40.3952 - val_loss: 43.0668
# Epoch 310/500
# 19/19 [==============================] - 3s 146ms/step - loss: 23.8292 - val_loss: 46.9353
# Epoch 311/500
# 19/19 [==============================] - 3s 142ms/step - loss: 37.5078 - val_loss: 39.2268
# Epoch 312/500
# 19/19 [==============================] - 3s 141ms/step - loss: 24.1586 - val_loss: 45.6880
# Epoch 313/500
# 19/19 [==============================] - 3s 141ms/step - loss: 35.9453 - val_loss: 42.9213
# Epoch 314/500
# 19/19 [==============================] - 3s 144ms/step - loss: 23.3644 - val_loss: 47.6836
# Epoch 315/500
# 19/19 [==============================] - 3s 145ms/step - loss: 41.6006 - val_loss: 40.7638
# Epoch 316/500
# 19/19 [==============================] - 3s 141ms/step - loss: 24.1207 - val_loss: 46.1858
# Epoch 317/500
# 19/19 [==============================] - 3s 144ms/step - loss: 37.3463 - val_loss: 42.6227
# Epoch 318/500
# 19/19 [==============================] - 3s 143ms/step - loss: 22.4089 - val_loss: 45.1392
# Epoch 319/500
# 19/19 [==============================] - 3s 143ms/step - loss: 33.6504 - val_loss: 40.5233
# Epoch 320/500
# 19/19 [==============================] - 3s 141ms/step - loss: 20.5738 - val_loss: 42.9293
# Epoch 321/500
# 19/19 [==============================] - 3s 139ms/step - loss: 28.9709 - val_loss: 41.0170
# Epoch 322/500
# 19/19 [==============================] - 3s 134ms/step - loss: 20.1823 - val_loss: 43.6952
# Epoch 323/500
# 19/19 [==============================] - 3s 145ms/step - loss: 33.6627 - val_loss: 40.5936
# Epoch 324/500
# 19/19 [==============================] - 3s 141ms/step - loss: 21.2308 - val_loss: 44.5531
# Epoch 325/500
# 19/19 [==============================] - 4s 201ms/step - loss: 35.1984 - val_loss: 41.2346
# Epoch 326/500
# 19/19 [==============================] - 3s 143ms/step - loss: 21.4796 - val_loss: 45.3557
# Epoch 327/500
# 19/19 [==============================] - 3s 144ms/step - loss: 36.9875 - val_loss: 39.8647
# Epoch 328/500
# 19/19 [==============================] - 3s 141ms/step - loss: 22.2142 - val_loss: 45.1565
# Epoch 329/500
# 19/19 [==============================] - 3s 137ms/step - loss: 36.5621 - val_loss: 40.2768
# Epoch 330/500
# 19/19 [==============================] - 3s 140ms/step - loss: 26.3629 - val_loss: 48.9651
# Epoch 331/500
# 19/19 [==============================] - 3s 137ms/step - loss: 50.8527 - val_loss: 40.5886
# Epoch 332/500
# 19/19 [==============================] - 3s 140ms/step - loss: 41.8069 - val_loss: 62.6115
# Epoch 333/500
# 19/19 [==============================] - 3s 138ms/step - loss: 122.3779 - val_loss: 68.1707
# Epoch 334/500
# 19/19 [==============================] - 3s 136ms/step - loss: 165.8035 - val_loss: 159.9270
# Epoch 335/500
# 19/19 [==============================] - 3s 141ms/step - loss: 365.1078 - val_loss: 150.1770
# Epoch 336/500
# 19/19 [==============================] - 3s 141ms/step - loss: 345.9542 - val_loss: 208.7972
# Epoch 337/500
# 19/19 [==============================] - 3s 140ms/step - loss: 302.5462 - val_loss: 217.4352
# Epoch 338/500
# 19/19 [==============================] - 3s 142ms/step - loss: 312.8268 - val_loss: 201.7593
# Epoch 339/500
# 19/19 [==============================] - 3s 141ms/step - loss: 278.4730 - val_loss: 209.6492
# Epoch 340/500
# 19/19 [==============================] - 3s 150ms/step - loss: 188.5533 - val_loss: 244.0743
# Epoch 341/500
# 19/19 [==============================] - 3s 137ms/step - loss: 146.0760 - val_loss: 189.2897
# Epoch 342/500
# 19/19 [==============================] - 3s 140ms/step - loss: 149.6181 - val_loss: 208.2195
# Epoch 343/500
# 19/19 [==============================] - 3s 140ms/step - loss: 93.9173 - val_loss: 184.6287
# Epoch 344/500
# 19/19 [==============================] - 3s 145ms/step - loss: 72.2831 - val_loss: 142.2709
# Epoch 345/500
# 19/19 [==============================] - 3s 140ms/step - loss: 67.2132 - val_loss: 133.3951
# Epoch 346/500
# 19/19 [==============================] - 3s 139ms/step - loss: 56.3065 - val_loss: 115.8868
# Epoch 347/500
# 19/19 [==============================] - 3s 139ms/step - loss: 54.2377 - val_loss: 99.0213
# Epoch 348/500
# 19/19 [==============================] - 3s 142ms/step - loss: 44.1514 - val_loss: 101.4082
# Epoch 349/500
# 19/19 [==============================] - 3s 139ms/step - loss: 51.8786 - val_loss: 83.2990
# Epoch 350/500
# 19/19 [==============================] - 3s 137ms/step - loss: 37.7557 - val_loss: 76.1035
# Epoch 351/500
# 19/19 [==============================] - 3s 144ms/step - loss: 35.6896 - val_loss: 74.9149
# Epoch 352/500
# 19/19 [==============================] - 3s 150ms/step - loss: 34.6431 - val_loss: 80.0598
# Epoch 353/500
# 19/19 [==============================] - 3s 140ms/step - loss: 49.1981 - val_loss: 67.6115
# Epoch 354/500
# 19/19 [==============================] - 3s 142ms/step - loss: 39.7821 - val_loss: 64.6110
# Epoch 355/500
# 19/19 [==============================] - 3s 144ms/step - loss: 47.9130 - val_loss: 63.0041
# Epoch 356/500
# 19/19 [==============================] - 3s 145ms/step - loss: 36.1480 - val_loss: 60.2174
# Epoch 357/500
# 19/19 [==============================] - 3s 143ms/step - loss: 37.4379 - val_loss: 58.1142
# Epoch 358/500
# 19/19 [==============================] - 3s 147ms/step - loss: 38.1951 - val_loss: 63.0362
# Epoch 359/500
# 19/19 [==============================] - 3s 146ms/step - loss: 52.5058 - val_loss: 64.5558
# Epoch 360/500
# 19/19 [==============================] - 3s 151ms/step - loss: 57.6383 - val_loss: 78.9267
# Epoch 361/500
# 19/19 [==============================] - 3s 151ms/step - loss: 101.3861 - val_loss: 85.2435
# Epoch 362/500
# 19/19 [==============================] - 3s 150ms/step - loss: 52.1317 - val_loss: 86.8209
# Epoch 363/500
# 19/19 [==============================] - 3s 145ms/step - loss: 74.7717 - val_loss: 65.5180
# Epoch 364/500
# 19/19 [==============================] - 3s 141ms/step - loss: 61.0319 - val_loss: 66.7486
# Epoch 365/500
# 19/19 [==============================] - 3s 139ms/step - loss: 64.9578 - val_loss: 61.9824
# Epoch 366/500
# 19/19 [==============================] - 3s 148ms/step - loss: 54.8848 - val_loss: 75.2759
# Epoch 367/500
# 19/19 [==============================] - 3s 147ms/step - loss: 82.1779 - val_loss: 67.7415
# Epoch 368/500
# 19/19 [==============================] - 3s 154ms/step - loss: 36.9050 - val_loss: 56.2068
# Epoch 369/500
# 19/19 [==============================] - 3s 143ms/step - loss: 49.6359 - val_loss: 62.2720
# Epoch 370/500
# 19/19 [==============================] - 3s 142ms/step - loss: 64.2259 - val_loss: 56.0652
# Epoch 371/500
# 19/19 [==============================] - 3s 142ms/step - loss: 30.4824 - val_loss: 51.3406
# Epoch 372/500
# 19/19 [==============================] - 3s 146ms/step - loss: 36.7003 - val_loss: 67.8777
# Epoch 373/500
# 19/19 [==============================] - 3s 147ms/step - loss: 55.3214 - val_loss: 53.0572
# Epoch 374/500
# 19/19 [==============================] - 3s 146ms/step - loss: 37.5684 - val_loss: 54.4988
# Epoch 375/500
# 19/19 [==============================] - 3s 144ms/step - loss: 36.2728 - val_loss: 45.8155
# Epoch 376/500
# 19/19 [==============================] - 3s 141ms/step - loss: 29.3656 - val_loss: 47.4046
# Epoch 377/500
# 19/19 [==============================] - 3s 140ms/step - loss: 30.1084 - val_loss: 45.9168
# Epoch 378/500
# 19/19 [==============================] - 3s 146ms/step - loss: 30.5730 - val_loss: 51.3343
# Epoch 379/500
# 19/19 [==============================] - 3s 147ms/step - loss: 41.9690 - val_loss: 49.5071
# Epoch 380/500
# 19/19 [==============================] - 3s 147ms/step - loss: 35.1511 - val_loss: 50.1585
# Epoch 381/500
# 19/19 [==============================] - 3s 146ms/step - loss: 62.9850 - val_loss: 67.1405
# Epoch 382/500
# 19/19 [==============================] - 3s 136ms/step - loss: 46.1561 - val_loss: 72.8559
# Epoch 383/500
# 19/19 [==============================] - 4s 203ms/step - loss: 70.8770 - val_loss: 51.2412
# Epoch 384/500
# 19/19 [==============================] - 3s 142ms/step - loss: 33.7831 - val_loss: 59.6658
# Epoch 385/500
# 19/19 [==============================] - 3s 146ms/step - loss: 54.2855 - val_loss: 52.1753
# Epoch 386/500
# 19/19 [==============================] - 3s 146ms/step - loss: 37.1090 - val_loss: 52.7484
# Epoch 387/500
# 19/19 [==============================] - 3s 144ms/step - loss: 33.8735 - val_loss: 46.3835
# Epoch 388/500
# 19/19 [==============================] - 3s 144ms/step - loss: 24.3272 - val_loss: 47.9446
# Epoch 389/500
# 19/19 [==============================] - 3s 142ms/step - loss: 30.2990 - val_loss: 44.5868
# Epoch 390/500
# 19/19 [==============================] - 3s 148ms/step - loss: 26.9953 - val_loss: 51.9212
# Epoch 391/500
# 19/19 [==============================] - 3s 135ms/step - loss: 45.2103 - val_loss: 47.7384
# Epoch 392/500
# 19/19 [==============================] - 3s 140ms/step - loss: 38.3918 - val_loss: 49.3621
# Epoch 393/500
# 19/19 [==============================] - 3s 145ms/step - loss: 34.9694 - val_loss: 44.5183
# Epoch 394/500
# 19/19 [==============================] - 3s 144ms/step - loss: 26.5489 - val_loss: 46.5633
# Epoch 395/500
# 19/19 [==============================] - 3s 141ms/step - loss: 33.7854 - val_loss: 44.8461
# Epoch 396/500
# 19/19 [==============================] - 3s 139ms/step - loss: 29.0338 - val_loss: 52.0375
# Epoch 397/500
# 19/19 [==============================] - 3s 138ms/step - loss: 52.2608 - val_loss: 48.3235
# Epoch 398/500
# 19/19 [==============================] - 3s 143ms/step - loss: 41.7614 - val_loss: 61.3257
# Epoch 399/500
# 19/19 [==============================] - 3s 142ms/step - loss: 59.8166 - val_loss: 52.0319
# Epoch 400/500
# 19/19 [==============================] - 3s 140ms/step - loss: 72.0089 - val_loss: 84.4450
# Epoch 401/500
# 19/19 [==============================] - 3s 151ms/step - loss: 106.6788 - val_loss: 61.5225
# Epoch 402/500
# 19/19 [==============================] - 3s 145ms/step - loss: 79.7425 - val_loss: 55.8423
# Epoch 403/500
# 19/19 [==============================] - 3s 140ms/step - loss: 81.9429 - val_loss: 78.7389
# Epoch 404/500
# 19/19 [==============================] - 3s 140ms/step - loss: 71.2423 - val_loss: 920.4735
# Epoch 405/500
# 19/19 [==============================] - 3s 138ms/step - loss: 171.4709 - val_loss: 2939.7437
# Epoch 406/500
# 19/19 [==============================] - 3s 142ms/step - loss: 491.3347 - val_loss: 776.1744
# Epoch 407/500
# 19/19 [==============================] - 3s 143ms/step - loss: 206.3011 - val_loss: 200.3491
# Epoch 408/500
# 19/19 [==============================] - 3s 143ms/step - loss: 192.5373 - val_loss: 147.9803
# Epoch 409/500
# 19/19 [==============================] - 3s 140ms/step - loss: 154.0450 - val_loss: 100.6563
# Epoch 410/500
# 19/19 [==============================] - 3s 141ms/step - loss: 212.8790 - val_loss: 103.1942
# Epoch 411/500
# 19/19 [==============================] - 3s 145ms/step - loss: 163.7562 - val_loss: 135.9167
# Epoch 412/500
# 19/19 [==============================] - 3s 148ms/step - loss: 130.3469 - val_loss: 146.1339
# Epoch 413/500
# 19/19 [==============================] - 3s 144ms/step - loss: 87.9355 - val_loss: 106.4687
# Epoch 414/500
# 19/19 [==============================] - 3s 144ms/step - loss: 76.6520 - val_loss: 73.8120
# Epoch 415/500
# 19/19 [==============================] - 3s 147ms/step - loss: 61.6260 - val_loss: 63.8787
# Epoch 416/500
# 19/19 [==============================] - 3s 144ms/step - loss: 62.1965 - val_loss: 51.6401
# Epoch 417/500
# 19/19 [==============================] - 3s 137ms/step - loss: 55.5754 - val_loss: 70.7432
# Epoch 418/500
# 19/19 [==============================] - 3s 143ms/step - loss: 58.2009 - val_loss: 49.7984
# Epoch 419/500
# 19/19 [==============================] - 3s 138ms/step - loss: 53.1484 - val_loss: 60.6678
# Epoch 420/500
# 19/19 [==============================] - 3s 138ms/step - loss: 53.0703 - val_loss: 47.7069
# Epoch 421/500
# 19/19 [==============================] - 3s 145ms/step - loss: 45.9056 - val_loss: 53.1875
# Epoch 422/500
# 19/19 [==============================] - 3s 135ms/step - loss: 51.7075 - val_loss: 46.6748
# Epoch 423/500
# 19/19 [==============================] - 3s 145ms/step - loss: 44.3965 - val_loss: 50.5325
# Epoch 424/500
# 19/19 [==============================] - 3s 144ms/step - loss: 50.6755 - val_loss: 46.0152
# Epoch 425/500
# 19/19 [==============================] - 3s 137ms/step - loss: 42.8414 - val_loss: 48.7492
# Epoch 426/500
# 19/19 [==============================] - 3s 142ms/step - loss: 49.7532 - val_loss: 45.2854
# Epoch 427/500
# 19/19 [==============================] - 3s 140ms/step - loss: 42.4261 - val_loss: 48.0431
# Epoch 428/500
# 19/19 [==============================] - 3s 141ms/step - loss: 49.1170 - val_loss: 45.0737
# Epoch 429/500
# 19/19 [==============================] - 3s 143ms/step - loss: 42.6499 - val_loss: 47.0414
# Epoch 430/500
# 19/19 [==============================] - 3s 144ms/step - loss: 49.9435 - val_loss: 44.4478
# Epoch 431/500
# 19/19 [==============================] - 3s 141ms/step - loss: 43.5261 - val_loss: 46.4619
# Epoch 432/500
# 19/19 [==============================] - 3s 145ms/step - loss: 52.2688 - val_loss: 43.7110
# Epoch 433/500
# 19/19 [==============================] - 3s 146ms/step - loss: 45.5819 - val_loss: 47.0370
# Epoch 434/500
# 19/19 [==============================] - 3s 147ms/step - loss: 56.0534 - val_loss: 43.0986
# Epoch 435/500
# 19/19 [==============================] - 3s 150ms/step - loss: 48.5627 - val_loss: 47.7247
# Epoch 436/500
# 19/19 [==============================] - 3s 146ms/step - loss: 61.6661 - val_loss: 42.9771
# Epoch 437/500
# 19/19 [==============================] - 3s 139ms/step - loss: 53.0006 - val_loss: 50.2877
# Epoch 438/500
# 19/19 [==============================] - 3s 136ms/step - loss: 68.8750 - val_loss: 43.6803
# Epoch 439/500
# 19/19 [==============================] - 3s 146ms/step - loss: 59.3166 - val_loss: 54.2193
# Epoch 440/500
# 19/19 [==============================] - 4s 207ms/step - loss: 73.4631 - val_loss: 45.2982
# Epoch 441/500
# 19/19 [==============================] - 3s 145ms/step - loss: 62.5402 - val_loss: 58.0619
# Epoch 442/500
# 19/19 [==============================] - 3s 145ms/step - loss: 71.6830 - val_loss: 45.5811
# Epoch 443/500
# 19/19 [==============================] - 3s 143ms/step - loss: 60.3658 - val_loss: 61.8670
# Epoch 444/500
# 19/19 [==============================] - 3s 141ms/step - loss: 63.8828 - val_loss: 45.6975
# Epoch 445/500
# 19/19 [==============================] - 3s 141ms/step - loss: 53.5240 - val_loss: 57.3344
# Epoch 446/500
# 19/19 [==============================] - 3s 141ms/step - loss: 56.1179 - val_loss: 43.4423
# Epoch 447/500
# 19/19 [==============================] - 3s 145ms/step - loss: 46.1552 - val_loss: 50.4750
# Epoch 448/500
# 19/19 [==============================] - 3s 140ms/step - loss: 50.4187 - val_loss: 43.7202
# Epoch 449/500
# 19/19 [==============================] - 3s 140ms/step - loss: 44.1329 - val_loss: 48.3860
# Epoch 450/500
# 19/19 [==============================] - 3s 147ms/step - loss: 48.5063 - val_loss: 42.7065
# Epoch 451/500
# 19/19 [==============================] - 3s 149ms/step - loss: 43.3414 - val_loss: 50.6733
# Epoch 452/500
# 19/19 [==============================] - 3s 145ms/step - loss: 45.4910 - val_loss: 49.5321
# Epoch 453/500
# 19/19 [==============================] - 3s 141ms/step - loss: 40.1746 - val_loss: 45.5013
# Epoch 454/500
# 19/19 [==============================] - 3s 144ms/step - loss: 34.1862 - val_loss: 57.4829
# Epoch 455/500
# 19/19 [==============================] - 3s 140ms/step - loss: 36.9189 - val_loss: 44.6102
# Epoch 456/500
# 19/19 [==============================] - 3s 141ms/step - loss: 24.6171 - val_loss: 41.5943
# Epoch 457/500
# 19/19 [==============================] - 3s 141ms/step - loss: 24.1855 - val_loss: 46.9462
# Epoch 458/500
# 19/19 [==============================] - 3s 143ms/step - loss: 25.6511 - val_loss: 47.4432
# Epoch 459/500
# 19/19 [==============================] - 3s 144ms/step - loss: 31.5439 - val_loss: 45.6738
# Epoch 460/500
# 19/19 [==============================] - 3s 141ms/step - loss: 26.6021 - val_loss: 42.8727
# Epoch 461/500
# 19/19 [==============================] - 3s 138ms/step - loss: 21.2487 - val_loss: 40.5287
# Epoch 462/500
# 19/19 [==============================] - 3s 145ms/step - loss: 18.5921 - val_loss: 40.1431
# Epoch 463/500
# 19/19 [==============================] - 3s 145ms/step - loss: 18.0724 - val_loss: 40.0320
# Epoch 464/500
# 19/19 [==============================] - 3s 144ms/step - loss: 17.7343 - val_loss: 40.5272
# Epoch 465/500
# 19/19 [==============================] - 3s 150ms/step - loss: 18.0354 - val_loss: 40.3556
# Epoch 466/500
# 19/19 [==============================] - 3s 158ms/step - loss: 17.5862 - val_loss: 40.5933
# Epoch 467/500
# 19/19 [==============================] - 3s 156ms/step - loss: 17.7037 - val_loss: 39.9344
# Epoch 468/500
# 19/19 [==============================] - 3s 146ms/step - loss: 17.0630 - val_loss: 40.1710
# Epoch 469/500
# 19/19 [==============================] - 3s 147ms/step - loss: 17.1960 - val_loss: 39.4672
# Epoch 470/500
# 19/19 [==============================] - 3s 147ms/step - loss: 16.8103 - val_loss: 39.8025
# Epoch 471/500
# 19/19 [==============================] - 3s 147ms/step - loss: 16.9513 - val_loss: 39.2246
# Epoch 472/500
# 19/19 [==============================] - 3s 142ms/step - loss: 16.9599 - val_loss: 39.7008
# Epoch 473/500
# 19/19 [==============================] - 3s 144ms/step - loss: 17.0715 - val_loss: 39.3345
# Epoch 474/500
# 19/19 [==============================] - 3s 147ms/step - loss: 16.7362 - val_loss: 39.9550
# Epoch 475/500
# 19/19 [==============================] - 3s 145ms/step - loss: 16.8383 - val_loss: 39.4706
# Epoch 476/500
# 19/19 [==============================] - 3s 145ms/step - loss: 16.3703 - val_loss: 39.9829
# Epoch 477/500
# 19/19 [==============================] - 3s 145ms/step - loss: 16.4155 - val_loss: 39.4441
# Epoch 478/500
# 19/19 [==============================] - 3s 142ms/step - loss: 16.1227 - val_loss: 39.7639
# Epoch 479/500
# 19/19 [==============================] - 3s 153ms/step - loss: 16.0977 - val_loss: 39.4099
# Epoch 480/500
# 19/19 [==============================] - 3s 139ms/step - loss: 15.9408 - val_loss: 39.5690
# Epoch 481/500
# 19/19 [==============================] - 3s 141ms/step - loss: 15.7892 - val_loss: 39.4398
# Epoch 482/500
# 19/19 [==============================] - 3s 144ms/step - loss: 15.7728 - val_loss: 39.5236
# Epoch 483/500
# 19/19 [==============================] - 3s 143ms/step - loss: 15.5642 - val_loss: 39.5088
# Epoch 484/500
# 19/19 [==============================] - 3s 148ms/step - loss: 15.6168 - val_loss: 39.6314
# Epoch 485/500
# 19/19 [==============================] - 3s 149ms/step - loss: 15.4486 - val_loss: 39.6150
# Epoch 486/500
# 19/19 [==============================] - 3s 140ms/step - loss: 15.5302 - val_loss: 39.7359
# Epoch 487/500
# 19/19 [==============================] - 3s 143ms/step - loss: 15.3579 - val_loss: 39.7818
# Epoch 488/500
# 19/19 [==============================] - 3s 143ms/step - loss: 15.5593 - val_loss: 39.7632
# Epoch 489/500
# 19/19 [==============================] - 3s 144ms/step - loss: 15.1545 - val_loss: 39.8447
# Epoch 490/500
# 19/19 [==============================] - 3s 143ms/step - loss: 15.2151 - val_loss: 39.9300
# Epoch 491/500
# 19/19 [==============================] - 3s 148ms/step - loss: 14.9401 - val_loss: 39.7203
# Epoch 492/500
# 19/19 [==============================] - 3s 144ms/step - loss: 14.8957 - val_loss: 40.2482
# Epoch 493/500
# 19/19 [==============================] - 3s 152ms/step - loss: 15.1411 - val_loss: 40.1405
# Epoch 494/500
# 19/19 [==============================] - 3s 150ms/step - loss: 15.2009 - val_loss: 40.8313
# Epoch 495/500
# 19/19 [==============================] - 4s 192ms/step - loss: 15.9643 - val_loss: 40.0192
# Epoch 496/500
# 19/19 [==============================] - 3s 160ms/step - loss: 18.9966 - val_loss: 45.4561
# Epoch 497/500
# 19/19 [==============================] - 3s 139ms/step - loss: 21.1277 - val_loss: 45.3743
# Epoch 498/500
# 19/19 [==============================] - 3s 143ms/step - loss: 38.7432 - val_loss: 71.6439
# Epoch 499/500
# 19/19 [==============================] - 3s 142ms/step - loss: 54.4547 - val_loss: 53.2490
# Epoch 500/500
# 19/19 [==============================] - 3s 141ms/step - loss: 33.1120 - val_loss: 51.2620

# %% [markdown]
# ## **7. Đánh giá và trực quan hóa**

# %%
def mae(y_true, y_pred):
    mae = np.mean(np.abs((y_true - y_pred)))

    return mae

def mse(y_true, y_pred):
    mse = np.mean((y_true - y_pred) ** 2)

    return mse

def rmse(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true-y_pred)**2))

    return rmse

def mape(y_true, y_pred):
    mape = np.mean(np.abs((y_true-y_pred) / y_true)) * 100

    return mape

# %%
y_test_pred = model.predict(X_test, verbose=0)
print(f'RMSE: {rmse(y_test, y_test_pred)}')
print(f'MAPE: {mape(y_test, y_test_pred)}')
print(f'MSE: {mse(y_test, y_test_pred)}')
print(f'MAE: {mae(y_test, y_test_pred)}')
# Out:
# RMSE: 6.453594423451137
# MAPE: 2.3762082296487987
# MSE: 41.64888098239961
# MAE: 5.250510790102293

# %%
train_loss = history.history['loss']# Đọc thông tin loss trên tập train
val_loss = history.history['val_loss'] # Đọc thông tin loss trên tập val

plt.figure(figsize=(10, 5)) # Cài đặt kích thước khung ảnh

plt.subplot(1, 2, 1) # Khởi tạo khung ảnh cho training loss
plt.xlabel('Epochs') # Hiển thị tên trục hoành là 'Epochs'
plt.ylabel('Loss') # Hiển thị tên trục tung là 'Loss'
plt.title('Training loss') # Hiển thị title của khung ảnh hiện tại là 'Training Loss'
plt.plot(train_loss, color='green') # Vẽ đường giá trị loss trên tập train qua từng epoch (đường vẽ màu đỏ)

plt.subplot(1, 2, 2) # Khởi tạo khung ảnh cho val loss
plt.xlabel('Epochs') # Hiển thị tên trục hoành là 'Epochs'
plt.ylabel('Loss') # Hiển thị tên trục tung là 'Loss'
plt.title('Validation loss') # Hiển thị title của khung ảnh hiện tại là 'Validation loss'
plt.plot(val_loss, color='orange') # Vẽ đường giá trị loss trên tập val qua từng epoch (đường vẽ màu đỏ)

plt.show() # Hiển thị 2 khung ảnh nhỏ

# %%
def plot_difference(y, pred):
    plt.figure(figsize=(20, 6))
    times = range(len(y))
    y_to_plot = y.flatten()
    pred_to_plot = pred.flatten()

    plt.plot(times, y_to_plot, color='steelblue', marker='o', label='True value')
    plt.plot(times, pred_to_plot, color='orangered', marker='X', label='Prediction')

    plt.title('Adj Closing Price per day')
    plt.xlabel('Date')
    plt.ylabel('Adj Close Price')
    plt.legend()
    plt.show()

plot_difference(y_test[:300], model.predict(X_test[:300], verbose=0))
