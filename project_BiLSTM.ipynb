# %%
# https://drive.google.com/file/d/1FC2P-NC8q_6cAqYIAkV4mBH5MCF1c-oc/view?usp=share_link
# !gdown --id 1FC2P-NC8q_6cAqYIAkV4mBH5MCF1c-oc
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1FC2P-NC8q_6cAqYIAkV4mBH5MCF1c-oc
# To: /content/tesla_stock_price.zip
# 100% 34.1k/34.1k [00:00<00:00, 40.2MB/s]

# %%
# !unzip './tesla_stock_price.zip'
# Out:
# Archive:  ./tesla_stock_price.zip
#   inflating: tesla_stock.csv

# %% [markdown]
# ## **1. Import các thư viện cần thiết**

# %%
import os   
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

from sklearn.model_selection import train_test_split

RANDOM_SEED = 1
tf.random.set_seed(RANDOM_SEED)

# %% [markdown]
# ## **2. Trực quan hóa dữ liệu**

# %%
dataset_filepath = './tesla_stock.csv' # Khai báo đường dẫn đến file .csv của bộ dữ liệu
df = pd.read_csv(dataset_filepath, index_col=0) # Đọc file .csv thành DataFrame
df
# Out:
#                  Open        High         Low       Close    Volume  \
# Date
# 6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 7/1/2010    25.000000   25.920000   20.270000   21.959999   8218800
# 7/2/2010    23.000000   23.100000   18.709999   19.200001   5139800
# 7/6/2010    20.000000   20.000000   15.830000   16.110001   6866900
# ...               ...         ...         ...         ...       ...
# 3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#             Adj Close
# Date
# 6/29/2010   23.889999
# 6/30/2010   23.830000
# 7/1/2010    21.959999
# 7/2/2010    19.200001
# 7/6/2010    16.110001
# ...               ...
# 3/13/2017  246.169998
# 3/14/2017  258.000000
# 3/15/2017  255.729996
# 3/16/2017  262.049988
# 3/17/2017  261.500000
#
# [1692 rows x 6 columns]

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.215000    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1692 entries, 6/29/2010 to 3/17/2017
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1692 non-null   float64
#  1   High       1692 non-null   float64
#  2   Low        1692 non-null   float64
#  3   Close      1692 non-null   float64
#  4   Volume     1692 non-null   int64
#  5   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 92.5+ KB

# %%
plt.figure(figsize=(10, 5))
df['Adj Close'].plot()
plt.title('Adjusted Closing Price of Tesla Stock')
plt.xlabel('Date')
plt.ylabel('Adj Closing Price')
plt.show()

# %%
plt.figure(figsize=(10, 5))
df['Volume'].plot()
plt.title('Volume over day of Tesla Stock')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.show()

# %% [markdown]
# ## **3. Chuẩn bị dữ liệu**

# %%
# Khai báo hàm Windowing (dùng để tạo các cặp X, y cho time series data)
def slicing_window(df, df_start_idx, df_end_idx, input_size, label_size, offset, label_name):
    features = [] # Khai báo list dùng để lưu trữ các X
    labels = [] # Khai báo list dùng để lưu trữ các y

    # Nếu df_end_idx = chỉ mục cuối cùng bảng dữ liệu, cần phải dời xuống 1 khoảng = window size 
    if df_end_idx == None:
        df_end_idx = len(df) - label_size - offset

    df_start_idx = df_start_idx + input_size + offset

    # Duyệt qua từng mẫu dữ liệu
    for idx in range(df_start_idx, df_end_idx):
        feature_start_idx = idx - input_size - offset
        feature_end_idx = feature_start_idx + input_size

        label_start_idx = idx - 1
        label_end_idx = label_start_idx + label_size

        feature = df[feature_start_idx:feature_end_idx] # Lấy X
        label = df[label_name][label_start_idx:label_end_idx] # Lấy y

        features.append(feature) 
        labels.append(label)

    # Chuyển list thành np.ndarrray
    features = np.array(features)
    labels = np.array(labels)

    return features, labels

# %%
INPUT_SIZE = 30 
LABEL_SIZE = 1 
OFFSET = 1 
BATCH_SIZE = 64
TARGET_NAME = 'Adj Close'

# %%
dataset_length = len(df) # Số lượng mẫu dữ liệu trong DataFrame
TRAIN_SIZE = 0.7 # Tỉ lệ kích thước tập train
VAL_SIZE = 0.2 # Tỉ lệ kích thước tập val
# Đổi tỉ lệ thành chỉ mục
TRAIN_END_IDX = int(TRAIN_SIZE * dataset_length) 
VAL_END_IDX = int(VAL_SIZE * dataset_length) + TRAIN_END_IDX

# Khởi tạo X, y cho tập train
X_train, y_train = slicing_window(df, 
                                  df_start_idx=0,
                                  df_end_idx=TRAIN_END_IDX,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET,
                                  label_name=TARGET_NAME)

# Khởi tạo X, y cho tập val
X_val, y_val = slicing_window(df, 
                                  df_start_idx=TRAIN_END_IDX,
                                  df_end_idx=VAL_END_IDX,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET,
                                  label_name=TARGET_NAME)

# Khởi tạo X, y cho tập test
X_test, y_test = slicing_window(df, 
                                  df_start_idx=VAL_END_IDX,
                                  df_end_idx=None,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET,
                                  label_name=TARGET_NAME)

# %%
# Khởi tạo tf.data.Dataset
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(BATCH_SIZE)
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(BATCH_SIZE)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE)

# %%
# Cấu hình các tham số tối ưu cho việc đọc dữ liệu
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## **4. Xây dựng mô hình**

# %%
# Khai báo normalization layer
normalize_layer = tf.keras.layers.Normalization()
normalize_layer.adapt(np.vstack((X_train, X_val, X_test)))

# %%
# Xây dựng hàm khởi tạo model
def build_model(input_shape, output_size):
    model = tf.keras.Sequential([
        # Input layer 
        tf.keras.Input(shape=input_shape, name='input_layer'), 

        normalize_layer,

        # BiLSTM Layer 1 
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, 
                                                           return_sequences=True, 
                                                           kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)),
                                      name='bilstm_layer_1'), 

        # BiLSTM Layer 2
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, 
                                                           return_sequences=True, 
                                                           kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)),
                                      name='bilstm_layer_2'),          

        # BiLSTM Layer 3
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, 
                                                           return_sequences=False, 
                                                           kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)),
                                      name='bilstm_layer_3'),   
                            
        # FC Layer 1
        tf.keras.layers.Dense(32,
                              activation='relu',
                              kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED),
                              name='fc_layer_1'
                              ),
        
        # Output Layer
        tf.keras.layers.Dense(output_size, 
                              kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED),
                              name='output_layer') 
    ],
    name='bilstm_model')

    return model

# %%
INPUT_SHAPE = X_train.shape[-2:] 
model = build_model(INPUT_SHAPE,
                    LABEL_SIZE)
model.summary()
# Out:
# Model: "bilstm_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 30, 6)            13
#  n)
#
#  bilstm_layer_1 (Bidirection  (None, 30, 256)          138240
#  al)
#
#  bilstm_layer_2 (Bidirection  (None, 30, 128)          164352
#  al)
#
#  bilstm_layer_3 (Bidirection  (None, 64)               41216
#  al)
#
#  fc_layer_1 (Dense)          (None, 32)                2080
#
#  output_layer (Dense)        (None, 1)                 33
#
# =================================================================
# Total params: 345,934
# Trainable params: 345,921
# Non-trainable params: 13
# _________________________________________________________________

# %% [markdown]
# ## **5. Cấu hình mô hình**

# %%
# Khai báo một số giá trị siêu tham số
EPOCHS = 500
LR = 1e-3

# %%
# Cấu hình một số thông tin cho mô hình
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR), # Sử dụng optimizer Adam
    loss=tf.keras.losses.MeanSquaredError(), # Sử dụng hàm loss Mean Squared Error
)

# %% [markdown]
# ## **6. Huấn luyện mô hình**

# %%
history = model.fit(train_ds, 
                    validation_data=val_ds,
                    epochs=EPOCHS)
# Out:
# Epoch 1/500
# 19/19 [==============================] - 11s 120ms/step - loss: 16171.7021 - val_loss: 53083.1953
# Epoch 2/500
# 19/19 [==============================] - 0s 20ms/step - loss: 15869.1494 - val_loss: 52791.4492
# Epoch 3/500
# 19/19 [==============================] - 0s 18ms/step - loss: 15234.0293 - val_loss: 48275.2109
# Epoch 4/500
# 19/19 [==============================] - 0s 21ms/step - loss: 13744.7080 - val_loss: 46096.5273
# Epoch 5/500
# 19/19 [==============================] - 0s 20ms/step - loss: 12888.6748 - val_loss: 43822.3203
# Epoch 6/500
# 19/19 [==============================] - 0s 19ms/step - loss: 12041.1963 - val_loss: 41386.1680
# Epoch 7/500
# 19/19 [==============================] - 0s 18ms/step - loss: 11251.8809 - val_loss: 39081.3242
# Epoch 8/500
# 19/19 [==============================] - 0s 19ms/step - loss: 10549.4229 - val_loss: 36880.5938
# Epoch 9/500
# 19/19 [==============================] - 0s 19ms/step - loss: 9922.8174 - val_loss: 34779.2969
# Epoch 10/500
# 19/19 [==============================] - 0s 19ms/step - loss: 9374.2188 - val_loss: 32798.6602
# Epoch 11/500
# 19/19 [==============================] - 0s 19ms/step - loss: 8905.9863 - val_loss: 30959.1387
# Epoch 12/500
# 19/19 [==============================] - 0s 19ms/step - loss: 8516.5088 - val_loss: 29274.2539
# Epoch 13/500
# 19/19 [==============================] - 0s 19ms/step - loss: 8200.6426 - val_loss: 27750.2148
# Epoch 14/500
# 19/19 [==============================] - 0s 19ms/step - loss: 7950.7617 - val_loss: 26386.8047
# Epoch 15/500
# 19/19 [==============================] - 0s 19ms/step - loss: 7757.8691 - val_loss: 25178.6914
# Epoch 16/500
# 19/19 [==============================] - 0s 20ms/step - loss: 7612.5850 - val_loss: 24116.8203
# Epoch 17/500
# 19/19 [==============================] - 0s 19ms/step - loss: 7505.8984 - val_loss: 23189.7539
# Epoch 18/500
# 19/19 [==============================] - 0s 20ms/step - loss: 7429.6655 - val_loss: 22384.8301
# Epoch 19/500
# 19/19 [==============================] - 0s 19ms/step - loss: 7563.8813 - val_loss: 22369.7129
# Epoch 20/500
# 19/19 [==============================] - 0s 19ms/step - loss: 7377.8960 - val_loss: 21690.4707
# Epoch 21/500
# 19/19 [==============================] - 0s 20ms/step - loss: 7341.9438 - val_loss: 21096.3027
# Epoch 22/500
# 19/19 [==============================] - 0s 19ms/step - loss: 7319.5132 - val_loss: 20583.4004
# Epoch 23/500
# 19/19 [==============================] - 0s 19ms/step - loss: 7306.3447 - val_loss: 20142.3418
# Epoch 24/500
# 19/19 [==============================] - 0s 19ms/step - loss: 7299.6611 - val_loss: 19763.8730
# Epoch 25/500
# 19/19 [==============================] - 0s 19ms/step - loss: 7297.3892 - val_loss: 19439.4453
# Epoch 26/500
# 19/19 [==============================] - 0s 19ms/step - loss: 7298.2817 - val_loss: 19161.4668
# Epoch 27/500
# 19/19 [==============================] - 0s 18ms/step - loss: 7459.3413 - val_loss: 19309.9883
# Epoch 28/500
# 19/19 [==============================] - 0s 19ms/step - loss: 7311.4712 - val_loss: 19007.4375
# Epoch 29/500
# 19/19 [==============================] - 0s 20ms/step - loss: 7470.6865 - val_loss: 19605.4668
# Epoch 30/500
# 19/19 [==============================] - 0s 20ms/step - loss: 7471.7349 - val_loss: 20069.8438
# Epoch 31/500
# 19/19 [==============================] - 0s 19ms/step - loss: 7509.5547 - val_loss: 21163.0527
# Epoch 32/500
# 19/19 [==============================] - 0s 20ms/step - loss: 8847.4014 - val_loss: 26058.4531
# Epoch 33/500
# 19/19 [==============================] - 0s 19ms/step - loss: 6375.2930 - val_loss: 22518.4844
# Epoch 34/500
# 19/19 [==============================] - 0s 19ms/step - loss: 5357.5811 - val_loss: 19680.5039
# Epoch 35/500
# 19/19 [==============================] - 0s 19ms/step - loss: 4579.9619 - val_loss: 17276.6855
# Epoch 36/500
# 19/19 [==============================] - 0s 19ms/step - loss: 3935.0027 - val_loss: 15329.1250
# Epoch 37/500
# 19/19 [==============================] - 0s 20ms/step - loss: 3535.9983 - val_loss: 13888.8428
# Epoch 38/500
# 19/19 [==============================] - 0s 19ms/step - loss: 3087.2876 - val_loss: 12492.3857
# Epoch 39/500
# 19/19 [==============================] - 0s 19ms/step - loss: 2783.5295 - val_loss: 11402.0156
# Epoch 40/500
# 19/19 [==============================] - 0s 20ms/step - loss: 2522.4248 - val_loss: 10396.0889
# Epoch 41/500
# 19/19 [==============================] - 0s 19ms/step - loss: 2286.8684 - val_loss: 9468.2100
# Epoch 42/500
# 19/19 [==============================] - 0s 19ms/step - loss: 2078.3049 - val_loss: 8620.7334
# Epoch 43/500
# 19/19 [==============================] - 0s 19ms/step - loss: 1894.5970 - val_loss: 7849.9756
# Epoch 44/500
# 19/19 [==============================] - 0s 19ms/step - loss: 1735.4969 - val_loss: 7154.3013
# Epoch 45/500
# 19/19 [==============================] - 0s 20ms/step - loss: 1598.4478 - val_loss: 6529.0708
# Epoch 46/500
# 19/19 [==============================] - 0s 19ms/step - loss: 1481.7377 - val_loss: 5970.6821
# Epoch 47/500
# 19/19 [==============================] - 0s 20ms/step - loss: 1382.8060 - val_loss: 5473.8662
# Epoch 48/500
# 19/19 [==============================] - 0s 19ms/step - loss: 1300.1461 - val_loss: 5034.1313
# Epoch 49/500
# 19/19 [==============================] - 0s 18ms/step - loss: 1231.4443 - val_loss: 4646.2407
# Epoch 50/500
# 19/19 [==============================] - 0s 19ms/step - loss: 1175.0236 - val_loss: 4305.4390
# Epoch 51/500
# 19/19 [==============================] - 0s 19ms/step - loss: 1128.9319 - val_loss: 4006.8757
# Epoch 52/500
# 19/19 [==============================] - 0s 19ms/step - loss: 1091.7141 - val_loss: 3746.0981
# Epoch 53/500
# 19/19 [==============================] - 0s 19ms/step - loss: 1061.8197 - val_loss: 3518.8511
# Epoch 54/500
# 19/19 [==============================] - 0s 19ms/step - loss: 1038.1101 - val_loss: 3321.2705
# Epoch 55/500
# 19/19 [==============================] - 0s 19ms/step - loss: 1019.3317 - val_loss: 3149.7612
# Epoch 56/500
# 19/19 [==============================] - 0s 20ms/step - loss: 1004.6966 - val_loss: 3001.1550
# Epoch 57/500
# 19/19 [==============================] - 0s 19ms/step - loss: 993.2349 - val_loss: 2872.4814
# Epoch 58/500
# 19/19 [==============================] - 0s 20ms/step - loss: 984.4560 - val_loss: 2761.1970
# Epoch 59/500
# 19/19 [==============================] - 0s 19ms/step - loss: 977.6431 - val_loss: 2665.0164
# Epoch 60/500
# 19/19 [==============================] - 0s 19ms/step - loss: 990.1146 - val_loss: 2579.8528
# Epoch 61/500
# 19/19 [==============================] - 0s 20ms/step - loss: 968.4370 - val_loss: 2506.1677
# Epoch 62/500
# 19/19 [==============================] - 0s 19ms/step - loss: 974.4866 - val_loss: 2446.8818
# Epoch 63/500
# 19/19 [==============================] - 0s 19ms/step - loss: 963.0367 - val_loss: 2393.1868
# Epoch 64/500
# 19/19 [==============================] - 0s 19ms/step - loss: 961.9966 - val_loss: 2347.8821
# Epoch 65/500
# 19/19 [==============================] - 0s 19ms/step - loss: 960.6760 - val_loss: 2308.8491
# Epoch 66/500
# 19/19 [==============================] - 0s 20ms/step - loss: 959.6498 - val_loss: 2275.2944
# Epoch 67/500
# 19/19 [==============================] - 0s 19ms/step - loss: 965.3505 - val_loss: 2245.9492
# Epoch 68/500
# 19/19 [==============================] - 0s 18ms/step - loss: 958.4957 - val_loss: 2220.3313
# Epoch 69/500
# 19/19 [==============================] - 0s 19ms/step - loss: 958.1819 - val_loss: 2199.4482
# Epoch 70/500
# 19/19 [==============================] - 0s 18ms/step - loss: 957.9005 - val_loss: 2181.7539
# Epoch 71/500
# 19/19 [==============================] - 0s 20ms/step - loss: 957.6895 - val_loss: 2166.5811
# Epoch 72/500
# 19/19 [==============================] - 0s 20ms/step - loss: 957.4488 - val_loss: 2153.4324
# Epoch 73/500
# 19/19 [==============================] - 0s 19ms/step - loss: 957.3997 - val_loss: 2142.2476
# Epoch 74/500
# 19/19 [==============================] - 0s 20ms/step - loss: 957.0143 - val_loss: 2131.9263
# Epoch 75/500
# 19/19 [==============================] - 0s 19ms/step - loss: 956.7460 - val_loss: 2124.9854
# Epoch 76/500
# 19/19 [==============================] - 0s 19ms/step - loss: 958.6016 - val_loss: 2116.4910
# Epoch 77/500
# 19/19 [==============================] - 0s 19ms/step - loss: 1000.3297 - val_loss: 2207.3010
# Epoch 78/500
# 19/19 [==============================] - 0s 20ms/step - loss: 937.9611 - val_loss: 2241.6016
# Epoch 79/500
# 19/19 [==============================] - 0s 19ms/step - loss: 940.9022 - val_loss: 2126.6797
# Epoch 80/500
# 19/19 [==============================] - 0s 19ms/step - loss: 900.7425 - val_loss: 2064.5466
# Epoch 81/500
# 19/19 [==============================] - 0s 19ms/step - loss: 946.4819 - val_loss: 2005.0438
# Epoch 82/500
# 19/19 [==============================] - 0s 19ms/step - loss: 890.9097 - val_loss: 1961.5968
# Epoch 83/500
# 19/19 [==============================] - 0s 20ms/step - loss: 878.5278 - val_loss: 1961.0613
# Epoch 84/500
# 19/19 [==============================] - 0s 19ms/step - loss: 858.4431 - val_loss: 1955.7461
# Epoch 85/500
# 19/19 [==============================] - 0s 19ms/step - loss: 794.0416 - val_loss: 1942.0353
# Epoch 86/500
# 19/19 [==============================] - 0s 20ms/step - loss: 713.5338 - val_loss: 1898.2847
# Epoch 87/500
# 19/19 [==============================] - 0s 19ms/step - loss: 623.2345 - val_loss: 1832.1447
# Epoch 88/500
# 19/19 [==============================] - 0s 19ms/step - loss: 562.2180 - val_loss: 1745.0836
# Epoch 89/500
# 19/19 [==============================] - 0s 20ms/step - loss: 581.3532 - val_loss: 1694.3879
# Epoch 90/500
# 19/19 [==============================] - 0s 19ms/step - loss: 641.8981 - val_loss: 2011.5962
# Epoch 91/500
# 19/19 [==============================] - 0s 20ms/step - loss: 588.0569 - val_loss: 1913.6342
# Epoch 92/500
# 19/19 [==============================] - 0s 19ms/step - loss: 561.4868 - val_loss: 1724.2163
# Epoch 93/500
# 19/19 [==============================] - 0s 19ms/step - loss: 545.7379 - val_loss: 1643.0239
# Epoch 94/500
# 19/19 [==============================] - 0s 19ms/step - loss: 529.1013 - val_loss: 1574.5282
# Epoch 95/500
# 19/19 [==============================] - 0s 19ms/step - loss: 524.7783 - val_loss: 1517.9399
# Epoch 96/500
# 19/19 [==============================] - 0s 19ms/step - loss: 794.4977 - val_loss: 1532.0046
# Epoch 97/500
# 19/19 [==============================] - 0s 19ms/step - loss: 963.3406 - val_loss: 3201.0508
# Epoch 98/500
# 19/19 [==============================] - 0s 20ms/step - loss: 836.8309 - val_loss: 2950.6133
# Epoch 99/500
# 19/19 [==============================] - 0s 19ms/step - loss: 800.6135 - val_loss: 2706.6904
# Epoch 100/500
# 19/19 [==============================] - 0s 19ms/step - loss: 772.8650 - val_loss: 2495.2097
# Epoch 101/500
# 19/19 [==============================] - 0s 19ms/step - loss: 817.9830 - val_loss: 2435.1797
# Epoch 102/500
# 19/19 [==============================] - 0s 19ms/step - loss: 733.3397 - val_loss: 2131.3528
# Epoch 103/500
# 19/19 [==============================] - 0s 20ms/step - loss: 719.3508 - val_loss: 2002.2999
# Epoch 104/500
# 19/19 [==============================] - 0s 20ms/step - loss: 715.1829 - val_loss: 1931.1952
# Epoch 105/500
# 19/19 [==============================] - 0s 20ms/step - loss: 712.8048 - val_loss: 1880.0321
# Epoch 106/500
# 19/19 [==============================] - 0s 19ms/step - loss: 711.4290 - val_loss: 1840.6538
# Epoch 107/500
# 19/19 [==============================] - 0s 19ms/step - loss: 710.4443 - val_loss: 1809.4844
# Epoch 108/500
# 19/19 [==============================] - 0s 19ms/step - loss: 709.7545 - val_loss: 1784.5934
# Epoch 109/500
# 19/19 [==============================] - 0s 19ms/step - loss: 709.2767 - val_loss: 1764.6875
# Epoch 110/500
# 19/19 [==============================] - 0s 19ms/step - loss: 708.8909 - val_loss: 1748.7889
# Epoch 111/500
# 19/19 [==============================] - 0s 19ms/step - loss: 720.8510 - val_loss: 1738.8066
# Epoch 112/500
# 19/19 [==============================] - 0s 19ms/step - loss: 720.7382 - val_loss: 1732.6047
# Epoch 113/500
# 19/19 [==============================] - 0s 19ms/step - loss: 720.6166 - val_loss: 1727.9229
# Epoch 114/500
# 19/19 [==============================] - 0s 19ms/step - loss: 720.5056 - val_loss: 1724.2699
# Epoch 115/500
# 19/19 [==============================] - 0s 19ms/step - loss: 720.4245 - val_loss: 1721.4780
# Epoch 116/500
# 19/19 [==============================] - 0s 19ms/step - loss: 720.1945 - val_loss: 1719.4310
# Epoch 117/500
# 19/19 [==============================] - 0s 19ms/step - loss: 720.8210 - val_loss: 1720.9489
# Epoch 118/500
# 19/19 [==============================] - 0s 19ms/step - loss: 720.0163 - val_loss: 1716.4939
# Epoch 119/500
# 19/19 [==============================] - 0s 19ms/step - loss: 719.5349 - val_loss: 1716.3934
# Epoch 120/500
# 19/19 [==============================] - 0s 19ms/step - loss: 718.8057 - val_loss: 1719.2052
# Epoch 121/500
# 19/19 [==============================] - 0s 19ms/step - loss: 717.9973 - val_loss: 1718.2703
# Epoch 122/500
# 19/19 [==============================] - 0s 20ms/step - loss: 809.1470 - val_loss: 2329.2561
# Epoch 123/500
# 19/19 [==============================] - 0s 20ms/step - loss: 691.3340 - val_loss: 2129.4165
# Epoch 124/500
# 19/19 [==============================] - 0s 18ms/step - loss: 677.6707 - val_loss: 1989.0784
# Epoch 125/500
# 19/19 [==============================] - 0s 20ms/step - loss: 686.1208 - val_loss: 1897.6075
# Epoch 126/500
# 19/19 [==============================] - 0s 19ms/step - loss: 764.3632 - val_loss: 2118.4917
# Epoch 127/500
# 19/19 [==============================] - 0s 19ms/step - loss: 996.1549 - val_loss: 3346.0710
# Epoch 128/500
# 19/19 [==============================] - 0s 19ms/step - loss: 996.8915 - val_loss: 3663.8267
# Epoch 129/500
# 19/19 [==============================] - 0s 19ms/step - loss: 815.4620 - val_loss: 2912.7290
# Epoch 130/500
# 19/19 [==============================] - 0s 19ms/step - loss: 752.1548 - val_loss: 2436.9177
# Epoch 131/500
# 19/19 [==============================] - 0s 20ms/step - loss: 727.4041 - val_loss: 2202.4902
# Epoch 132/500
# 19/19 [==============================] - 0s 19ms/step - loss: 716.8107 - val_loss: 2040.7147
# Epoch 133/500
# 19/19 [==============================] - 0s 19ms/step - loss: 712.6585 - val_loss: 1914.3413
# Epoch 134/500
# 19/19 [==============================] - 0s 19ms/step - loss: 713.3912 - val_loss: 1805.7852
# Epoch 135/500
# 19/19 [==============================] - 0s 18ms/step - loss: 703.5463 - val_loss: 1742.2528
# Epoch 136/500
# 19/19 [==============================] - 0s 19ms/step - loss: 744.5878 - val_loss: 1874.7883
# Epoch 137/500
# 19/19 [==============================] - 0s 19ms/step - loss: 622.7242 - val_loss: 1642.7148
# Epoch 138/500
# 19/19 [==============================] - 0s 20ms/step - loss: 626.1665 - val_loss: 1223.2848
# Epoch 139/500
# 19/19 [==============================] - 0s 21ms/step - loss: 358.2975 - val_loss: 1058.5635
# Epoch 140/500
# 19/19 [==============================] - 0s 20ms/step - loss: 256.1145 - val_loss: 816.8880
# Epoch 141/500
# 19/19 [==============================] - 0s 20ms/step - loss: 512.3815 - val_loss: 944.6840
# Epoch 142/500
# 19/19 [==============================] - 0s 20ms/step - loss: 558.6762 - val_loss: 1271.0944
# Epoch 143/500
# 19/19 [==============================] - 0s 20ms/step - loss: 450.3178 - val_loss: 716.6894
# Epoch 144/500
# 19/19 [==============================] - 0s 19ms/step - loss: 462.9735 - val_loss: 837.7878
# Epoch 145/500
# 19/19 [==============================] - 0s 20ms/step - loss: 386.1783 - val_loss: 884.1473
# Epoch 146/500
# 19/19 [==============================] - 0s 20ms/step - loss: 252.0475 - val_loss: 683.4197
# Epoch 147/500
# 19/19 [==============================] - 0s 20ms/step - loss: 244.5375 - val_loss: 663.9686
# Epoch 148/500
# 19/19 [==============================] - 0s 21ms/step - loss: 203.8737 - val_loss: 537.7814
# Epoch 149/500
# 19/19 [==============================] - 0s 19ms/step - loss: 269.6237 - val_loss: 560.9406
# Epoch 150/500
# 19/19 [==============================] - 0s 20ms/step - loss: 295.1886 - val_loss: 559.8655
# Epoch 151/500
# 19/19 [==============================] - 0s 20ms/step - loss: 254.8169 - val_loss: 651.8191
# Epoch 152/500
# 19/19 [==============================] - 0s 20ms/step - loss: 197.6048 - val_loss: 491.6386
# Epoch 153/500
# 19/19 [==============================] - 0s 20ms/step - loss: 163.8291 - val_loss: 435.5412
# Epoch 154/500
# 19/19 [==============================] - 0s 19ms/step - loss: 147.4538 - val_loss: 379.9769
# Epoch 155/500
# 19/19 [==============================] - 0s 21ms/step - loss: 135.5276 - val_loss: 327.3232
# Epoch 156/500
# 19/19 [==============================] - 0s 20ms/step - loss: 123.7693 - val_loss: 280.0623
# Epoch 157/500
# 19/19 [==============================] - 0s 19ms/step - loss: 108.9807 - val_loss: 247.5821
# Epoch 158/500
# 19/19 [==============================] - 0s 20ms/step - loss: 200.5939 - val_loss: 257.6084
# Epoch 159/500
# 19/19 [==============================] - 0s 20ms/step - loss: 146.7359 - val_loss: 211.1546
# Epoch 160/500
# 19/19 [==============================] - 0s 19ms/step - loss: 225.5461 - val_loss: 212.4230
# Epoch 161/500
# 19/19 [==============================] - 0s 21ms/step - loss: 263.6142 - val_loss: 308.0981
# Epoch 162/500
# 19/19 [==============================] - 0s 19ms/step - loss: 197.1380 - val_loss: 342.3885
# Epoch 163/500
# 19/19 [==============================] - 0s 20ms/step - loss: 137.4515 - val_loss: 287.3140
# Epoch 164/500
# 19/19 [==============================] - 0s 20ms/step - loss: 116.7176 - val_loss: 270.8034
# Epoch 165/500
# 19/19 [==============================] - 0s 19ms/step - loss: 99.3791 - val_loss: 233.3196
# Epoch 166/500
# 19/19 [==============================] - 0s 19ms/step - loss: 95.0524 - val_loss: 213.4927
# Epoch 167/500
# 19/19 [==============================] - 0s 19ms/step - loss: 89.3614 - val_loss: 192.2568
# Epoch 168/500
# 19/19 [==============================] - 0s 20ms/step - loss: 87.4754 - val_loss: 176.5214
# Epoch 169/500
# 19/19 [==============================] - 0s 20ms/step - loss: 85.7462 - val_loss: 160.5040
# Epoch 170/500
# 19/19 [==============================] - 0s 20ms/step - loss: 91.4475 - val_loss: 151.1454
# Epoch 171/500
# 19/19 [==============================] - 0s 20ms/step - loss: 96.1336 - val_loss: 142.6339
# Epoch 172/500
# 19/19 [==============================] - 0s 19ms/step - loss: 106.5291 - val_loss: 138.1463
# Epoch 173/500
# 19/19 [==============================] - 0s 19ms/step - loss: 132.5411 - val_loss: 139.5099
# Epoch 174/500
# 19/19 [==============================] - 0s 20ms/step - loss: 162.1596 - val_loss: 148.3291
# Epoch 175/500
# 19/19 [==============================] - 0s 20ms/step - loss: 256.5786 - val_loss: 172.6646
# Epoch 176/500
# 19/19 [==============================] - 0s 20ms/step - loss: 184.9592 - val_loss: 196.1681
# Epoch 177/500
# 19/19 [==============================] - 0s 20ms/step - loss: 141.6333 - val_loss: 183.1516
# Epoch 178/500
# 19/19 [==============================] - 0s 19ms/step - loss: 102.0020 - val_loss: 177.4463
# Epoch 179/500
# 19/19 [==============================] - 0s 19ms/step - loss: 93.7678 - val_loss: 142.6431
# Epoch 180/500
# 19/19 [==============================] - 0s 20ms/step - loss: 90.4791 - val_loss: 138.7686
# Epoch 181/500
# 19/19 [==============================] - 0s 19ms/step - loss: 91.3394 - val_loss: 123.5823
# Epoch 182/500
# 19/19 [==============================] - 0s 20ms/step - loss: 74.8931 - val_loss: 118.3606
# Epoch 183/500
# 19/19 [==============================] - 0s 19ms/step - loss: 70.5338 - val_loss: 110.5688
# Epoch 184/500
# 19/19 [==============================] - 0s 20ms/step - loss: 68.0947 - val_loss: 107.7099
# Epoch 185/500
# 19/19 [==============================] - 0s 20ms/step - loss: 67.3553 - val_loss: 100.3260
# Epoch 186/500
# 19/19 [==============================] - 0s 19ms/step - loss: 66.6295 - val_loss: 98.9027
# Epoch 187/500
# 19/19 [==============================] - 0s 19ms/step - loss: 70.9009 - val_loss: 93.4798
# Epoch 188/500
# 19/19 [==============================] - 0s 20ms/step - loss: 80.2528 - val_loss: 93.6801
# Epoch 189/500
# 19/19 [==============================] - 0s 19ms/step - loss: 100.9792 - val_loss: 92.8428
# Epoch 190/500
# 19/19 [==============================] - 0s 19ms/step - loss: 114.0836 - val_loss: 101.2176
# Epoch 191/500
# 19/19 [==============================] - 0s 19ms/step - loss: 147.0674 - val_loss: 110.5187
# Epoch 192/500
# 19/19 [==============================] - 0s 19ms/step - loss: 129.5321 - val_loss: 119.4006
# Epoch 193/500
# 19/19 [==============================] - 0s 20ms/step - loss: 125.4381 - val_loss: 111.1699
# Epoch 194/500
# 19/19 [==============================] - 0s 20ms/step - loss: 93.1782 - val_loss: 119.7648
# Epoch 195/500
# 19/19 [==============================] - 0s 19ms/step - loss: 79.2740 - val_loss: 97.1887
# Epoch 196/500
# 19/19 [==============================] - 0s 20ms/step - loss: 72.3266 - val_loss: 100.0437
# Epoch 197/500
# 19/19 [==============================] - 0s 19ms/step - loss: 66.6893 - val_loss: 86.5988
# Epoch 198/500
# 19/19 [==============================] - 0s 20ms/step - loss: 67.2066 - val_loss: 89.1316
# Epoch 199/500
# 19/19 [==============================] - 0s 20ms/step - loss: 86.6108 - val_loss: 79.8464
# Epoch 200/500
# 19/19 [==============================] - 0s 19ms/step - loss: 90.2993 - val_loss: 83.3607
# Epoch 201/500
# 19/19 [==============================] - 0s 20ms/step - loss: 71.0682 - val_loss: 76.6849
# Epoch 202/500
# 19/19 [==============================] - 0s 20ms/step - loss: 67.5249 - val_loss: 79.5988
# Epoch 203/500
# 19/19 [==============================] - 0s 19ms/step - loss: 66.8983 - val_loss: 72.6516
# Epoch 204/500
# 19/19 [==============================] - 0s 19ms/step - loss: 69.7611 - val_loss: 73.3850
# Epoch 205/500
# 19/19 [==============================] - 0s 20ms/step - loss: 70.0847 - val_loss: 70.2075
# Epoch 206/500
# 19/19 [==============================] - 0s 20ms/step - loss: 71.3319 - val_loss: 76.6308
# Epoch 207/500
# 19/19 [==============================] - 0s 20ms/step - loss: 86.2414 - val_loss: 72.0559
# Epoch 208/500
# 19/19 [==============================] - 0s 19ms/step - loss: 84.3952 - val_loss: 79.9398
# Epoch 209/500
# 19/19 [==============================] - 0s 20ms/step - loss: 101.7387 - val_loss: 78.9216
# Epoch 210/500
# 19/19 [==============================] - 0s 19ms/step - loss: 93.5432 - val_loss: 89.9811
# Epoch 211/500
# 19/19 [==============================] - 0s 20ms/step - loss: 106.9029 - val_loss: 82.5667
# Epoch 212/500
# 19/19 [==============================] - 0s 19ms/step - loss: 86.4401 - val_loss: 93.2320
# Epoch 213/500
# 19/19 [==============================] - 0s 19ms/step - loss: 82.2588 - val_loss: 79.9152
# Epoch 214/500
# 19/19 [==============================] - 0s 19ms/step - loss: 69.9135 - val_loss: 85.7788
# Epoch 215/500
# 19/19 [==============================] - 0s 20ms/step - loss: 66.4534 - val_loss: 72.9187
# Epoch 216/500
# 19/19 [==============================] - 0s 19ms/step - loss: 60.3534 - val_loss: 77.2461
# Epoch 217/500
# 19/19 [==============================] - 0s 19ms/step - loss: 60.9786 - val_loss: 67.8593
# Epoch 218/500
# 19/19 [==============================] - 0s 19ms/step - loss: 57.8776 - val_loss: 71.4756
# Epoch 219/500
# 19/19 [==============================] - 0s 19ms/step - loss: 62.1296 - val_loss: 65.0530
# Epoch 220/500
# 19/19 [==============================] - 0s 20ms/step - loss: 74.2434 - val_loss: 68.2260
# Epoch 221/500
# 19/19 [==============================] - 0s 19ms/step - loss: 78.7136 - val_loss: 63.1258
# Epoch 222/500
# 19/19 [==============================] - 0s 19ms/step - loss: 61.9907 - val_loss: 66.3330
# Epoch 223/500
# 19/19 [==============================] - 0s 19ms/step - loss: 57.1541 - val_loss: 60.9660
# Epoch 224/500
# 19/19 [==============================] - 0s 19ms/step - loss: 57.2337 - val_loss: 64.9438
# Epoch 225/500
# 19/19 [==============================] - 1s 38ms/step - loss: 56.6147 - val_loss: 59.9832
# Epoch 226/500
# 19/19 [==============================] - 1s 33ms/step - loss: 57.9820 - val_loss: 65.5466
# Epoch 227/500
# 19/19 [==============================] - 0s 24ms/step - loss: 58.9643 - val_loss: 59.4905
# Epoch 228/500
# 19/19 [==============================] - 1s 43ms/step - loss: 64.6593 - val_loss: 64.9602
# Epoch 229/500
# 19/19 [==============================] - 0s 20ms/step - loss: 79.5706 - val_loss: 124.9661
# Epoch 230/500
# 19/19 [==============================] - 0s 20ms/step - loss: 154.0747 - val_loss: 77.5188
# Epoch 231/500
# 19/19 [==============================] - 0s 19ms/step - loss: 128.0351 - val_loss: 60.2607
# Epoch 232/500
# 19/19 [==============================] - 0s 19ms/step - loss: 104.5360 - val_loss: 78.1842
# Epoch 233/500
# 19/19 [==============================] - 0s 21ms/step - loss: 94.3212 - val_loss: 70.7855
# Epoch 234/500
# 19/19 [==============================] - 0s 19ms/step - loss: 71.8933 - val_loss: 78.8236
# Epoch 235/500
# 19/19 [==============================] - 0s 20ms/step - loss: 62.1231 - val_loss: 62.5713
# Epoch 236/500
# 19/19 [==============================] - 0s 20ms/step - loss: 58.3194 - val_loss: 66.5992
# Epoch 237/500
# 19/19 [==============================] - 0s 20ms/step - loss: 54.2714 - val_loss: 58.8987
# Epoch 238/500
# 19/19 [==============================] - 0s 20ms/step - loss: 61.2983 - val_loss: 74.5754
# Epoch 239/500
# 19/19 [==============================] - 0s 20ms/step - loss: 56.6285 - val_loss: 58.6425
# Epoch 240/500
# 19/19 [==============================] - 0s 20ms/step - loss: 51.2104 - val_loss: 61.5484
# Epoch 241/500
# 19/19 [==============================] - 0s 20ms/step - loss: 51.5167 - val_loss: 56.0200
# Epoch 242/500
# 19/19 [==============================] - 0s 22ms/step - loss: 50.6475 - val_loss: 57.7352
# Epoch 243/500
# 19/19 [==============================] - 1s 27ms/step - loss: 55.2160 - val_loss: 53.1720
# Epoch 244/500
# 19/19 [==============================] - 1s 27ms/step - loss: 51.2140 - val_loss: 56.0860
# Epoch 245/500
# 19/19 [==============================] - 1s 27ms/step - loss: 55.1118 - val_loss: 52.3043
# Epoch 246/500
# 19/19 [==============================] - 1s 27ms/step - loss: 51.1929 - val_loss: 56.7251
# Epoch 247/500
# 19/19 [==============================] - 0s 22ms/step - loss: 55.1438 - val_loss: 54.0611
# Epoch 248/500
# 19/19 [==============================] - 0s 21ms/step - loss: 51.0981 - val_loss: 57.0686
# Epoch 249/500
# 19/19 [==============================] - 0s 21ms/step - loss: 62.4412 - val_loss: 52.0685
# Epoch 250/500
# 19/19 [==============================] - 0s 20ms/step - loss: 56.9637 - val_loss: 61.3272
# Epoch 251/500
# 19/19 [==============================] - 0s 19ms/step - loss: 70.1658 - val_loss: 56.7173
# Epoch 252/500
# 19/19 [==============================] - 0s 20ms/step - loss: 61.2137 - val_loss: 68.7188
# Epoch 253/500
# 19/19 [==============================] - 0s 19ms/step - loss: 64.2690 - val_loss: 82.1935
# Epoch 254/500
# 19/19 [==============================] - 0s 19ms/step - loss: 91.3133 - val_loss: 108.9760
# Epoch 255/500
# 19/19 [==============================] - 0s 20ms/step - loss: 77.5905 - val_loss: 81.4110
# Epoch 256/500
# 19/19 [==============================] - 0s 20ms/step - loss: 69.2900 - val_loss: 79.0715
# Epoch 257/500
# 19/19 [==============================] - 0s 20ms/step - loss: 95.3274 - val_loss: 94.0763
# Epoch 258/500
# 19/19 [==============================] - 0s 20ms/step - loss: 93.3248 - val_loss: 86.7165
# Epoch 259/500
# 19/19 [==============================] - 0s 19ms/step - loss: 80.4046 - val_loss: 86.5047
# Epoch 260/500
# 19/19 [==============================] - 0s 20ms/step - loss: 68.9500 - val_loss: 96.7211
# Epoch 261/500
# 19/19 [==============================] - 0s 20ms/step - loss: 55.3306 - val_loss: 84.0626
# Epoch 262/500
# 19/19 [==============================] - 0s 20ms/step - loss: 52.3287 - val_loss: 82.0437
# Epoch 263/500
# 19/19 [==============================] - 0s 20ms/step - loss: 52.3619 - val_loss: 70.5888
# Epoch 264/500
# 19/19 [==============================] - 0s 20ms/step - loss: 45.9383 - val_loss: 74.9280
# Epoch 265/500
# 19/19 [==============================] - 0s 21ms/step - loss: 54.5970 - val_loss: 70.5159
# Epoch 266/500
# 19/19 [==============================] - 0s 20ms/step - loss: 44.7256 - val_loss: 83.4029
# Epoch 267/500
# 19/19 [==============================] - 0s 20ms/step - loss: 50.6764 - val_loss: 90.1296
# Epoch 268/500
# 19/19 [==============================] - 0s 20ms/step - loss: 45.7954 - val_loss: 79.9363
# Epoch 269/500
# 19/19 [==============================] - 0s 19ms/step - loss: 60.7760 - val_loss: 70.1179
# Epoch 270/500
# 19/19 [==============================] - 0s 19ms/step - loss: 48.3916 - val_loss: 52.5082
# Epoch 271/500
# 19/19 [==============================] - 0s 20ms/step - loss: 48.5399 - val_loss: 47.5205
# Epoch 272/500
# 19/19 [==============================] - 0s 19ms/step - loss: 48.6806 - val_loss: 50.6554
# Epoch 273/500
# 19/19 [==============================] - 0s 20ms/step - loss: 49.8015 - val_loss: 47.9704
# Epoch 274/500
# 19/19 [==============================] - 0s 20ms/step - loss: 51.2342 - val_loss: 52.7817
# Epoch 275/500
# 19/19 [==============================] - 0s 21ms/step - loss: 53.0998 - val_loss: 48.7217
# Epoch 276/500
# 19/19 [==============================] - 0s 21ms/step - loss: 55.1578 - val_loss: 54.8185
# Epoch 277/500
# 19/19 [==============================] - 0s 20ms/step - loss: 62.7304 - val_loss: 50.4873
# Epoch 278/500
# 19/19 [==============================] - 0s 19ms/step - loss: 53.9000 - val_loss: 60.3604
# Epoch 279/500
# 19/19 [==============================] - 0s 20ms/step - loss: 65.7802 - val_loss: 50.0351
# Epoch 280/500
# 19/19 [==============================] - 0s 20ms/step - loss: 53.6326 - val_loss: 57.0897
# Epoch 281/500
# 19/19 [==============================] - 0s 20ms/step - loss: 60.5087 - val_loss: 50.3675
# Epoch 282/500
# 19/19 [==============================] - 0s 20ms/step - loss: 51.9833 - val_loss: 58.2068
# Epoch 283/500
# 19/19 [==============================] - 0s 20ms/step - loss: 58.4199 - val_loss: 48.6716
# Epoch 284/500
# 19/19 [==============================] - 0s 19ms/step - loss: 56.1927 - val_loss: 51.9345
# Epoch 285/500
# 19/19 [==============================] - 0s 20ms/step - loss: 71.6437 - val_loss: 50.9310
# Epoch 286/500
# 19/19 [==============================] - 0s 20ms/step - loss: 62.3210 - val_loss: 62.6544
# Epoch 287/500
# 19/19 [==============================] - 0s 20ms/step - loss: 67.0094 - val_loss: 51.6785
# Epoch 288/500
# 19/19 [==============================] - 0s 19ms/step - loss: 52.9550 - val_loss: 60.4596
# Epoch 289/500
# 19/19 [==============================] - 0s 20ms/step - loss: 49.2699 - val_loss: 50.3594
# Epoch 290/500
# 19/19 [==============================] - 0s 22ms/step - loss: 44.8971 - val_loss: 55.6529
# Epoch 291/500
# 19/19 [==============================] - 0s 21ms/step - loss: 55.9935 - val_loss: 49.1679
# Epoch 292/500
# 19/19 [==============================] - 0s 20ms/step - loss: 43.2967 - val_loss: 54.7418
# Epoch 293/500
# 19/19 [==============================] - 0s 20ms/step - loss: 52.3326 - val_loss: 48.7021
# Epoch 294/500
# 19/19 [==============================] - 0s 20ms/step - loss: 39.9094 - val_loss: 51.6919
# Epoch 295/500
# 19/19 [==============================] - 0s 20ms/step - loss: 46.8728 - val_loss: 46.8315
# Epoch 296/500
# 19/19 [==============================] - 0s 20ms/step - loss: 43.5151 - val_loss: 48.9672
# Epoch 297/500
# 19/19 [==============================] - 0s 20ms/step - loss: 58.5280 - val_loss: 46.9370
# Epoch 298/500
# 19/19 [==============================] - 0s 22ms/step - loss: 48.6873 - val_loss: 50.0051
# Epoch 299/500
# 19/19 [==============================] - 0s 20ms/step - loss: 47.8509 - val_loss: 46.2995
# Epoch 300/500
# 19/19 [==============================] - 0s 20ms/step - loss: 48.9784 - val_loss: 50.4879
# Epoch 301/500
# 19/19 [==============================] - 0s 20ms/step - loss: 52.9282 - val_loss: 45.8491
# Epoch 302/500
# 19/19 [==============================] - 0s 20ms/step - loss: 49.9697 - val_loss: 51.0872
# Epoch 303/500
# 19/19 [==============================] - 0s 19ms/step - loss: 63.2655 - val_loss: 46.6798
# Epoch 304/500
# 19/19 [==============================] - 0s 21ms/step - loss: 55.7470 - val_loss: 54.9267
# Epoch 305/500
# 19/19 [==============================] - 0s 20ms/step - loss: 59.6802 - val_loss: 48.6013
# Epoch 306/500
# 19/19 [==============================] - 0s 20ms/step - loss: 51.7869 - val_loss: 57.9248
# Epoch 307/500
# 19/19 [==============================] - 0s 21ms/step - loss: 59.5413 - val_loss: 49.2839
# Epoch 308/500
# 19/19 [==============================] - 0s 22ms/step - loss: 49.9271 - val_loss: 57.6352
# Epoch 309/500
# 19/19 [==============================] - 0s 21ms/step - loss: 51.9999 - val_loss: 48.6019
# Epoch 310/500
# 19/19 [==============================] - 0s 21ms/step - loss: 44.0679 - val_loss: 55.6426
# Epoch 311/500
# 19/19 [==============================] - 0s 21ms/step - loss: 62.9421 - val_loss: 48.2308
# Epoch 312/500
# 19/19 [==============================] - 0s 20ms/step - loss: 49.7146 - val_loss: 54.9385
# Epoch 313/500
# 19/19 [==============================] - 0s 20ms/step - loss: 47.2793 - val_loss: 47.0722
# Epoch 314/500
# 19/19 [==============================] - 0s 20ms/step - loss: 47.1251 - val_loss: 52.3302
# Epoch 315/500
# 19/19 [==============================] - 0s 20ms/step - loss: 45.1331 - val_loss: 46.3970
# Epoch 316/500
# 19/19 [==============================] - 0s 19ms/step - loss: 43.1549 - val_loss: 52.1446
# Epoch 317/500
# 19/19 [==============================] - 0s 19ms/step - loss: 51.3863 - val_loss: 46.3586
# Epoch 318/500
# 19/19 [==============================] - 0s 20ms/step - loss: 40.2482 - val_loss: 52.4156
# Epoch 319/500
# 19/19 [==============================] - 0s 20ms/step - loss: 49.9285 - val_loss: 45.9121
# Epoch 320/500
# 19/19 [==============================] - 0s 20ms/step - loss: 39.3418 - val_loss: 51.4676
# Epoch 321/500
# 19/19 [==============================] - 0s 21ms/step - loss: 50.4711 - val_loss: 45.8262
# Epoch 322/500
# 19/19 [==============================] - 0s 20ms/step - loss: 39.7380 - val_loss: 52.3292
# Epoch 323/500
# 19/19 [==============================] - 0s 20ms/step - loss: 48.2035 - val_loss: 45.6579
# Epoch 324/500
# 19/19 [==============================] - 0s 20ms/step - loss: 38.7413 - val_loss: 51.6297
# Epoch 325/500
# 19/19 [==============================] - 0s 20ms/step - loss: 51.0477 - val_loss: 45.5339
# Epoch 326/500
# 19/19 [==============================] - 0s 20ms/step - loss: 41.7218 - val_loss: 51.9200
# Epoch 327/500
# 19/19 [==============================] - 0s 21ms/step - loss: 46.5628 - val_loss: 45.4664
# Epoch 328/500
# 19/19 [==============================] - 0s 20ms/step - loss: 39.5940 - val_loss: 51.8456
# Epoch 329/500
# 19/19 [==============================] - 0s 20ms/step - loss: 52.0948 - val_loss: 45.6253
# Epoch 330/500
# 19/19 [==============================] - 0s 21ms/step - loss: 41.0901 - val_loss: 52.5302
# Epoch 331/500
# 19/19 [==============================] - 0s 20ms/step - loss: 49.7358 - val_loss: 45.6863
# Epoch 332/500
# 19/19 [==============================] - 0s 20ms/step - loss: 41.1037 - val_loss: 52.2387
# Epoch 333/500
# 19/19 [==============================] - 0s 20ms/step - loss: 59.9894 - val_loss: 45.8867
# Epoch 334/500
# 19/19 [==============================] - 0s 19ms/step - loss: 47.7240 - val_loss: 51.9961
# Epoch 335/500
# 19/19 [==============================] - 0s 21ms/step - loss: 47.5419 - val_loss: 45.3775
# Epoch 336/500
# 19/19 [==============================] - 0s 21ms/step - loss: 48.0552 - val_loss: 51.7537
# Epoch 337/500
# 19/19 [==============================] - 0s 20ms/step - loss: 46.8743 - val_loss: 45.4676
# Epoch 338/500
# 19/19 [==============================] - 0s 20ms/step - loss: 41.4126 - val_loss: 52.5911
# Epoch 339/500
# 19/19 [==============================] - 0s 20ms/step - loss: 55.4699 - val_loss: 46.0039
# Epoch 340/500
# 19/19 [==============================] - 0s 21ms/step - loss: 41.7036 - val_loss: 53.9344
# Epoch 341/500
# 19/19 [==============================] - 0s 21ms/step - loss: 49.5541 - val_loss: 45.8958
# Epoch 342/500
# 19/19 [==============================] - 0s 20ms/step - loss: 41.3493 - val_loss: 52.1493
# Epoch 343/500
# 19/19 [==============================] - 0s 21ms/step - loss: 43.0082 - val_loss: 45.2371
# Epoch 344/500
# 19/19 [==============================] - 0s 20ms/step - loss: 39.0138 - val_loss: 51.9513
# Epoch 345/500
# 19/19 [==============================] - 0s 20ms/step - loss: 45.2076 - val_loss: 45.1044
# Epoch 346/500
# 19/19 [==============================] - 0s 20ms/step - loss: 36.6487 - val_loss: 52.1674
# Epoch 347/500
# 19/19 [==============================] - 0s 20ms/step - loss: 45.0461 - val_loss: 44.4150
# Epoch 348/500
# 19/19 [==============================] - 0s 21ms/step - loss: 36.6365 - val_loss: 51.4977
# Epoch 349/500
# 19/19 [==============================] - 0s 20ms/step - loss: 44.0563 - val_loss: 44.4527
# Epoch 350/500
# 19/19 [==============================] - 0s 20ms/step - loss: 37.4678 - val_loss: 50.8131
# Epoch 351/500
# 19/19 [==============================] - 0s 20ms/step - loss: 43.3831 - val_loss: 44.3279
# Epoch 352/500
# 19/19 [==============================] - 0s 19ms/step - loss: 36.4900 - val_loss: 50.7315
# Epoch 353/500
# 19/19 [==============================] - 0s 20ms/step - loss: 43.0263 - val_loss: 44.2314
# Epoch 354/500
# 19/19 [==============================] - 0s 20ms/step - loss: 37.9912 - val_loss: 51.0323
# Epoch 355/500
# 19/19 [==============================] - 0s 20ms/step - loss: 43.6685 - val_loss: 44.1663
# Epoch 356/500
# 19/19 [==============================] - 0s 20ms/step - loss: 37.6630 - val_loss: 52.5037
# Epoch 357/500
# 19/19 [==============================] - 0s 21ms/step - loss: 43.1450 - val_loss: 44.7469
# Epoch 358/500
# 19/19 [==============================] - 0s 21ms/step - loss: 36.7385 - val_loss: 51.3887
# Epoch 359/500
# 19/19 [==============================] - 0s 20ms/step - loss: 48.4158 - val_loss: 44.6501
# Epoch 360/500
# 19/19 [==============================] - 0s 20ms/step - loss: 39.5470 - val_loss: 54.5371
# Epoch 361/500
# 19/19 [==============================] - 0s 20ms/step - loss: 46.2593 - val_loss: 45.6568
# Epoch 362/500
# 19/19 [==============================] - 0s 21ms/step - loss: 35.6377 - val_loss: 50.4730
# Epoch 363/500
# 19/19 [==============================] - 0s 20ms/step - loss: 43.0925 - val_loss: 44.5658
# Epoch 364/500
# 19/19 [==============================] - 0s 20ms/step - loss: 36.3496 - val_loss: 54.1941
# Epoch 365/500
# 19/19 [==============================] - 0s 20ms/step - loss: 42.4630 - val_loss: 45.3175
# Epoch 366/500
# 19/19 [==============================] - 0s 22ms/step - loss: 39.3686 - val_loss: 50.4894
# Epoch 367/500
# 19/19 [==============================] - 0s 20ms/step - loss: 49.1492 - val_loss: 49.2610
# Epoch 368/500
# 19/19 [==============================] - 0s 21ms/step - loss: 56.6822 - val_loss: 63.1025
# Epoch 369/500
# 19/19 [==============================] - 0s 20ms/step - loss: 46.7080 - val_loss: 45.2143
# Epoch 370/500
# 19/19 [==============================] - 0s 20ms/step - loss: 58.1265 - val_loss: 51.9189
# Epoch 371/500
# 19/19 [==============================] - 0s 20ms/step - loss: 59.0060 - val_loss: 44.7090
# Epoch 372/500
# 19/19 [==============================] - 0s 21ms/step - loss: 456.1300 - val_loss: 52.4324
# Epoch 373/500
# 19/19 [==============================] - 0s 20ms/step - loss: 162.7930 - val_loss: 48.9217
# Epoch 374/500
# 19/19 [==============================] - 0s 21ms/step - loss: 66.7782 - val_loss: 69.6245
# Epoch 375/500
# 19/19 [==============================] - 0s 21ms/step - loss: 73.2855 - val_loss: 48.5688
# Epoch 376/500
# 19/19 [==============================] - 0s 21ms/step - loss: 50.4544 - val_loss: 51.5959
# Epoch 377/500
# 19/19 [==============================] - 0s 19ms/step - loss: 49.7339 - val_loss: 44.7736
# Epoch 378/500
# 19/19 [==============================] - 0s 21ms/step - loss: 43.7777 - val_loss: 50.4986
# Epoch 379/500
# 19/19 [==============================] - 0s 21ms/step - loss: 48.4792 - val_loss: 43.8220
# Epoch 380/500
# 19/19 [==============================] - 0s 21ms/step - loss: 37.0079 - val_loss: 48.0728
# Epoch 381/500
# 19/19 [==============================] - 0s 21ms/step - loss: 47.0159 - val_loss: 43.1208
# Epoch 382/500
# 19/19 [==============================] - 0s 21ms/step - loss: 34.3684 - val_loss: 47.2792
# Epoch 383/500
# 19/19 [==============================] - 0s 20ms/step - loss: 34.8297 - val_loss: 42.7232
# Epoch 384/500
# 19/19 [==============================] - 0s 21ms/step - loss: 33.7155 - val_loss: 46.4642
# Epoch 385/500
# 19/19 [==============================] - 0s 20ms/step - loss: 41.7421 - val_loss: 42.2978
# Epoch 386/500
# 19/19 [==============================] - 0s 21ms/step - loss: 39.9468 - val_loss: 46.5780
# Epoch 387/500
# 19/19 [==============================] - 0s 21ms/step - loss: 37.1048 - val_loss: 42.1841
# Epoch 388/500
# 19/19 [==============================] - 0s 20ms/step - loss: 37.1896 - val_loss: 47.8981
# Epoch 389/500
# 19/19 [==============================] - 0s 20ms/step - loss: 51.3140 - val_loss: 42.3871
# Epoch 390/500
# 19/19 [==============================] - 0s 20ms/step - loss: 44.2730 - val_loss: 49.5545
# Epoch 391/500
# 19/19 [==============================] - 0s 21ms/step - loss: 42.2882 - val_loss: 42.7814
# Epoch 392/500
# 19/19 [==============================] - 0s 21ms/step - loss: 41.6646 - val_loss: 51.9803
# Epoch 393/500
# 19/19 [==============================] - 0s 20ms/step - loss: 47.0131 - val_loss: 43.5292
# Epoch 394/500
# 19/19 [==============================] - 0s 21ms/step - loss: 48.9907 - val_loss: 51.4721
# Epoch 395/500
# 19/19 [==============================] - 0s 21ms/step - loss: 48.0972 - val_loss: 44.0175
# Epoch 396/500
# 19/19 [==============================] - 0s 21ms/step - loss: 43.0166 - val_loss: 55.2881
# Epoch 397/500
# 19/19 [==============================] - 0s 20ms/step - loss: 41.2406 - val_loss: 44.6929
# Epoch 398/500
# 19/19 [==============================] - 0s 20ms/step - loss: 44.0371 - val_loss: 53.0779
# Epoch 399/500
# 19/19 [==============================] - 0s 22ms/step - loss: 61.6977 - val_loss: 44.6630
# Epoch 400/500
# 19/19 [==============================] - 0s 20ms/step - loss: 47.4911 - val_loss: 55.2782
# Epoch 401/500
# 19/19 [==============================] - 0s 21ms/step - loss: 40.8031 - val_loss: 44.3101
# Epoch 402/500
# 19/19 [==============================] - 0s 21ms/step - loss: 34.6464 - val_loss: 50.2299
# Epoch 403/500
# 19/19 [==============================] - 0s 21ms/step - loss: 39.2397 - val_loss: 43.4112
# Epoch 404/500
# 19/19 [==============================] - 0s 21ms/step - loss: 33.6252 - val_loss: 51.6589
# Epoch 405/500
# 19/19 [==============================] - 0s 20ms/step - loss: 31.1319 - val_loss: 43.3756
# Epoch 406/500
# 19/19 [==============================] - 0s 21ms/step - loss: 31.8916 - val_loss: 48.9417
# Epoch 407/500
# 19/19 [==============================] - 0s 21ms/step - loss: 36.4854 - val_loss: 42.5322
# Epoch 408/500
# 19/19 [==============================] - 0s 21ms/step - loss: 36.4726 - val_loss: 46.6917
# Epoch 409/500
# 19/19 [==============================] - 0s 20ms/step - loss: 42.0774 - val_loss: 42.4609
# Epoch 410/500
# 19/19 [==============================] - 0s 21ms/step - loss: 32.4627 - val_loss: 48.0374
# Epoch 411/500
# 19/19 [==============================] - 0s 21ms/step - loss: 28.3340 - val_loss: 42.3968
# Epoch 412/500
# 19/19 [==============================] - 0s 21ms/step - loss: 27.4455 - val_loss: 47.4920
# Epoch 413/500
# 19/19 [==============================] - 0s 21ms/step - loss: 26.7184 - val_loss: 42.1475
# Epoch 414/500
# 19/19 [==============================] - 0s 21ms/step - loss: 27.6984 - val_loss: 47.1854
# Epoch 415/500
# 19/19 [==============================] - 0s 20ms/step - loss: 33.1548 - val_loss: 42.0746
# Epoch 416/500
# 19/19 [==============================] - 0s 22ms/step - loss: 36.1923 - val_loss: 47.0425
# Epoch 417/500
# 19/19 [==============================] - 0s 20ms/step - loss: 49.8563 - val_loss: 42.3572
# Epoch 418/500
# 19/19 [==============================] - 0s 20ms/step - loss: 37.6112 - val_loss: 47.7598
# Epoch 419/500
# 19/19 [==============================] - 0s 20ms/step - loss: 32.7506 - val_loss: 42.2494
# Epoch 420/500
# 19/19 [==============================] - 0s 19ms/step - loss: 36.4022 - val_loss: 59.7608
# Epoch 421/500
# 19/19 [==============================] - 0s 21ms/step - loss: 36.5619 - val_loss: 45.1242
# Epoch 422/500
# 19/19 [==============================] - 0s 20ms/step - loss: 34.6145 - val_loss: 46.7293
# Epoch 423/500
# 19/19 [==============================] - 0s 21ms/step - loss: 46.2856 - val_loss: 43.7445
# Epoch 424/500
# 19/19 [==============================] - 0s 21ms/step - loss: 50.2696 - val_loss: 58.5075
# Epoch 425/500
# 19/19 [==============================] - 0s 19ms/step - loss: 55.5410 - val_loss: 45.5946
# Epoch 426/500
# 19/19 [==============================] - 0s 21ms/step - loss: 44.6172 - val_loss: 52.6500
# Epoch 427/500
# 19/19 [==============================] - 0s 19ms/step - loss: 43.2608 - val_loss: 47.0262
# Epoch 428/500
# 19/19 [==============================] - 0s 20ms/step - loss: 40.8081 - val_loss: 62.6511
# Epoch 429/500
# 19/19 [==============================] - 0s 20ms/step - loss: 36.0570 - val_loss: 43.6147
# Epoch 430/500
# 19/19 [==============================] - 0s 20ms/step - loss: 44.8246 - val_loss: 48.6323
# Epoch 431/500
# 19/19 [==============================] - 0s 21ms/step - loss: 53.9981 - val_loss: 42.3442
# Epoch 432/500
# 19/19 [==============================] - 0s 20ms/step - loss: 48.0401 - val_loss: 54.7760
# Epoch 433/500
# 19/19 [==============================] - 0s 20ms/step - loss: 52.0646 - val_loss: 44.2742
# Epoch 434/500
# 19/19 [==============================] - 0s 21ms/step - loss: 50.0335 - val_loss: 56.1914
# Epoch 435/500
# 19/19 [==============================] - 0s 20ms/step - loss: 45.9500 - val_loss: 43.7137
# Epoch 436/500
# 19/19 [==============================] - 0s 20ms/step - loss: 40.8801 - val_loss: 57.9409
# Epoch 437/500
# 19/19 [==============================] - 0s 20ms/step - loss: 33.2489 - val_loss: 44.2003
# Epoch 438/500
# 19/19 [==============================] - 0s 21ms/step - loss: 29.5779 - val_loss: 50.3531
# Epoch 439/500
# 19/19 [==============================] - 0s 22ms/step - loss: 26.2609 - val_loss: 42.7765
# Epoch 440/500
# 19/19 [==============================] - 0s 21ms/step - loss: 25.9022 - val_loss: 49.2210
# Epoch 441/500
# 19/19 [==============================] - 0s 20ms/step - loss: 23.5476 - val_loss: 42.2952
# Epoch 442/500
# 19/19 [==============================] - 0s 20ms/step - loss: 23.3514 - val_loss: 46.2240
# Epoch 443/500
# 19/19 [==============================] - 0s 20ms/step - loss: 21.8768 - val_loss: 42.1803
# Epoch 444/500
# 19/19 [==============================] - 0s 21ms/step - loss: 27.7684 - val_loss: 58.7297
# Epoch 445/500
# 19/19 [==============================] - 0s 20ms/step - loss: 34.1346 - val_loss: 64.1181
# Epoch 446/500
# 19/19 [==============================] - 0s 21ms/step - loss: 38.5034 - val_loss: 70.7744
# Epoch 447/500
# 19/19 [==============================] - 0s 20ms/step - loss: 37.8295 - val_loss: 69.4892
# Epoch 448/500
# 19/19 [==============================] - 0s 20ms/step - loss: 45.8677 - val_loss: 64.2763
# Epoch 449/500
# 19/19 [==============================] - 0s 22ms/step - loss: 55.0256 - val_loss: 91.7766
# Epoch 450/500
# 19/19 [==============================] - 0s 20ms/step - loss: 74.6862 - val_loss: 56.7402
# Epoch 451/500
# 19/19 [==============================] - 0s 20ms/step - loss: 53.6539 - val_loss: 69.9845
# Epoch 452/500
# 19/19 [==============================] - 0s 21ms/step - loss: 82.2094 - val_loss: 73.7687
# Epoch 453/500
# 19/19 [==============================] - 0s 21ms/step - loss: 66.6869 - val_loss: 51.0622
# Epoch 454/500
# 19/19 [==============================] - 0s 21ms/step - loss: 66.0592 - val_loss: 64.8103
# Epoch 455/500
# 19/19 [==============================] - 0s 21ms/step - loss: 69.3402 - val_loss: 62.4747
# Epoch 456/500
# 19/19 [==============================] - 0s 20ms/step - loss: 60.7285 - val_loss: 82.8888
# Epoch 457/500
# 19/19 [==============================] - 0s 21ms/step - loss: 40.3907 - val_loss: 57.5224
# Epoch 458/500
# 19/19 [==============================] - 0s 21ms/step - loss: 30.8289 - val_loss: 61.7700
# Epoch 459/500
# 19/19 [==============================] - 0s 21ms/step - loss: 32.7687 - val_loss: 48.5696
# Epoch 460/500
# 19/19 [==============================] - 0s 21ms/step - loss: 26.8117 - val_loss: 49.0230
# Epoch 461/500
# 19/19 [==============================] - 0s 20ms/step - loss: 21.0226 - val_loss: 43.3959
# Epoch 462/500
# 19/19 [==============================] - 0s 21ms/step - loss: 19.5582 - val_loss: 46.5265
# Epoch 463/500
# 19/19 [==============================] - 0s 21ms/step - loss: 44.1411 - val_loss: 51.2726
# Epoch 464/500
# 19/19 [==============================] - 0s 21ms/step - loss: 37.3552 - val_loss: 48.5695
# Epoch 465/500
# 19/19 [==============================] - 0s 20ms/step - loss: 25.4716 - val_loss: 51.3253
# Epoch 466/500
# 19/19 [==============================] - 0s 20ms/step - loss: 21.2863 - val_loss: 49.4232
# Epoch 467/500
# 19/19 [==============================] - 0s 22ms/step - loss: 22.1138 - val_loss: 43.9299
# Epoch 468/500
# 19/19 [==============================] - 0s 20ms/step - loss: 23.3735 - val_loss: 48.3601
# Epoch 469/500
# 19/19 [==============================] - 0s 21ms/step - loss: 20.7234 - val_loss: 43.5929
# Epoch 470/500
# 19/19 [==============================] - 0s 21ms/step - loss: 20.0821 - val_loss: 44.4442
# Epoch 471/500
# 19/19 [==============================] - 0s 21ms/step - loss: 20.8504 - val_loss: 43.0142
# Epoch 472/500
# 19/19 [==============================] - 0s 20ms/step - loss: 21.2430 - val_loss: 44.9167
# Epoch 473/500
# 19/19 [==============================] - 0s 20ms/step - loss: 21.9798 - val_loss: 42.9654
# Epoch 474/500
# 19/19 [==============================] - 0s 21ms/step - loss: 23.6879 - val_loss: 45.9732
# Epoch 475/500
# 19/19 [==============================] - 0s 21ms/step - loss: 24.3902 - val_loss: 42.7715
# Epoch 476/500
# 19/19 [==============================] - 0s 21ms/step - loss: 27.3149 - val_loss: 47.7614
# Epoch 477/500
# 19/19 [==============================] - 0s 22ms/step - loss: 28.7102 - val_loss: 42.8851
# Epoch 478/500
# 19/19 [==============================] - 0s 21ms/step - loss: 31.6664 - val_loss: 50.4696
# Epoch 479/500
# 19/19 [==============================] - 0s 21ms/step - loss: 33.5473 - val_loss: 43.4145
# Epoch 480/500
# 19/19 [==============================] - 0s 21ms/step - loss: 35.0420 - val_loss: 52.8371
# Epoch 481/500
# 19/19 [==============================] - 0s 20ms/step - loss: 37.1004 - val_loss: 44.3304
# Epoch 482/500
# 19/19 [==============================] - 0s 21ms/step - loss: 35.5811 - val_loss: 54.1570
# Epoch 483/500
# 19/19 [==============================] - 0s 22ms/step - loss: 39.8490 - val_loss: 44.2652
# Epoch 484/500
# 19/19 [==============================] - 0s 21ms/step - loss: 38.3231 - val_loss: 52.8098
# Epoch 485/500
# 19/19 [==============================] - 0s 21ms/step - loss: 46.7414 - val_loss: 44.4596
# Epoch 486/500
# 19/19 [==============================] - 0s 21ms/step - loss: 48.5555 - val_loss: 51.8290
# Epoch 487/500
# 19/19 [==============================] - 0s 22ms/step - loss: 33.7128 - val_loss: 44.1668
# Epoch 488/500
# 19/19 [==============================] - 0s 21ms/step - loss: 29.6726 - val_loss: 51.5079
# Epoch 489/500
# 19/19 [==============================] - 0s 20ms/step - loss: 29.7487 - val_loss: 44.5418
# Epoch 490/500
# 19/19 [==============================] - 0s 20ms/step - loss: 37.7401 - val_loss: 50.1058
# Epoch 491/500
# 19/19 [==============================] - 0s 20ms/step - loss: 50.2102 - val_loss: 46.0052
# Epoch 492/500
# 19/19 [==============================] - 0s 21ms/step - loss: 28.8090 - val_loss: 52.9252
# Epoch 493/500
# 19/19 [==============================] - 0s 20ms/step - loss: 22.2638 - val_loss: 44.4373
# Epoch 494/500
# 19/19 [==============================] - 0s 21ms/step - loss: 22.5801 - val_loss: 47.3628
# Epoch 495/500
# 19/19 [==============================] - 0s 21ms/step - loss: 24.3083 - val_loss: 43.7927
# Epoch 496/500
# 19/19 [==============================] - 0s 21ms/step - loss: 23.2044 - val_loss: 60.8526
# Epoch 497/500
# 19/19 [==============================] - 0s 20ms/step - loss: 26.1395 - val_loss: 60.9813
# Epoch 498/500
# 19/19 [==============================] - 0s 21ms/step - loss: 29.9646 - val_loss: 60.5896
# Epoch 499/500
# 19/19 [==============================] - 0s 21ms/step - loss: 25.0846 - val_loss: 70.5141
# Epoch 500/500
# 19/19 [==============================] - 0s 20ms/step - loss: 32.5722 - val_loss: 55.0864

# %% [markdown]
# ## **7. Đánh giá và trực quan hóa**

# %%
def mae(y_true, y_pred):
    mae = np.mean(np.abs((y_true - y_pred)))

    return mae

def mse(y_true, y_pred):
    mse = np.mean((y_true - y_pred) ** 2)

    return mse

def rmse(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true-y_pred)**2))

    return rmse

def mape(y_true, y_pred):
    mape = np.mean(np.abs((y_true-y_pred) / y_true)) * 100

    return mape

# %%
y_test_pred = model.predict(X_test, verbose=0)
print(f'RMSE: {rmse(y_test, y_test_pred)}')
print(f'MAPE: {mape(y_test, y_test_pred)}')
print(f'MSE: {mse(y_test, y_test_pred)}')
print(f'MAE: {mae(y_test, y_test_pred)}')
# Out:
# RMSE: 4.963998275919773
# MAPE: 1.7415023621150687
# MSE: 24.64127888333448
# MAE: 3.7591494617103196

# %%
train_loss = history.history['loss']# Đọc thông tin loss trên tập train
val_loss = history.history['val_loss'] # Đọc thông tin loss trên tập val

plt.figure(figsize=(10, 5)) # Cài đặt kích thước khung ảnh

plt.subplot(1, 2, 1) # Khởi tạo khung ảnh cho training loss
plt.xlabel('Epochs') # Hiển thị tên trục hoành là 'Epochs'
plt.ylabel('Loss') # Hiển thị tên trục tung là 'Loss'
plt.title('Training loss') # Hiển thị title của khung ảnh hiện tại là 'Training Loss'
plt.plot(train_loss, color='green') # Vẽ đường giá trị loss trên tập train qua từng epoch (đường vẽ màu đỏ)

plt.subplot(1, 2, 2) # Khởi tạo khung ảnh cho val loss
plt.xlabel('Epochs') # Hiển thị tên trục hoành là 'Epochs'
plt.ylabel('Loss') # Hiển thị tên trục tung là 'Loss'
plt.title('Validation loss') # Hiển thị title của khung ảnh hiện tại là 'Validation loss'
plt.plot(val_loss, color='orange') # Vẽ đường giá trị loss trên tập val qua từng epoch (đường vẽ màu đỏ)

plt.show() # Hiển thị 2 khung ảnh nhỏ

# %%
def plot_difference(y, pred):
    plt.figure(figsize=(20, 6))
    times = range(len(y))
    y_to_plot = y.flatten()
    pred_to_plot = pred.flatten()

    plt.plot(times, y_to_plot, color='steelblue', marker='o', label='True value')
    plt.plot(times, pred_to_plot, color='orangered', marker='X', label='Prediction')

    plt.title('Adj Closing Price per day')
    plt.xlabel('Date')
    plt.ylabel('Adj Close Price')
    plt.legend()
    plt.show()

plot_difference(y_test[:300], model.predict(X_test[:300], verbose=0))
